# %% [markdown]
# # Knowledge Distillation: ConvNeXt V2 → MobileNetV3 (Colab)
#
# **Mục tiêu:** Dùng ID embedding 512-D của teacher ConvNeXt V2 (đã train MTL) để hướng dẫn student MobileNetV3 học compact embedding cho face recognition.
#
# | | Teacher | Student |
# |---|---|---|
# | Model | `MTLFaceRecognition` (ConvNeXt V2) | `FaceRecognitionMobileNetV3` |
# | Params | ~28M | ~5M |
# | Embedding dùng cho KD | `x_id` (512-D, tầng cuối) | 512-D |
# | Mode | **Frozen** | **Trainable** |
#
# **KD Loss:**
# ```
# L_total = α · L_MagFace(student)  +  β · L_KD
# L_KD    = mean(1 - cosine_sim(norm(s_emb), norm(t_emb)))
# ```
#
# **Cách dùng:**
# 1. Mount Google Drive (cell 1)
# 2. Sửa `CONFIGURATION` và `TEACHER_CKPT` (cell Config)
# 3. Chạy từ trên xuống

# %% [markdown]
# ## 1. Mount Drive & Setup môi trường

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

REPO_URL    = 'https://github.com/NguyenXuanBinh22/DATN.git'
REPO_BRANCH = 'convnext-v2-dev'
REPO_DIR    = '/content/FR_Photometric_Stereo'

if not os.path.exists(REPO_DIR):
    os.system(f'git clone -b {REPO_BRANCH} {REPO_URL} {REPO_DIR}')
else:
    os.system(f'git -C {REPO_DIR} pull origin {REPO_BRANCH}')
    print('Repo đã tồn tại, đã pull latest.')

# %cd {REPO_DIR}
print(f'Working dir: {os.getcwd()}')

os.system('pip install -q albumentations==1.3.1 timm tabulate termcolor')
# Out:
# Mounted at /content/drive
# /content/FR_Photometric_Stereo
# Working dir: /content/FR_Photometric_Stereo
# 0

# %% [markdown]
# ## 2. Imports & Cấu hình

# %%
# %cd /content/FR_Photometric_Stereo
import warnings
warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import albumentations as A
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
from torch.utils.tensorboard import SummaryWriter
from tabulate import tabulate

from going_modular.dataloader.multitask import create_multitask_datafetcher, create_eval_loaders
from going_modular.model.MTLFaceRecognition import MTLFaceRecognition
from going_modular.model.FaceRecognitionMobileNetV3 import FaceRecognitionMobileNetV3
from going_modular.loss.WeightClassMagLoss import WeightClassMagLoss
from going_modular.utils.transforms import RandomResizedCropRect, GaussianNoise
from going_modular.utils.roc_auc_id import (
    compute_id_auc, compute_rank1,
    compute_id_auc_gallery_probe, compute_rank1_gallery_probe,
)
from going_modular.utils.MultiMetricEarlyStopping import MultiMetricEarlyStopping
from going_modular.utils.ModelCheckPoint import ModelCheckpoint
from going_modular.utils.ExperimentManager import ExperimentManager

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(42)
print(f'Device: {device}')
if device == 'cuda':
    print(f'GPU: {torch.cuda.get_device_name(0)}')
# Out:
# /content/FR_Photometric_Stereo
# Device: cuda
# GPU: NVIDIA A100-SXM4-40GB

# %%
# ════════════════════════════════════════════════════════════
#  CẤU HÌNH — chỉnh sửa ở đây
# ════════════════════════════════════════════════════════════

# Đường dẫn dataset trên Google Drive
DRIVE_DATASET_DIR = '/content/drive/MyDrive/Photometric_DB_Full/'

# Checkpoint teacher ConvNeXt V2 đã train (best_model.pth hoặc last_model.pth)
# Ví dụ: '/content/drive/MyDrive/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth'
TEACHER_CKPT = '/content/drive/MyDrive/Photometric_DB_Full/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth'

EXPERIMENT_NAME = '(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector'

CONFIGURATION = {
    'note':        EXPERIMENT_NAME,
    'dataset_dir': DRIVE_DATASET_DIR,

    # Ghi checkpoint và log vào Drive để không mất khi Colab disconnect
    'output_dir':  '/content/drive/MyDrive/',

    # Modality: 'albedo' | 'normalmap' | 'depthmap'
    # Phải giống modality mà teacher đã được train
    'type':        'albedo',

    # Teacher backbone (để tái tạo đúng kiến trúc khi load checkpoint)
    'teacher_backbone': 'convnextv2_tiny',

    # Student backbone
    'backbone':    'mobilenetv3_large_100',

    'use_sampler': True,   # PK Sampler — mỗi batch gồm batch_size identity khác nhau
    'device':      device,
    'epochs':      100,
    'batch_size':  32,
    'image_size':  112,
    'base_lr':     1e-4,
    'num_classes': None,   # tự động lấy từ CSV

    # Trọng số loss
    # L_total = task_weight * L_MagFace + kd_weight * L_KD
    'task_weight': 1.0,
    'kd_weight':   15.0,
}

print(f"Dataset dir : {CONFIGURATION['dataset_dir']}")
print(f"Output dir  : {CONFIGURATION['output_dir']}")
print(f"Teacher ckpt: {TEACHER_CKPT}")
# Out:
# Dataset dir : /content/drive/MyDrive/Photometric_DB_Full/
# Output dir  : /content/drive/MyDrive/
# Teacher ckpt: /content/drive/MyDrive/Photometric_DB_Full/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth

# %% [markdown]
# ## 3. Data Loading
#
# Dùng **cùng transform** với ConvNeXt V2 để student và teacher nhận cùng input trong mỗi batch.

# %%
dataset_dir = CONFIGURATION['dataset_dir']

# Tìm CSV — hỗ trợ cả hai cấu trúc thư mục
train_csv = os.path.join(dataset_dir, 'train_split.csv')
if not os.path.exists(train_csv):
    train_csv = os.path.join(dataset_dir, 'dataset', 'train_split.csv')
if not os.path.exists(train_csv):
    train_csv = os.path.join(dataset_dir, 'train_set.csv')
if not os.path.exists(train_csv):
    raise FileNotFoundError(
        f'Không tìm thấy CSV train tại {dataset_dir}.\n'
        f'Kiểm tra lại DRIVE_DATASET_DIR.'
    )
print(f'Train CSV: {train_csv}')

df_train = pd.read_csv(train_csv)
CONFIGURATION['num_classes'] = int(df_train['id'].nunique())
print(f'num_classes : {CONFIGURATION["num_classes"]}')
print(f'Số mẫu train: {len(df_train)}')

# Transform — giống hệt ConvNeXt V2 pipeline
train_transform = A.Compose([
    RandomResizedCropRect(CONFIGURATION['image_size']),
    GaussianNoise(p=0.2),
    A.HorizontalFlip(p=0.5),
])
test_transform = A.Compose([
    A.Resize(CONFIGURATION['image_size'], CONFIGURATION['image_size']),
])

# Training dataloader — probe_split.csv dùng để monitor AUC trong vòng lặp train
train_dl, test_dl, _ = create_multitask_datafetcher(
    CONFIGURATION, train_transform, test_transform, 'train_split.csv', 'probe_split.csv'
)
print(f'Train batches: {len(train_dl)} | Test batches (probe): {len(test_dl)}')

# Gallery-probe loaders — CHỈ dùng cho đánh giá cuối, không dùng trong training
# gallery_split.csv: reference set | probe_split.csv: query set
gallery_dl, probe_dl = create_eval_loaders(CONFIGURATION, test_transform)
# Out:
# Train CSV: /content/drive/MyDrive/Photometric_DB_Full/train_split.csv
# num_classes : 352
# Số mẫu train: 2622
# >>> SingleLoader: MODE = PK SAMPLER
# Train batches: 81 | Test batches (probe): 9
# Gallery: 68 ảnh | Probe: 288 ảnh
# Shared identity space: 68 identities

# %% [markdown]
# ## 4. Teacher Model (ConvNeXt V2 — Frozen)
#
# Load checkpoint đã train, freeze toàn bộ weights.
# Chỉ dùng `get_embedding(x)[-1]` để lấy **ID embedding** (`x_id`, tầng embedding cuối).

# %%
if not os.path.exists(TEACHER_CKPT):
    raise FileNotFoundError(
        f'Không tìm thấy teacher checkpoint: {TEACHER_CKPT}\n'
        f'Kiểm tra lại biến TEACHER_CKPT.'
    )

# Khởi tạo teacher với đúng kiến trúc
teacher = MTLFaceRecognition(
    backbone=CONFIGURATION['teacher_backbone'],
    num_classes=CONFIGURATION['num_classes'],
)

# Load weights
ckpt = torch.load(TEACHER_CKPT, map_location=device, weights_only=False)
state_dict = ckpt['model_state_dict']

# Remove keys related to the id_head.maglinear layer to avoid size mismatch errors
# This layer is not needed as the teacher is used for feature extraction only
keys_to_remove = [k for k in state_dict.keys() if 'id_head.maglinear' in k]
for k in keys_to_remove:
    del state_dict[k]

teacher.load_state_dict(ckpt['model_state_dict'], strict=False)  # strict=False để bỏ qua nếu có layers mới (như classifier)
print(f"Teacher loaded — epoch {ckpt.get('epoch', '?')}")

# Freeze hoàn toàn
teacher.to(device)
teacher.eval()
for p in teacher.parameters():
    p.requires_grad = False

teacher_params = sum(p.numel() for p in teacher.parameters())
print(f'Teacher params: {teacher_params:,} (tất cả frozen)')

# Smoke test — kiểm tra embedding shape
with torch.no_grad():
    _dummy = torch.randn(2, 3, 112, 112).to(device)
    # get_embedding() trả về (x_spec, x_fh, x_pose, x_emot, x_gender, x_id)
    _t_emb = teacher.get_embedding(_dummy)[-1]   # x_id
    print(f'Teacher ID embedding shape: {_t_emb.shape}')   # mong đợi [2, 512]
# Out:
# Teacher loaded — epoch 28
# Teacher params: 45,670,280 (tất cả frozen)
# Teacher ID embedding shape: torch.Size([2, 512])

# %% [markdown]
# ## 4.1. Đánh giá Teacher Model (baseline)
#
# Đo AUC của teacher trên train/test set **trước khi distillation** để có baseline so sánh với student sau này.

# %%
class _TeacherEvalWrapper(torch.nn.Module):
    """MTLFaceRecognition.get_embedding() trả về tuple — wrapper giữ lại x_id (index -1)."""
    def __init__(self, teacher):
        super().__init__()
        self._teacher = teacher

    def get_embedding(self, x):
        return self._teacher.get_embedding(x)[-1]   # x_id: [B, 512]


teacher_wrapper = _TeacherEvalWrapper(teacher).to(device)
teacher_wrapper.eval()

teacher_gp_auc   = compute_id_auc_gallery_probe(gallery_dl, probe_dl, teacher_wrapper, device)
teacher_gp_rank1 = compute_rank1_gallery_probe(gallery_dl, probe_dl, teacher_wrapper, device)

rows = [
    ['Cosine AUC    (gallery→probe)', f"{teacher_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)', f"{teacher_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)', f"{teacher_gp_rank1:.4f}"],
]
print(f"Teacher ({CONFIGURATION['teacher_backbone']}) — weight: {TEACHER_CKPT}")
print(tabulate(rows, headers=['Metric', 'Value'], tablefmt='fancy_grid'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1092/3359094226.py in <cell line: 0>()
#      12 teacher_wrapper.eval()
#      13
# ---> 14 teacher_gp_auc   = compute_id_auc_gallery_probe(gallery_dl, probe_dl, teacher_wrapper, device)
#      15 teacher_gp_rank1 = compute_rank1_gallery_probe(gallery_dl, probe_dl, teacher_wrapper, device)
#      16
#
# /content/FR_Photometric_Stereo/going_modular/utils/roc_auc_id.py in compute_id_auc_gallery_probe(gallery_dl, probe_dl, model, device)
#      65     """
#      66     g_ids, g_emb = _collect_embeddings(gallery_dl, model, device)
# ---> 67     p_ids, p_emb = _collect_embeddings(probe_dl,   model, device)
#      68
#      69     cos_sim  = torch.mm(p_emb, g_emb.t())          # [P, G]
#
# /content/FR_Photometric_Stereo/going_modular/utils/roc_auc_id.py in _collect_embeddings(dataloader, model, device)
#      11     embeddings_list = []
#      12     with torch.no_grad():
# ---> 13         for X, y in dataloader:
#      14             X = X.to(device)
#      15             emb = model.get_embedding(X)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     739                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740                 self._reset()  # type: ignore[call-arg]
# --> 741             data = self._next_data()
#     742             self._num_yielded += 1
#     743             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1522                     "Invalid iterator state: shutdown or no outstanding tasks when fetching next data"
#    1523                 )
# -> 1524             idx, data = self._get_data()
#    1525             self._tasks_outstanding -= 1
#    1526             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1481         else:
#    1482             while True:
# -> 1483                 success, data = self._try_get_data()
#    1484                 if success:
#    1485                     return data
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1308         #   (bool: whether successfully get data, any: data if successful else None)
#    1309         try:
# -> 1310             data = self._data_queue.get(timeout=timeout)
#    1311             return (True, data)
#    1312         except Exception as e:
#
# /usr/lib/python3.12/multiprocessing/queues.py in get(self, block, timeout)
#     111                 if block:
#     112                     timeout = deadline - time.monotonic()
# --> 113                     if not self._poll(timeout):
#     114                         raise Empty
#     115                 elif not self._poll():
#
# /usr/lib/python3.12/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# /usr/lib/python3.12/multiprocessing/connection.py in _poll(self, timeout)
#     438
#     439     def _poll(self, timeout):
# --> 440         r = wait([self], timeout)
#     441         return bool(r)
#     442
#
# /usr/lib/python3.12/multiprocessing/connection.py in wait(object_list, timeout)
#    1134
#    1135             while True:
# -> 1136                 ready = selector.select(timeout)
#    1137                 if ready:
#    1138                     return [key.fileobj for (key, events) in ready]
#
# /usr/lib/python3.12/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %% [markdown]
# ## 5. Student Model (MobileNetV3 — Trainable)

# %%
student = FaceRecognitionMobileNetV3(
    num_classes=CONFIGURATION['num_classes'],
    backbone=CONFIGURATION['backbone'],
)
student.to(device)

total_p     = sum(p.numel() for p in student.parameters())
trainable_p = sum(p.numel() for p in student.parameters() if p.requires_grad)
print(f'Student total params    : {total_p:,}')
print(f'Student trainable params: {trainable_p:,}')

# Smoke test
with torch.no_grad():
    _s_emb = student.get_embedding(_dummy)
    print(f'Student embedding shape: {_s_emb.shape}')   # mong đợi [2, 512]
# Out:
# model.safetensors:   0%|          | 0.00/22.1M [00:00<?, ?B/s]
# WARNING:timm.models._builder:Unexpected keys (classifier.bias, classifier.weight, conv_head.bias, conv_head.weight) found while loading pretrained weights. This may be expected if model is being adapted.
# Student total params    : 3,645,744
# Student trainable params: 3,645,744
# Student embedding shape: torch.Size([2, 512])

# %% [markdown]
# ## 6. Knowledge Distillation Loss
#
# ```
# L_total = α · L_MagFace  +  β · L_KD
#
# L_MagFace : WeightClassMagFace — phân biệt class boundaries cho student
# L_KD      : Cosine distance giữa student emb và teacher ID emb
#            = mean(1 - cos_sim(norm(s_emb), norm(t_emb)))
# ```
#
# **Tại sao cosine loss:**
# Face verification so sánh *hướng* của embedding (cosine sim), không phải magnitude.
# Cosine loss kéo student về đúng hướng mà không ràng buộc magnitude.

# %%
class KDLoss(nn.Module):
    """
    L_total = task_weight * L_MagFace  +  kd_weight * L_KD_cosine
    """

    def __init__(self, metadata_path: str, task_weight: float = 1.0, kd_weight: float = 1.0):
        super().__init__()
        self.magface = WeightClassMagLoss(metadata_path)
        self.task_w  = task_weight
        self.kd_w    = kd_weight

    def forward(
        self,
        student_logits,   # [cos_theta, cos_theta_m] từ MagLinear
        student_norm,     # x_norm từ MagLinear
        student_emb,      # [B, 512] — embedding trước MagLinear
        teacher_emb,      # [B, 512] — ID embedding của teacher (no_grad)
        id_labels,        # [B] — ground-truth identity
    ):
        # Task loss
        l_task = self.magface(student_logits, id_labels, student_norm)

        # KD loss — cosine distance trên unit hypersphere
        s_n = F.normalize(student_emb, p=2, dim=1)
        t_n = F.normalize(teacher_emb, p=2, dim=1)
        l_kd = (1.0 - F.cosine_similarity(s_n, t_n, dim=1)).mean()

        total = self.task_w * l_task + self.kd_w * l_kd
        return total, l_task, l_kd


criterion = KDLoss(
    metadata_path=train_csv,
    task_weight=CONFIGURATION['task_weight'],
    kd_weight=CONFIGURATION['kd_weight'],
)
print('KDLoss khởi tạo thành công.')
# Out:
# KDLoss khởi tạo thành công.

# %% [markdown]
# ## 6.1. Projection Head
#
# Student và teacher sống trong hai embedding space khác nhau — ép chúng chia sẻ cùng một space là quá cứng nhắc và thường dẫn đến `loss_kd` cao.
#
# Giải pháp: thêm một MLP nhỏ (**ProjectionHead**) giúp bridge hai space lại.
#
# ```
# student_emb (512-D)  →  projector  →  proj_emb (512-D)  ←→  teacher_emb
# ```
#
# - `student_emb` vẫn đi thẳng vào `MagLinear` (task loss không thay đổi)
# - Chỉ `proj_emb` được dùng cho KD loss
# - Projector **chỉ tồn tại khi train**, bỏ hoàn toàn khi export ONNX

# %%
class ProjectionHead(nn.Module):
    """
    MLP bridge: student embedding space → teacher embedding space.
    Chỉ dùng khi tính KD loss, không tham gia inference / ONNX export.

    Luồng:
        student_emb  →  Linear(512→512) → BN → ReLU → Linear(512→512)
                     →  proj_emb  ←→  teacher_emb  (cosine KD loss)
    """
    def __init__(self, in_dim: int = 512, hidden_dim: int = 512, out_dim: int = 512):
        super().__init__()
        self.proj = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Linear(hidden_dim, out_dim),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.proj(x)


projector = ProjectionHead(in_dim=512, hidden_dim=512, out_dim=512).to(device)
proj_params = sum(p.numel() for p in projector.parameters())
print(f'ProjectionHead params: {proj_params:,}  (train-only, dropped at export)')
# Out:
# ProjectionHead params: 526,336  (train-only, dropped at export)

# %% [markdown]
# ## 7. Training

# %%
def train_epoch(train_dl, teacher, student, projector, criterion, optimizer, device):
    student.train()
    projector.train()
    # teacher.eval() + frozen — không cần đặt lại mỗi epoch

    total_loss = total_task = total_kd = 0.0

    for X, y in train_dl:
        X, y = X.to(device), y.to(device)
        id_labels = y[:, 0]   # chỉ cần identity label

        # Teacher forward — no gradient, không update weights
        with torch.no_grad():
            # get_embedding() → (x_spec, x_fh, x_pose, x_emot, x_gender, x_id)
            teacher_emb = teacher.get_embedding(X)[-1]   # x_id: [B, 512]

        # Student forward — một lần duy nhất để lấy cả embedding lẫn logits
        feat         = student.backbone(X)          # [B, 512, H, W]
        student_emb  = student.embedding(feat)      # [B, 512]
        proj_emb     = projector(student_emb)       # [B, 512] — bridge to teacher space
        logits, norm = student.maglinear(student_emb)

        # Loss tổng hợp
        # task loss dùng student_emb gốc (không qua projector)
        # KD loss dùng proj_emb để không ràng buộc student_emb phải giống teacher
        loss, l_task, l_kd = criterion(
            logits, norm, proj_emb, teacher_emb, id_labels
        )

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        total_task += l_task.item()
        total_kd   += l_kd.item()

    n = len(train_dl)
    return total_loss / n, total_task / n, total_kd / n


def display_metrics(epoch, train_metrics, test_metrics):
    rows = []
    for k in train_metrics:
        tv = train_metrics[k]
        ev = test_metrics.get(k, '-')
        fmt = lambda v: f'{v:.4f}' if isinstance(v, float) else str(v)
        rows.append([k, fmt(tv), fmt(ev)])
    print(f'\nEp {epoch}:')
    print(tabulate(rows, headers=['Metric', 'Train', 'Test'], tablefmt='fancy_grid'))

# %%
optimizer = Adam(
    list(student.parameters()) + list(projector.parameters()),
    lr=CONFIGURATION['base_lr'],
)
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=20, T_mult=2, eta_min=1e-6)

manager = ExperimentManager(CONFIGURATION)
manager.log_text(
    f"Teacher: {CONFIGURATION['teacher_backbone']} | "
    f"Student: {CONFIGURATION['backbone']} | "
    f"Modality: {CONFIGURATION['type']} | "
    f"kd_weight={CONFIGURATION['kd_weight']} task_weight={CONFIGURATION['task_weight']} | "
    f"projector=True"
)

ckpt_saver = ModelCheckpoint(
    output_dir=manager.ckpt_dir,
    mode='max',
    best_metric_name='auc_id_cosine',
)
early_stopping = MultiMetricEarlyStopping(
    monitor_keys=['auc_id_cosine'],
    patience=10,
    mode='max',
    verbose=1,
    save_dir=manager.ckpt_dir,
    start_from_epoch=5,
)

writer = SummaryWriter(log_dir=manager.log_dir)
print(f'Experiment dir: {manager.exp_dir}')
print(f'Checkpoint dir: {manager.ckpt_dir}')
print('(Tất cả được ghi thẳng vào Google Drive)')
# Out:
# KHOI TAO THI NGHIEM: (hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector
# Luu tru tai: /content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector
# Thoi gian: 2026-05-31 13:44:53
# --------------------------------------------------
# Teacher: convnextv2_tiny | Student: mobilenetv3_large_100 | Modality: albedo | kd_weight=15.0 task_weight=1.0 | projector=True
# Experiment dir: /content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector
# Checkpoint dir: /content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints
# (Tất cả được ghi thẳng vào Google Drive)

# %%
START_EPOCH = 0

manager.log_text('BAT DAU KNOWLEDGE DISTILLATION (với ProjectionHead)')

for epoch in range(START_EPOCH, CONFIGURATION['epochs']):
    manager.log_text(f'\n--- Epoch {epoch+1}/{CONFIGURATION["epochs"]} ---')

    # Train
    train_loss, train_task, train_kd = train_epoch(
        train_dl, teacher, student, projector, criterion, optimizer, device
    )

    # AUC — dùng student.get_embedding() trực tiếp (không qua projector)
    train_auc = compute_id_auc(train_dl, student, device)
    test_auc  = compute_id_auc(test_dl,  student, device)

    train_metrics = {
        'loss':             train_loss,
        'loss_task':        train_task,
        'loss_kd':          train_kd,
        'auc_id_cosine':    train_auc['id_cosine'],
        'auc_id_euclidean': train_auc['id_euclidean'],
    }
    test_metrics = {
        'auc_id_cosine':    test_auc['id_cosine'],
        'auc_id_euclidean': test_auc['id_euclidean'],
    }

    # TensorBoard
    writer.add_scalar('Loss/total', train_loss, epoch + 1)
    writer.add_scalar('Loss/task',  train_task, epoch + 1)
    writer.add_scalar('Loss/kd',    train_kd,   epoch + 1)
    writer.add_scalars('AUC/cosine',
        {'train': train_auc['id_cosine'],    'test': test_auc['id_cosine']},    epoch + 1)
    writer.add_scalars('AUC/euclidean',
        {'train': train_auc['id_euclidean'], 'test': test_auc['id_euclidean']}, epoch + 1)

    # Console + file log
    display_metrics(epoch + 1, train_metrics, test_metrics)
    manager.log_metrics(epoch + 1, {**train_metrics, **test_metrics})

    # Checkpoint (lưu cả projector state để có thể resume)
    ckpt_saver(
        student, optimizer, epoch + 1, test_metrics, scheduler,
        extra_state={'projector_state_dict': projector.state_dict()},
    )
    early_stopping(test_metrics, student, epoch + 1)
    scheduler.step(epoch)

    if early_stopping.early_stop:
        manager.log_text('Early stopping triggered.')
        break

writer.close()
manager.log_text('KNOWLEDGE DISTILLATION HOAN TAT.')
# Out:
# BAT DAU KNOWLEDGE DISTILLATION (với ProjectionHead)
#
# --- Epoch 1/100 ---
#
# Ep 1:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 42.458  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 28.2895 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9446 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9138 │ 0.8821 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9138 │ 0.8821 │
# ╘══════════════════╧═════════╧════════╛
# Ep 1: loss: 42.4580, loss_task: 28.2895, loss_kd: 0.9446, auc_id_cosine: 0.8821, auc_id_euclidean: 0.8821
# --> SAVE BEST MODEL (auc_id_cosine: 0.8821)
#
# --- Epoch 2/100 ---
#
# Ep 2:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 44.9103 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 31.6686 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.8828 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9349 │ 0.8962 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9349 │ 0.8962 │
# ╘══════════════════╧═════════╧════════╛
# Ep 2: loss: 44.9103, loss_task: 31.6686, loss_kd: 0.8828, auc_id_cosine: 0.8962, auc_id_euclidean: 0.8962
# --> SAVE BEST MODEL (auc_id_cosine: 0.8962)
#
# --- Epoch 3/100 ---
#
# Ep 3:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 42.7042 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 30.0899 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.8409 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9508 │ 0.9136 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9508 │ 0.9136 │
# ╘══════════════════╧═════════╧════════╛
# Ep 3: loss: 42.7042, loss_task: 30.0899, loss_kd: 0.8409, auc_id_cosine: 0.9136, auc_id_euclidean: 0.9136
# --> SAVE BEST MODEL (auc_id_cosine: 0.9136)
#
# --- Epoch 4/100 ---
#
# Ep 4:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 39.4987 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 27.6142 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.7923 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9634 │ 0.9206 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9634 │ 0.9206 │
# ╘══════════════════╧═════════╧════════╛
# Ep 4: loss: 39.4987, loss_task: 27.6142, loss_kd: 0.7923, auc_id_cosine: 0.9206, auc_id_euclidean: 0.9206
# --> SAVE BEST MODEL (auc_id_cosine: 0.9206)
#
# --- Epoch 5/100 ---
#
# Ep 5:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 36.3045 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 25.0519 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.7502 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9741 │ 0.9291 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9741 │ 0.9291 │
# ╘══════════════════╧═════════╧════════╛
# Ep 5: loss: 36.3045, loss_task: 25.0519, loss_kd: 0.7502, auc_id_cosine: 0.9291, auc_id_euclidean: 0.9291
# --> SAVE BEST MODEL (auc_id_cosine: 0.9291)
# 	Saved best model weights for 'auc_id_cosine' at epoch 5 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_5.pth'
#
# --- Epoch 6/100 ---
#
# Ep 6:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 33.439  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 22.7423 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.7131 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9767 │ 0.9334 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9767 │ 0.9334 │
# ╘══════════════════╧═════════╧════════╛
# Ep 6: loss: 33.4390, loss_task: 22.7423, loss_kd: 0.7131, auc_id_cosine: 0.9334, auc_id_euclidean: 0.9334
# --> SAVE BEST MODEL (auc_id_cosine: 0.9334)
# 	Saved best model weights for 'auc_id_cosine' at epoch 6 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_6.pth'
#
# --- Epoch 7/100 ---
#
# Ep 7:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 30.4825 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 20.2617 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.6814 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9832 │ 0.9360 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9832 │ 0.9360 │
# ╘══════════════════╧═════════╧════════╛
# Ep 7: loss: 30.4825, loss_task: 20.2617, loss_kd: 0.6814, auc_id_cosine: 0.9360, auc_id_euclidean: 0.9360
# --> SAVE BEST MODEL (auc_id_cosine: 0.9360)
# 	Saved best model weights for 'auc_id_cosine' at epoch 7 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_7.pth'
#
# --- Epoch 8/100 ---
#
# Ep 8:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 27.4572 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 17.7013 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.6504 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9864 │ 0.9389 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9864 │ 0.9389 │
# ╘══════════════════╧═════════╧════════╛
# Ep 8: loss: 27.4572, loss_task: 17.7013, loss_kd: 0.6504, auc_id_cosine: 0.9389, auc_id_euclidean: 0.9389
# --> SAVE BEST MODEL (auc_id_cosine: 0.9389)
# 	Saved best model weights for 'auc_id_cosine' at epoch 8 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_8.pth'
#
# --- Epoch 9/100 ---
#
# Ep 9:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 25.1152 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 15.7578 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.6238 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9831 │ 0.9409 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9831 │ 0.9409 │
# ╘══════════════════╧═════════╧════════╛
# Ep 9: loss: 25.1152, loss_task: 15.7578, loss_kd: 0.6238, auc_id_cosine: 0.9409, auc_id_euclidean: 0.9409
# --> SAVE BEST MODEL (auc_id_cosine: 0.9409)
# 	Saved best model weights for 'auc_id_cosine' at epoch 9 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_9.pth'
#
# --- Epoch 10/100 ---
#
# Ep 10:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 23.0549 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 14.0429 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.6008 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9898 │ 0.9402 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9898 │ 0.9402 │
# ╘══════════════════╧═════════╧════════╛
# Ep 10: loss: 23.0549, loss_task: 14.0429, loss_kd: 0.6008, auc_id_cosine: 0.9402, auc_id_euclidean: 0.9402
# 	Epoch 10: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 11/100 ---
#
# Ep 11:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 21.8334 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 13.1208 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5808 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9919 │ 0.9459 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9919 │ 0.9459 │
# ╘══════════════════╧═════════╧════════╛
# Ep 11: loss: 21.8334, loss_task: 13.1208, loss_kd: 0.5808, auc_id_cosine: 0.9459, auc_id_euclidean: 0.9459
# --> SAVE BEST MODEL (auc_id_cosine: 0.9459)
# 	Saved best model weights for 'auc_id_cosine' at epoch 11 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_11.pth'
#
# --- Epoch 12/100 ---
#
# Ep 12:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 20.5484 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 12.0548 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5662 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.992  │ 0.9457 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.992  │ 0.9457 │
# ╘══════════════════╧═════════╧════════╛
# Ep 12: loss: 20.5484, loss_task: 12.0548, loss_kd: 0.5662, auc_id_cosine: 0.9457, auc_id_euclidean: 0.9457
# 	Epoch 12: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 13/100 ---
#
# Ep 13:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 19.7712 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 11.452  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5546 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9922 │ 0.9469 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9922 │ 0.9469 │
# ╘══════════════════╧═════════╧════════╛
# Ep 13: loss: 19.7712, loss_task: 11.4520, loss_kd: 0.5546, auc_id_cosine: 0.9469, auc_id_euclidean: 0.9469
# --> SAVE BEST MODEL (auc_id_cosine: 0.9469)
# 	Saved best model weights for 'auc_id_cosine' at epoch 13 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_13.pth'
#
# --- Epoch 14/100 ---
#
# Ep 14:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 18.0607 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 10.1112 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.53   │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9927 │ 0.9485 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9927 │ 0.9485 │
# ╘══════════════════╧═════════╧════════╛
# Ep 14: loss: 18.0607, loss_task: 10.1112, loss_kd: 0.5300, auc_id_cosine: 0.9485, auc_id_euclidean: 0.9485
# --> SAVE BEST MODEL (auc_id_cosine: 0.9485)
# 	Saved best model weights for 'auc_id_cosine' at epoch 14 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_14.pth'
#
# --- Epoch 15/100 ---
#
# Ep 15:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 18.1068 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 10.1734 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5289 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9919 │ 0.9482 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9919 │ 0.9482 │
# ╘══════════════════╧═════════╧════════╛
# Ep 15: loss: 18.1068, loss_task: 10.1734, loss_kd: 0.5289, auc_id_cosine: 0.9482, auc_id_euclidean: 0.9482
# 	Epoch 15: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 16/100 ---
#
# Ep 16:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 17.3132 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.5608 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5168 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9911 │ 0.9495 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9911 │ 0.9495 │
# ╘══════════════════╧═════════╧════════╛
# Ep 16: loss: 17.3132, loss_task: 9.5608, loss_kd: 0.5168, auc_id_cosine: 0.9495, auc_id_euclidean: 0.9495
# --> SAVE BEST MODEL (auc_id_cosine: 0.9495)
# 	Saved best model weights for 'auc_id_cosine' at epoch 16 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_16.pth'
#
# --- Epoch 17/100 ---
#
# Ep 17:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 17.0687 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.3764 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5128 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9939 │ 0.9491 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9939 │ 0.9491 │
# ╘══════════════════╧═════════╧════════╛
# Ep 17: loss: 17.0687, loss_task: 9.3764, loss_kd: 0.5128, auc_id_cosine: 0.9491, auc_id_euclidean: 0.9491
# 	Epoch 17: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 18/100 ---
#
# Ep 18:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 16.697  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.0714 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5084 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9941 │ 0.9488 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9941 │ 0.9488 │
# ╘══════════════════╧═════════╧════════╛
# Ep 18: loss: 16.6970, loss_task: 9.0714, loss_kd: 0.5084, auc_id_cosine: 0.9488, auc_id_euclidean: 0.9488
# 	Epoch 18: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 19/100 ---
#
# Ep 19:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 16.8238 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.2173 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5071 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9945 │ 0.9508 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9945 │ 0.9508 │
# ╘══════════════════╧═════════╧════════╛
# Ep 19: loss: 16.8238, loss_task: 9.2173, loss_kd: 0.5071, auc_id_cosine: 0.9508, auc_id_euclidean: 0.9508
# --> SAVE BEST MODEL (auc_id_cosine: 0.9508)
# 	Saved best model weights for 'auc_id_cosine' at epoch 19 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_19.pth'
#
# --- Epoch 20/100 ---
#
# Ep 20:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 16.7352 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.1442 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5061 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9947 │ 0.9505 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9947 │ 0.9505 │
# ╘══════════════════╧═════════╧════════╛
# Ep 20: loss: 16.7352, loss_task: 9.1442, loss_kd: 0.5061, auc_id_cosine: 0.9505, auc_id_euclidean: 0.9505
# 	Epoch 20: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 21/100 ---
#
# Ep 21:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 16.8247 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.2254 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5066 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.995  │ 0.9500 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.995  │ 0.9500 │
# ╘══════════════════╧═════════╧════════╛
# Ep 21: loss: 16.8247, loss_task: 9.2254, loss_kd: 0.5066, auc_id_cosine: 0.9500, auc_id_euclidean: 0.9500
# 	Epoch 21: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 22/100 ---
#
# Ep 22:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 16.1707 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  8.7387 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.4955 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9952 │ 0.9519 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9952 │ 0.9519 │
# ╘══════════════════╧═════════╧════════╛
# Ep 22: loss: 16.1707, loss_task: 8.7387, loss_kd: 0.4955, auc_id_cosine: 0.9519, auc_id_euclidean: 0.9519
# --> SAVE BEST MODEL (auc_id_cosine: 0.9519)
# 	Saved best model weights for 'auc_id_cosine' at epoch 22 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_22.pth'
#
# --- Epoch 23/100 ---
#
# Ep 23:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 15.1307 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  7.9948 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.4757 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9956 │ 0.9576 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9956 │ 0.9576 │
# ╘══════════════════╧═════════╧════════╛
# Ep 23: loss: 15.1307, loss_task: 7.9948, loss_kd: 0.4757, auc_id_cosine: 0.9576, auc_id_euclidean: 0.9576
# --> SAVE BEST MODEL (auc_id_cosine: 0.9576)
# 	Saved best model weights for 'auc_id_cosine' at epoch 23 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_23.pth'
#
# --- Epoch 24/100 ---
#
# Ep 24:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 13.6863 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  6.9619 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.4483 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9958 │ 0.9559 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9958 │ 0.9559 │
# ╘══════════════════╧═════════╧════════╛
# Ep 24: loss: 13.6863, loss_task: 6.9619, loss_kd: 0.4483, auc_id_cosine: 0.9559, auc_id_euclidean: 0.9559
# 	Epoch 24: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 25/100 ---
#
# Ep 25:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 13.2363 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  6.7287 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.4338 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.997  │ 0.9608 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.997  │ 0.9608 │
# ╘══════════════════╧═════════╧════════╛
# Ep 25: loss: 13.2363, loss_task: 6.7287, loss_kd: 0.4338, auc_id_cosine: 0.9608, auc_id_euclidean: 0.9608
# --> SAVE BEST MODEL (auc_id_cosine: 0.9608)
# 	Saved best model weights for 'auc_id_cosine' at epoch 25 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_25.pth'
#
# --- Epoch 26/100 ---
#
# Ep 26:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 12.2943 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  6.0729 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.4148 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9978 │ 0.9605 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9978 │ 0.9605 │
# ╘══════════════════╧═════════╧════════╛
# Ep 26: loss: 12.2943, loss_task: 6.0729, loss_kd: 0.4148, auc_id_cosine: 0.9605, auc_id_euclidean: 0.9605
# 	Epoch 26: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 27/100 ---
#
# Ep 27:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 11.2238 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  5.3244 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3933 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9971 │ 0.9595 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9971 │ 0.9595 │
# ╘══════════════════╧═════════╧════════╛
# Ep 27: loss: 11.2238, loss_task: 5.3244, loss_kd: 0.3933, auc_id_cosine: 0.9595, auc_id_euclidean: 0.9595
# 	Epoch 27: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 28/100 ---
#
# Ep 28:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 10.7791 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  5.0852 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3796 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9974 │ 0.9616 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9974 │ 0.9616 │
# ╘══════════════════╧═════════╧════════╛
# Ep 28: loss: 10.7791, loss_task: 5.0852, loss_kd: 0.3796, auc_id_cosine: 0.9616, auc_id_euclidean: 0.9616
# --> SAVE BEST MODEL (auc_id_cosine: 0.9616)
# 	Saved best model weights for 'auc_id_cosine' at epoch 28 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_28.pth'
#
# --- Epoch 29/100 ---
#
# Ep 29:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 10.1342 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  4.6786 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3637 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9982 │ 0.9633 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9982 │ 0.9633 │
# ╘══════════════════╧═════════╧════════╛
# Ep 29: loss: 10.1342, loss_task: 4.6786, loss_kd: 0.3637, auc_id_cosine: 0.9633, auc_id_euclidean: 0.9633
# --> SAVE BEST MODEL (auc_id_cosine: 0.9633)
# 	Saved best model weights for 'auc_id_cosine' at epoch 29 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_29.pth'
#
# --- Epoch 30/100 ---
#
# Ep 30:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  9.9254 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  4.5709 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.357  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9992 │ 0.9621 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9992 │ 0.9621 │
# ╘══════════════════╧═════════╧════════╛
# Ep 30: loss: 9.9254, loss_task: 4.5709, loss_kd: 0.3570, auc_id_cosine: 0.9621, auc_id_euclidean: 0.9621
# 	Epoch 30: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 31/100 ---
#
# Ep 31:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  9.0588 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  4.036  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3349 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9992 │ 0.9605 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9992 │ 0.9605 │
# ╘══════════════════╧═════════╧════════╛
# Ep 31: loss: 9.0588, loss_task: 4.0360, loss_kd: 0.3349, auc_id_cosine: 0.9605, auc_id_euclidean: 0.9605
# 	Epoch 31: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 32/100 ---
#
# Ep 32:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  8.6869 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.8396 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3232 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9994 │ 0.9625 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9994 │ 0.9625 │
# ╘══════════════════╧═════════╧════════╛
# Ep 32: loss: 8.6869, loss_task: 3.8396, loss_kd: 0.3232, auc_id_cosine: 0.9625, auc_id_euclidean: 0.9625
# 	Epoch 32: EarlyStopping counter for 'auc_id_cosine': 3/10
#
# --- Epoch 33/100 ---
#
# Ep 33:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  8.2264 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.5535 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3115 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9992 │ 0.9638 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9992 │ 0.9638 │
# ╘══════════════════╧═════════╧════════╛
# Ep 33: loss: 8.2264, loss_task: 3.5535, loss_kd: 0.3115, auc_id_cosine: 0.9638, auc_id_euclidean: 0.9638
# --> SAVE BEST MODEL (auc_id_cosine: 0.9638)
# 	Saved best model weights for 'auc_id_cosine' at epoch 33 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_33.pth'
#
# --- Epoch 34/100 ---
#
# Ep 34:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  8.1009 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.5275 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3049 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9994 │ 0.9627 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9994 │ 0.9627 │
# ╘══════════════════╧═════════╧════════╛
# Ep 34: loss: 8.1009, loss_task: 3.5275, loss_kd: 0.3049, auc_id_cosine: 0.9627, auc_id_euclidean: 0.9627
# 	Epoch 34: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 35/100 ---
#
# Ep 35:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  7.9231 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.4663 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2971 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9610 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9610 │
# ╘══════════════════╧═════════╧════════╛
# Ep 35: loss: 7.9231, loss_task: 3.4663, loss_kd: 0.2971, auc_id_cosine: 0.9610, auc_id_euclidean: 0.9610
# 	Epoch 35: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 36/100 ---
#
# Ep 36:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  7.7787 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.3809 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2932 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9994 │ 0.9656 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9994 │ 0.9656 │
# ╘══════════════════╧═════════╧════════╛
# Ep 36: loss: 7.7787, loss_task: 3.3809, loss_kd: 0.2932, auc_id_cosine: 0.9656, auc_id_euclidean: 0.9656
# --> SAVE BEST MODEL (auc_id_cosine: 0.9656)
# 	Saved best model weights for 'auc_id_cosine' at epoch 36 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_36.pth'
#
# --- Epoch 37/100 ---
#
# Ep 37:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  7.4741 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.2851 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2793 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9993 │ 0.9657 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9993 │ 0.9657 │
# ╘══════════════════╧═════════╧════════╛
# Ep 37: loss: 7.4741, loss_task: 3.2851, loss_kd: 0.2793, auc_id_cosine: 0.9657, auc_id_euclidean: 0.9657
# --> SAVE BEST MODEL (auc_id_cosine: 0.9657)
# 	Saved best model weights for 'auc_id_cosine' at epoch 37 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_37.pth'
#
# --- Epoch 38/100 ---
#
# Ep 38:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  7.1262 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.0361 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2727 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9996 │ 0.9650 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9996 │ 0.9650 │
# ╘══════════════════╧═════════╧════════╛
# Ep 38: loss: 7.1262, loss_task: 3.0361, loss_kd: 0.2727, auc_id_cosine: 0.9650, auc_id_euclidean: 0.9650
# 	Epoch 38: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 39/100 ---
#
# Ep 39:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.9869 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.9659 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2681 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9640 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9640 │
# ╘══════════════════╧═════════╧════════╛
# Ep 39: loss: 6.9869, loss_task: 2.9659, loss_kd: 0.2681, auc_id_cosine: 0.9640, auc_id_euclidean: 0.9640
# 	Epoch 39: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 40/100 ---
#
# Ep 40:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.773  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.9001 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2582 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9995 │ 0.9649 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9995 │ 0.9649 │
# ╘══════════════════╧═════════╧════════╛
# Ep 40: loss: 6.7730, loss_task: 2.9001, loss_kd: 0.2582, auc_id_cosine: 0.9649, auc_id_euclidean: 0.9649
# 	Epoch 40: EarlyStopping counter for 'auc_id_cosine': 3/10
#
# --- Epoch 41/100 ---
#
# Ep 41:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.9208 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.0165 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2603 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9647 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9647 │
# ╘══════════════════╧═════════╧════════╛
# Ep 41: loss: 6.9208, loss_task: 3.0165, loss_kd: 0.2603, auc_id_cosine: 0.9647, auc_id_euclidean: 0.9647
# 	Epoch 41: EarlyStopping counter for 'auc_id_cosine': 4/10
#
# --- Epoch 42/100 ---
#
# Ep 42:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.5281 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.7759 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2501 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9643 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9643 │
# ╘══════════════════╧═════════╧════════╛
# Ep 42: loss: 6.5281, loss_task: 2.7759, loss_kd: 0.2501, auc_id_cosine: 0.9643, auc_id_euclidean: 0.9643
# 	Epoch 42: EarlyStopping counter for 'auc_id_cosine': 5/10
#
# --- Epoch 43/100 ---
#
# Ep 43:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.5544 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.8219 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2488 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9998 │ 0.9677 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9998 │ 0.9677 │
# ╘══════════════════╧═════════╧════════╛
# Ep 43: loss: 6.5544, loss_task: 2.8219, loss_kd: 0.2488, auc_id_cosine: 0.9677, auc_id_euclidean: 0.9677
# --> SAVE BEST MODEL (auc_id_cosine: 0.9677)
# 	Saved best model weights for 'auc_id_cosine' at epoch 43 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_43.pth'
#
# --- Epoch 44/100 ---
#
# Ep 44:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.4755 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.7929 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2455 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9655 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9655 │
# ╘══════════════════╧═════════╧════════╛
# Ep 44: loss: 6.4755, loss_task: 2.7929, loss_kd: 0.2455, auc_id_cosine: 0.9655, auc_id_euclidean: 0.9655
# 	Epoch 44: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 45/100 ---
#
# Ep 45:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.1106 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.5399 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.238  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9984 │ 0.9675 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9984 │ 0.9675 │
# ╘══════════════════╧═════════╧════════╛
# Ep 45: loss: 6.1106, loss_task: 2.5399, loss_kd: 0.2380, auc_id_cosine: 0.9675, auc_id_euclidean: 0.9675
# 	Epoch 45: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 46/100 ---
#
# Ep 46:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.0899 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.5563 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2356 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9654 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9654 │
# ╘══════════════════╧═════════╧════════╛
# Ep 46: loss: 6.0899, loss_task: 2.5563, loss_kd: 0.2356, auc_id_cosine: 0.9654, auc_id_euclidean: 0.9654
# 	Epoch 46: EarlyStopping counter for 'auc_id_cosine': 3/10
#
# --- Epoch 47/100 ---
#
# Ep 47:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.1958 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.6793 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2344 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9671 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9671 │
# ╘══════════════════╧═════════╧════════╛
# Ep 47: loss: 6.1958, loss_task: 2.6793, loss_kd: 0.2344, auc_id_cosine: 0.9671, auc_id_euclidean: 0.9671
# 	Epoch 47: EarlyStopping counter for 'auc_id_cosine': 4/10
#
# --- Epoch 48/100 ---
#
# Ep 48:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.8929 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4955 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2265 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9663 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9663 │
# ╘══════════════════╧═════════╧════════╛
# Ep 48: loss: 5.8929, loss_task: 2.4955, loss_kd: 0.2265, auc_id_cosine: 0.9663, auc_id_euclidean: 0.9663
# 	Epoch 48: EarlyStopping counter for 'auc_id_cosine': 5/10
#
# --- Epoch 49/100 ---
#
# Ep 49:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.913  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4903 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2282 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9996 │ 0.9659 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9996 │ 0.9659 │
# ╘══════════════════╧═════════╧════════╛
# Ep 49: loss: 5.9130, loss_task: 2.4903, loss_kd: 0.2282, auc_id_cosine: 0.9659, auc_id_euclidean: 0.9659
# 	Epoch 49: EarlyStopping counter for 'auc_id_cosine': 6/10
#
# --- Epoch 50/100 ---
#
# Ep 50:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.9513 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.5609 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.226  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9678 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9678 │
# ╘══════════════════╧═════════╧════════╛
# Ep 50: loss: 5.9513, loss_task: 2.5609, loss_kd: 0.2260, auc_id_cosine: 0.9678, auc_id_euclidean: 0.9678
# --> SAVE BEST MODEL (auc_id_cosine: 0.9678)
# 	Saved best model weights for 'auc_id_cosine' at epoch 50 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_50.pth'
#
# --- Epoch 51/100 ---
#
# Ep 51:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.9541 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.5543 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2266 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9660 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9660 │
# ╘══════════════════╧═════════╧════════╛
# Ep 51: loss: 5.9541, loss_task: 2.5543, loss_kd: 0.2266, auc_id_cosine: 0.9660, auc_id_euclidean: 0.9660
# 	Epoch 51: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 52/100 ---
#
# Ep 52:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.8551 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4881 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2245 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9995 │ 0.9677 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9995 │ 0.9677 │
# ╘══════════════════╧═════════╧════════╛
# Ep 52: loss: 5.8551, loss_task: 2.4881, loss_kd: 0.2245, auc_id_cosine: 0.9677, auc_id_euclidean: 0.9677
# 	Epoch 52: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 53/100 ---
#
# Ep 53:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.7893 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4718 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2212 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9686 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9686 │
# ╘══════════════════╧═════════╧════════╛
# Ep 53: loss: 5.7893, loss_task: 2.4718, loss_kd: 0.2212, auc_id_cosine: 0.9686, auc_id_euclidean: 0.9686
# --> SAVE BEST MODEL (auc_id_cosine: 0.9686)
# 	Saved best model weights for 'auc_id_cosine' at epoch 53 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_53.pth'
#
# --- Epoch 54/100 ---
#
# Ep 54:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.8033 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4754 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2219 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9998 │ 0.9671 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9998 │ 0.9671 │
# ╘══════════════════╧═════════╧════════╛
# Ep 54: loss: 5.8033, loss_task: 2.4754, loss_kd: 0.2219, auc_id_cosine: 0.9671, auc_id_euclidean: 0.9671
# 	Epoch 54: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 55/100 ---
#
# Ep 55:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.6993 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.408  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2194 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9992 │ 0.9670 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9992 │ 0.9670 │
# ╘══════════════════╧═════════╧════════╛
# Ep 55: loss: 5.6993, loss_task: 2.4080, loss_kd: 0.2194, auc_id_cosine: 0.9670, auc_id_euclidean: 0.9670
# 	Epoch 55: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 56/100 ---
#
# Ep 56:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.8093 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4745 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2223 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9672 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9672 │
# ╘══════════════════╧═════════╧════════╛
# Ep 56: loss: 5.8093, loss_task: 2.4745, loss_kd: 0.2223, auc_id_cosine: 0.9672, auc_id_euclidean: 0.9672
# 	Epoch 56: EarlyStopping counter for 'auc_id_cosine': 3/10
#
# --- Epoch 57/100 ---
#
# Ep 57:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.8022 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4937 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2206 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9684 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9684 │
# ╘══════════════════╧═════════╧════════╛
# Ep 57: loss: 5.8022, loss_task: 2.4937, loss_kd: 0.2206, auc_id_cosine: 0.9684, auc_id_euclidean: 0.9684
# 	Epoch 57: EarlyStopping counter for 'auc_id_cosine': 4/10
#
# --- Epoch 58/100 ---
#
# Ep 58:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.7169 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4385 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2186 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9694 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9694 │
# ╘══════════════════╧═════════╧════════╛
# Ep 58: loss: 5.7169, loss_task: 2.4385, loss_kd: 0.2186, auc_id_cosine: 0.9694, auc_id_euclidean: 0.9694
# --> SAVE BEST MODEL (auc_id_cosine: 0.9694)
# 	Saved best model weights for 'auc_id_cosine' at epoch 58 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_58.pth'
#
# --- Epoch 59/100 ---
#
# Ep 59:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.6038 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.3476 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2171 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9998 │ 0.9683 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9998 │ 0.9683 │
# ╘══════════════════╧═════════╧════════╛
# Ep 59: loss: 5.6038, loss_task: 2.3476, loss_kd: 0.2171, auc_id_cosine: 0.9683, auc_id_euclidean: 0.9683
# 	Epoch 59: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 60/100 ---
#
# Ep 60:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.7135 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4276 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2191 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9683 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9683 │
# ╘══════════════════╧═════════╧════════╛
# Ep 60: loss: 5.7135, loss_task: 2.4276, loss_kd: 0.2191, auc_id_cosine: 0.9683, auc_id_euclidean: 0.9683
# 	Epoch 60: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 61/100 ---
#
# Ep 61:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.7192 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4589 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2174 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9679 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9679 │
# ╘══════════════════╧═════════╧════════╛
# Ep 61: loss: 5.7192, loss_task: 2.4589, loss_kd: 0.2174, auc_id_cosine: 0.9679, auc_id_euclidean: 0.9679
# 	Epoch 61: EarlyStopping counter for 'auc_id_cosine': 3/10
#
# --- Epoch 62/100 ---
#
# Ep 62:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.8042 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4598 │ -      │
# ...
# │ loss_task        │  1.8381 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1536 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9998 │ 0.9674 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9998 │ 0.9674 │
# ╘══════════════════╧═════════╧════════╛
# Ep 79: loss: 4.1425, loss_task: 1.8381, loss_kd: 0.1536, auc_id_cosine: 0.9674, auc_id_euclidean: 0.9674
# 	Epoch 79: EarlyStopping counter for 'auc_id_cosine': 5/10
#
# --- Epoch 80/100 ---
#
# Ep 80:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.1089 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.8226 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1524 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9674 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9674 │
# ╘══════════════════╧═════════╧════════╛
# Ep 80: loss: 4.1089, loss_task: 1.8226, loss_kd: 0.1524, auc_id_cosine: 0.9674, auc_id_euclidean: 0.9674
# 	Epoch 80: EarlyStopping counter for 'auc_id_cosine': 6/10
#
# --- Epoch 81/100 ---
#
# Ep 81:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.0379 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.8018 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1491 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9678 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9678 │
# ╘══════════════════╧═════════╧════════╛
# Ep 81: loss: 4.0379, loss_task: 1.8018, loss_kd: 0.1491, auc_id_cosine: 0.9678, auc_id_euclidean: 0.9678
# 	Epoch 81: EarlyStopping counter for 'auc_id_cosine': 7/10
#
# --- Epoch 82/100 ---
#
# Ep 82:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.9674 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.763  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.147  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9702 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9702 │
# ╘══════════════════╧═════════╧════════╛
# Ep 82: loss: 3.9674, loss_task: 1.7630, loss_kd: 0.1470, auc_id_cosine: 0.9702, auc_id_euclidean: 0.9702
# --> SAVE BEST MODEL (auc_id_cosine: 0.9702)
# 	Saved best model weights for 'auc_id_cosine' at epoch 82 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_82.pth'
#
# --- Epoch 83/100 ---
#
# Ep 83:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.9536 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.7472 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1471 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9693 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9693 │
# ╘══════════════════╧═════════╧════════╛
# Ep 83: loss: 3.9536, loss_task: 1.7472, loss_kd: 0.1471, auc_id_cosine: 0.9693, auc_id_euclidean: 0.9693
# 	Epoch 83: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 84/100 ---
#
# Ep 84:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.9822 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.7624 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.148  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9687 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9687 │
# ╘══════════════════╧═════════╧════════╛
# Ep 84: loss: 3.9822, loss_task: 1.7624, loss_kd: 0.1480, auc_id_cosine: 0.9687, auc_id_euclidean: 0.9687
# 	Epoch 84: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 85/100 ---
#
# Ep 85:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.9176 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.7593 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1439 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9679 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9679 │
# ╘══════════════════╧═════════╧════════╛
# Ep 85: loss: 3.9176, loss_task: 1.7593, loss_kd: 0.1439, auc_id_cosine: 0.9679, auc_id_euclidean: 0.9679
# 	Epoch 85: EarlyStopping counter for 'auc_id_cosine': 3/10
#
# --- Epoch 86/100 ---
#
# Ep 86:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.8563 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.7207 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1424 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9692 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9692 │
# ╘══════════════════╧═════════╧════════╛
# Ep 86: loss: 3.8563, loss_task: 1.7207, loss_kd: 0.1424, auc_id_cosine: 0.9692, auc_id_euclidean: 0.9692
# 	Epoch 86: EarlyStopping counter for 'auc_id_cosine': 4/10
#
# --- Epoch 87/100 ---
#
# Ep 87:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.7976 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.6812 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1411 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9700 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9700 │
# ╘══════════════════╧═════════╧════════╛
# Ep 87: loss: 3.7976, loss_task: 1.6812, loss_kd: 0.1411, auc_id_cosine: 0.9700, auc_id_euclidean: 0.9700
# 	Epoch 87: EarlyStopping counter for 'auc_id_cosine': 5/10
#
# --- Epoch 88/100 ---
#
# Ep 88:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.761  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.6796 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1388 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9694 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9694 │
# ╘══════════════════╧═════════╧════════╛
# Ep 88: loss: 3.7610, loss_task: 1.6796, loss_kd: 0.1388, auc_id_cosine: 0.9694, auc_id_euclidean: 0.9694
# 	Epoch 88: EarlyStopping counter for 'auc_id_cosine': 6/10
#
# --- Epoch 89/100 ---
#
# Ep 89:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.648  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.6251 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1349 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9699 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9699 │
# ╘══════════════════╧═════════╧════════╛
# Ep 89: loss: 3.6480, loss_task: 1.6251, loss_kd: 0.1349, auc_id_cosine: 0.9699, auc_id_euclidean: 0.9699
# 	Epoch 89: EarlyStopping counter for 'auc_id_cosine': 7/10
#
# --- Epoch 90/100 ---
#
# Ep 90:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.5845 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.5909 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1329 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9709 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9709 │
# ╘══════════════════╧═════════╧════════╛
# Ep 90: loss: 3.5845, loss_task: 1.5909, loss_kd: 0.1329, auc_id_cosine: 0.9709, auc_id_euclidean: 0.9709
# --> SAVE BEST MODEL (auc_id_cosine: 0.9709)
# 	Saved best model weights for 'auc_id_cosine' at epoch 90 to '/content/drive/MyDrive/experiments/(hardswish-weight1-15)KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_auc_id_cosine_90.pth'
#
# --- Epoch 91/100 ---
#
# Ep 91:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.6741 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.6513 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1349 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9998 │ 0.9693 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9998 │ 0.9693 │
# ╘══════════════════╧═════════╧════════╛
# Ep 91: loss: 3.6741, loss_task: 1.6513, loss_kd: 0.1349, auc_id_cosine: 0.9693, auc_id_euclidean: 0.9693
# 	Epoch 91: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 92/100 ---
#
# Ep 92:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.5259 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.5595 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1311 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9688 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9688 │
# ╘══════════════════╧═════════╧════════╛
# Ep 92: loss: 3.5259, loss_task: 1.5595, loss_kd: 0.1311, auc_id_cosine: 0.9688, auc_id_euclidean: 0.9688
# 	Epoch 92: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 93/100 ---
#
# Ep 93:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.5882 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.6179 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1314 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9675 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9675 │
# ╘══════════════════╧═════════╧════════╛
# Ep 93: loss: 3.5882, loss_task: 1.6179, loss_kd: 0.1314, auc_id_cosine: 0.9675, auc_id_euclidean: 0.9675
# 	Epoch 93: EarlyStopping counter for 'auc_id_cosine': 3/10
#
# --- Epoch 94/100 ---
#
# Ep 94:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.5254 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.5648 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1307 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9686 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9686 │
# ╘══════════════════╧═════════╧════════╛
# Ep 94: loss: 3.5254, loss_task: 1.5648, loss_kd: 0.1307, auc_id_cosine: 0.9686, auc_id_euclidean: 0.9686
# 	Epoch 94: EarlyStopping counter for 'auc_id_cosine': 4/10
#
# --- Epoch 95/100 ---
#
# Ep 95:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.4747 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.5498 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1283 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9668 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9668 │
# ╘══════════════════╧═════════╧════════╛
# Ep 95: loss: 3.4747, loss_task: 1.5498, loss_kd: 0.1283, auc_id_cosine: 0.9668, auc_id_euclidean: 0.9668
# 	Epoch 95: EarlyStopping counter for 'auc_id_cosine': 5/10
#
# --- Epoch 96/100 ---
#
# Ep 96:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.4363 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.5301 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1271 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9687 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9687 │
# ╘══════════════════╧═════════╧════════╛
# Ep 96: loss: 3.4363, loss_task: 1.5301, loss_kd: 0.1271, auc_id_cosine: 0.9687, auc_id_euclidean: 0.9687
# 	Epoch 96: EarlyStopping counter for 'auc_id_cosine': 6/10
#
# --- Epoch 97/100 ---
#
# Ep 97:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.5007 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.5606 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1293 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9674 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9674 │
# ╘══════════════════╧═════════╧════════╛
# Ep 97: loss: 3.5007, loss_task: 1.5606, loss_kd: 0.1293, auc_id_cosine: 0.9674, auc_id_euclidean: 0.9674
# 	Epoch 97: EarlyStopping counter for 'auc_id_cosine': 7/10
#
# --- Epoch 98/100 ---
#
# Ep 98:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.4662 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.5596 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1271 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9679 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9679 │
# ╘══════════════════╧═════════╧════════╛
# Ep 98: loss: 3.4662, loss_task: 1.5596, loss_kd: 0.1271, auc_id_cosine: 0.9679, auc_id_euclidean: 0.9679
# 	Epoch 98: EarlyStopping counter for 'auc_id_cosine': 8/10
#
# --- Epoch 99/100 ---
#
# Ep 99:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.3751 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.5105 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1243 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9677 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9677 │
# ╘══════════════════╧═════════╧════════╛
# Ep 99: loss: 3.3751, loss_task: 1.5105, loss_kd: 0.1243, auc_id_cosine: 0.9677, auc_id_euclidean: 0.9677
# 	Epoch 99: EarlyStopping counter for 'auc_id_cosine': 9/10
#
# --- Epoch 100/100 ---
#
# Ep 100:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.3479 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  1.4897 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.1239 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9675 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9675 │
# ╘══════════════════╧═════════╧════════╛
# Ep 100: loss: 3.3479, loss_task: 1.4897, loss_kd: 0.1239, auc_id_cosine: 0.9675, auc_id_euclidean: 0.9675
# 	Epoch 100: EarlyStopping counter for 'auc_id_cosine': 10/10
# 	Early stopping triggered at epoch 100 as all metrics exceeded patience.
# Early stopping triggered.
# KNOWLEDGE DISTILLATION HOAN TAT.

# %% [markdown]
# ## 8. Resume Training từ Checkpoint
#
# > Chạy cell này khi Colab disconnect và muốn tiếp tục train.
# > Checkpoint đã được ghi thẳng vào Drive nên không bị mất.
# >
# > **Cách dùng:** Chạy cell Setup → Imports → Data → Teacher → Student → Loss → Setup Train,
# > sau đó chạy cell này (không chạy cell fit ở trên), rồi chạy lại cell fit.

# %%
CKPT_PATH = os.path.join(manager.ckpt_dir, 'last_model.pth')

if not os.path.exists(CKPT_PATH):
    raise FileNotFoundError(f'Không tìm thấy checkpoint: {CKPT_PATH}')

checkpoint = torch.load(CKPT_PATH, map_location=device, weights_only=False)


student.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
if 'scheduler_state_dict' in checkpoint:
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
if 'projector_state_dict' in checkpoint:
    projector.load_state_dict(checkpoint['projector_state_dict'])
    print('Projector state loaded.')
else:
    print('Không tìm thấy projector_state_dict — projector khởi tạo ngẫu nhiên.')

START_EPOCH = checkpoint['epoch']
print(f'Resume từ epoch {START_EPOCH} — chạy lại cell "cell-fit" để tiếp tục.')
# Out:
# Projector state loaded.
# Resume từ epoch 40 — chạy lại cell "cell-fit" để tiếp tục.

# %% [markdown]
# ## 9. Đánh giá Final

# %%
best_ckpt_path = os.path.join(manager.ckpt_dir, 'best_model.pth')
best_ckpt = torch.load(best_ckpt_path, map_location=device, weights_only=False)
student.load_state_dict(best_ckpt['model_state_dict'])
student.eval()
# print(f"Best model từ epoch {best_ckpt.get('epoch', '?')}")

student_gp_auc   = compute_id_auc_gallery_probe(gallery_dl, probe_dl, student, device)
student_gp_rank1 = compute_rank1_gallery_probe(gallery_dl, probe_dl, student, device)

rows = [
    ['Cosine AUC    (gallery→probe)', f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)', f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)', f"{student_gp_rank1:.4f}"],
]
print(f"\nStudent ({CONFIGURATION['backbone']}) — KD from {CONFIGURATION['teacher_backbone']}")
print(tabulate(rows, headers=['Metric', 'Value'], tablefmt='fancy_grid'))

# So sánh Teacher vs Student
compare_rows = [
    ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
    ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
    ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
]
print('\n--- Teacher vs Student (KD) ---')
print(tabulate(compare_rows, headers=['Metric', 'Teacher', 'Student (KD)'], tablefmt='fancy_grid'))
# Out:
# Student (mobilenetv3_large_100) — KD from convnextv2_tiny
# ╒═══════════════════════════════╤═════════╕
# │ Metric                        │   Value │
# ╞═══════════════════════════════╪═════════╡
# │ Cosine AUC    (gallery→probe) │  0.9726 │
# ├───────────────────────────────┼─────────┤
# │ Euclidean AUC (gallery→probe) │  0.9726 │
# ├───────────────────────────────┼─────────┤
# │ Rank-1 Acc    (gallery→probe) │  0.7604 │
# ╘═══════════════════════════════╧═════════╛
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1092/1905580024.py in <cell line: 0>()
#      20     ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
#      21     ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
# ---> 22     ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
#      23     ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
#      24     ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
#
# NameError: name 'teacher_gp_auc' is not defined

# %% [markdown]
# ## 10. Export ONNX
#
# Export phần inference (backbone + embedding + L2 normalize, bỏ MagLinear)
# để chuẩn bị quantize INT8 deploy edge device.

# %%
class InferenceWrapper(nn.Module):
    """Backbone + embedding + L2 normalize — không có MagLinear."""
    def __init__(self, model):
        super().__init__()
        self.backbone  = model.backbone
        self.embedding = model.embedding

    def forward(self, x):
        emb = self.embedding(self.backbone(x))
        return F.normalize(emb, p=2, dim=1)


inference_model = InferenceWrapper(student).eval().cpu()
dummy_input = torch.randn(1, 3, 112, 112)

# Lưu vào Drive để không mất
onnx_path = os.path.join(manager.ckpt_dir, 'kd_mobilenetv3_fr.onnx')

torch.onnx.export(
    inference_model,
    dummy_input,
    onnx_path,
    input_names=['input'],
    output_names=['embedding'],
    dynamic_axes={'input': {0: 'batch'}, 'embedding': {0: 'batch'}},
    opset_version=17,
)
print(f'Exported ONNX: {onnx_path}')

# %%
best_ckpt_path = os.path.join(manager.ckpt_dir, 'best_model.pth')
best_ckpt = torch.load(best_ckpt_path, map_location=device, weights_only=False)
student.load_state_dict(best_ckpt['model_state_dict'])
student.eval()
print(f"Best model từ epoch {best_ckpt.get('epoch', '?')}")

student_gp_auc   = compute_id_auc_gallery_probe(gallery_dl, probe_dl, student, device)
student_gp_rank1 = compute_rank1_gallery_probe(gallery_dl, probe_dl, student, device)

rows = [
    ['Cosine AUC    (gallery→probe)', f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)', f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)', f"{student_gp_rank1:.4f}"],
]
print(f"\nStudent ({CONFIGURATION['backbone']}) — KD from {CONFIGURATION['teacher_backbone']}")
print(tabulate(rows, headers=['Metric', 'Value'], tablefmt='fancy_grid'))

# So sánh Teacher vs Student
compare_rows = [
    ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
    ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
    ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
]
print('\n--- Teacher vs Student (KD) ---')
print(tabulate(compare_rows, headers=['Metric', 'Teacher', 'Student (KD)'], tablefmt='fancy_grid'))
# Out:
# Best model từ epoch 90
#
# Student (mobilenetv3_large_100) — KD from convnextv2_tiny
# ╒═══════════════════════════════╤═════════╕
# │ Metric                        │   Value │
# ╞═══════════════════════════════╪═════════╡
# │ Cosine AUC    (gallery→probe) │  0.9715 │
# ├───────────────────────────────┼─────────┤
# │ Euclidean AUC (gallery→probe) │  0.9715 │
# ├───────────────────────────────┼─────────┤
# │ Rank-1 Acc    (gallery→probe) │  0.7535 │
# ╘═══════════════════════════════╧═════════╛
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1092/3485715062.py in <cell line: 0>()
#      20     ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
#      21     ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
# ---> 22     ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
#      23     ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
#      24     ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
#
# NameError: name 'teacher_gp_auc' is not defined
