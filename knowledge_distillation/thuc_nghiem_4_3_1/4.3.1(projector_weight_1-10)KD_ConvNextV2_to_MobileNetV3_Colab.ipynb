# %% [markdown]
# # Knowledge Distillation: ConvNeXt V2 → MobileNetV3 (Colab)
#
# **Mục tiêu:** Dùng ID embedding 512-D của teacher ConvNeXt V2 (đã train MTL) để hướng dẫn student MobileNetV3 học compact embedding cho face recognition.
#
# | | Teacher | Student |
# |---|---|---|
# | Model | `MTLFaceRecognition` (ConvNeXt V2) | `FaceRecognitionMobileNetV3` |
# | Params | ~28M | ~5M |
# | Embedding dùng cho KD | `x_id` (512-D, tầng cuối) | 512-D |
# | Mode | **Frozen** | **Trainable** |
#
# **KD Loss:**
# ```
# L_total = α · L_MagFace(student)  +  β · L_KD
# L_KD    = mean(1 - cosine_sim(norm(s_emb), norm(t_emb)))
# ```
#
# **Cách dùng:**
# 1. Mount Google Drive (cell 1)
# 2. Sửa `CONFIGURATION` và `TEACHER_CKPT` (cell Config)
# 3. Chạy từ trên xuống

# %% [markdown]
# ## 1. Mount Drive & Setup môi trường

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

REPO_URL    = 'https://github.com/NguyenXuanBinh22/DATN.git'
REPO_BRANCH = 'convnext-v2-dev'
REPO_DIR    = '/content/FR_Photometric_Stereo'

if not os.path.exists(REPO_DIR):
    os.system(f'git clone -b {REPO_BRANCH} {REPO_URL} {REPO_DIR}')
else:
    os.system(f'git -C {REPO_DIR} pull origin {REPO_BRANCH}')
    print('Repo đã tồn tại, đã pull latest.')

# %cd {REPO_DIR}
print(f'Working dir: {os.getcwd()}')

os.system('pip install -q albumentations==1.3.1 timm tabulate termcolor')
# Out:
# Mounted at /content/drive
# /content/FR_Photometric_Stereo
# Working dir: /content/FR_Photometric_Stereo
# 0

# %% [markdown]
# ## 2. Imports & Cấu hình

# %%
# %cd /content/FR_Photometric_Stereo
import warnings
warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import albumentations as A
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
from torch.utils.tensorboard import SummaryWriter
from tabulate import tabulate

from going_modular.dataloader.multitask import create_multitask_datafetcher, create_eval_loaders
from going_modular.model.MTLFaceRecognition import MTLFaceRecognition
from going_modular.model.FaceRecognitionMobileNetV3 import FaceRecognitionMobileNetV3
from going_modular.loss.WeightClassMagLoss import WeightClassMagLoss
from going_modular.utils.transforms import RandomResizedCropRect, GaussianNoise
from going_modular.utils.roc_auc_id import (
    compute_id_auc, compute_rank1,
    compute_id_auc_gallery_probe, compute_rank1_gallery_probe,
)
from going_modular.utils.MultiMetricEarlyStopping import MultiMetricEarlyStopping
from going_modular.utils.ModelCheckPoint import ModelCheckpoint
from going_modular.utils.ExperimentManager import ExperimentManager

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(42)
print(f'Device: {device}')
if device == 'cuda':
    print(f'GPU: {torch.cuda.get_device_name(0)}')
# Out:
# /content/FR_Photometric_Stereo
# Device: cuda
# GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition

# %%
# ════════════════════════════════════════════════════════════
#  CẤU HÌNH — chỉnh sửa ở đây
# ════════════════════════════════════════════════════════════

# Đường dẫn dataset trên Google Drive
DRIVE_DATASET_DIR = '/content/drive/MyDrive/Photometric_DB_Full/'

# Checkpoint teacher ConvNeXt V2 đã train (best_model.pth hoặc last_model.pth)
# Ví dụ: '/content/drive/MyDrive/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth'
TEACHER_CKPT = '/content/drive/MyDrive/Photometric_DB_Full/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth'

EXPERIMENT_NAME = 'KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)'

CONFIGURATION = {
    'note':        EXPERIMENT_NAME,
    'dataset_dir': DRIVE_DATASET_DIR,

    # Ghi checkpoint và log vào Drive để không mất khi Colab disconnect
    'output_dir':  '/content/drive/MyDrive/',

    # Modality: 'albedo' | 'normalmap' | 'depthmap'
    # Phải giống modality mà teacher đã được train
    'type':        'albedo',

    # Teacher backbone (để tái tạo đúng kiến trúc khi load checkpoint)
    'teacher_backbone': 'convnextv2_tiny',

    # Student backbone
    'backbone':    'mobilenetv3_large_100',

    'use_sampler': True,   # PK Sampler — mỗi batch gồm batch_size identity khác nhau
    'device':      device,
    'epochs':      60,
    'batch_size':  32,
    'image_size':  112,
    'base_lr':     1e-4,
    'num_classes': None,   # tự động lấy từ CSV

    # Trọng số loss
    # L_total = task_weight * L_MagFace + kd_weight * L_KD
    'task_weight': 1.0,
    'kd_weight':   10.0,
}

print(f"Dataset dir : {CONFIGURATION['dataset_dir']}")
print(f"Output dir  : {CONFIGURATION['output_dir']}")
print(f"Teacher ckpt: {TEACHER_CKPT}")
# Out:
# Dataset dir : /content/drive/MyDrive/Photometric_DB_Full/
# Output dir  : /content/drive/MyDrive/
# Teacher ckpt: /content/drive/MyDrive/Photometric_DB_Full/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth

# %% [markdown]
# ## 3. Data Loading
#
# Dùng **cùng transform** với ConvNeXt V2 để student và teacher nhận cùng input trong mỗi batch.

# %%
dataset_dir = CONFIGURATION['dataset_dir']

# Tìm CSV — hỗ trợ cả hai cấu trúc thư mục
train_csv = os.path.join(dataset_dir, 'train_split.csv')
if not os.path.exists(train_csv):
    train_csv = os.path.join(dataset_dir, 'dataset', 'train_split.csv')
if not os.path.exists(train_csv):
    train_csv = os.path.join(dataset_dir, 'train_set.csv')
if not os.path.exists(train_csv):
    raise FileNotFoundError(
        f'Không tìm thấy CSV train tại {dataset_dir}.\n'
        f'Kiểm tra lại DRIVE_DATASET_DIR.'
    )
print(f'Train CSV: {train_csv}')

df_train = pd.read_csv(train_csv)
CONFIGURATION['num_classes'] = int(df_train['id'].nunique())
print(f'num_classes : {CONFIGURATION["num_classes"]}')
print(f'Số mẫu train: {len(df_train)}')

# Transform — giống hệt ConvNeXt V2 pipeline
train_transform = A.Compose([
    RandomResizedCropRect(CONFIGURATION['image_size']),
    GaussianNoise(p=0.2),
    A.HorizontalFlip(p=0.5),
])
test_transform = A.Compose([
    A.Resize(CONFIGURATION['image_size'], CONFIGURATION['image_size']),
])

# Training dataloader — probe_split.csv dùng để monitor AUC trong vòng lặp train
train_dl, test_dl, _ = create_multitask_datafetcher(
    CONFIGURATION, train_transform, test_transform, 'train_split.csv', 'probe_split.csv'
)
print(f'Train batches: {len(train_dl)} | Test batches (probe): {len(test_dl)}')

# Gallery-probe loaders — CHỈ dùng cho đánh giá cuối, không dùng trong training
# gallery_split.csv: reference set | probe_split.csv: query set
gallery_dl, probe_dl = create_eval_loaders(CONFIGURATION, test_transform)
# Out:
# Train CSV: /content/drive/MyDrive/Photometric_DB_Full/train_split.csv
# num_classes : 352
# Số mẫu train: 2622
# >>> SingleLoader: MODE = PK SAMPLER
# Train batches: 81 | Test batches (probe): 9
# Gallery: 68 ảnh | Probe: 288 ảnh
# Shared identity space: 68 identities

# %% [markdown]
# ## 4. Teacher Model (ConvNeXt V2 — Frozen)
#
# Load checkpoint đã train, freeze toàn bộ weights.
# Chỉ dùng `get_embedding(x)[-1]` để lấy **ID embedding** (`x_id`, tầng embedding cuối).

# %%
if not os.path.exists(TEACHER_CKPT):
    raise FileNotFoundError(
        f'Không tìm thấy teacher checkpoint: {TEACHER_CKPT}\n'
        f'Kiểm tra lại biến TEACHER_CKPT.'
    )

# Khởi tạo teacher với đúng kiến trúc
teacher = MTLFaceRecognition(
    backbone=CONFIGURATION['teacher_backbone'],
    num_classes=CONFIGURATION['num_classes'],
)

# Load weights
ckpt = torch.load(TEACHER_CKPT, map_location=device, weights_only=False)
state_dict = ckpt['model_state_dict']

# Remove keys related to the id_head.maglinear layer to avoid size mismatch errors
# This layer is not needed as the teacher is used for feature extraction only
keys_to_remove = [k for k in state_dict.keys() if 'id_head.maglinear' in k]
for k in keys_to_remove:
    del state_dict[k]

teacher.load_state_dict(ckpt['model_state_dict'], strict=False)  # strict=False để bỏ qua nếu có layers mới (như classifier)
print(f"Teacher loaded — epoch {ckpt.get('epoch', '?')}")

# Freeze hoàn toàn
teacher.to(device)
teacher.eval()
for p in teacher.parameters():
    p.requires_grad = False

teacher_params = sum(p.numel() for p in teacher.parameters())
print(f'Teacher params: {teacher_params:,} (tất cả frozen)')

# Smoke test — kiểm tra embedding shape
with torch.no_grad():
    _dummy = torch.randn(2, 3, 112, 112).to(device)
    # get_embedding() trả về (x_spec, x_fh, x_pose, x_emot, x_gender, x_id)
    _t_emb = teacher.get_embedding(_dummy)[-1]   # x_id
    print(f'Teacher ID embedding shape: {_t_emb.shape}')   # mong đợi [2, 512]
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# Teacher loaded — epoch 28
# Teacher params: 45,670,280 (tất cả frozen)
# Teacher ID embedding shape: torch.Size([2, 512])

# %% [markdown]
# ## 4.1. Đánh giá Teacher Model (baseline)
#
# Đo AUC của teacher trên train/test set **trước khi distillation** để có baseline so sánh với student sau này.

# %%
class _TeacherEvalWrapper(torch.nn.Module):
    """MTLFaceRecognition.get_embedding() trả về tuple — wrapper giữ lại x_id (index -1)."""
    def __init__(self, teacher):
        super().__init__()
        self._teacher = teacher

    def get_embedding(self, x):
        return self._teacher.get_embedding(x)[-1]   # x_id: [B, 512]


teacher_wrapper = _TeacherEvalWrapper(teacher).to(device)
teacher_wrapper.eval()

teacher_gp_auc   = compute_id_auc_gallery_probe(gallery_dl, probe_dl, teacher_wrapper, device)
teacher_gp_rank1 = compute_rank1_gallery_probe(gallery_dl, probe_dl, teacher_wrapper, device)

rows = [
    ['Cosine AUC    (gallery→probe)', f"{teacher_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)', f"{teacher_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)', f"{teacher_gp_rank1:.4f}"],
]
print(f"Teacher ({CONFIGURATION['teacher_backbone']}) — weight: {TEACHER_CKPT}")
print(tabulate(rows, headers=['Metric', 'Value'], tablefmt='fancy_grid'))
# Out:
# Teacher (convnextv2_tiny) — weight: /content/drive/MyDrive/Photometric_DB_Full/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth
# ╒═══════════════════════════════╤═════════╕
# │ Metric                        │   Value │
# ╞═══════════════════════════════╪═════════╡
# │ Cosine AUC    (gallery→probe) │  0.9761 │
# ├───────────────────────────────┼─────────┤
# │ Euclidean AUC (gallery→probe) │  0.9761 │
# ├───────────────────────────────┼─────────┤
# │ Rank-1 Acc    (gallery→probe) │  0.8021 │
# ╘═══════════════════════════════╧═════════╛

# %% [markdown]
# ## 5. Student Model (MobileNetV3 — Trainable)

# %%
student = FaceRecognitionMobileNetV3(
    num_classes=CONFIGURATION['num_classes'],
    backbone=CONFIGURATION['backbone'],
)
student.to(device)

total_p     = sum(p.numel() for p in student.parameters())
trainable_p = sum(p.numel() for p in student.parameters() if p.requires_grad)
print(f'Student total params    : {total_p:,}')
print(f'Student trainable params: {trainable_p:,}')

# Smoke test
with torch.no_grad():
    _s_emb = student.get_embedding(_dummy)
    print(f'Student embedding shape: {_s_emb.shape}')   # mong đợi [2, 512]
# Out:
# model.safetensors:   0%|          | 0.00/22.1M [00:00<?, ?B/s]
# WARNING:timm.models._builder:Unexpected keys (classifier.bias, classifier.weight, conv_head.bias, conv_head.weight) found while loading pretrained weights. This may be expected if model is being adapted.
# Student total params    : 3,646,256
# Student trainable params: 3,646,256
# Student embedding shape: torch.Size([2, 512])

# %% [markdown]
# ## 6. Knowledge Distillation Loss
#
# ```
# L_total = α · L_MagFace  +  β · L_KD
#
# L_MagFace : WeightClassMagFace — phân biệt class boundaries cho student
# L_KD      : Cosine distance giữa student emb và teacher ID emb
#            = mean(1 - cos_sim(norm(s_emb), norm(t_emb)))
# ```
#
# **Tại sao cosine loss:**
# Face verification so sánh *hướng* của embedding (cosine sim), không phải magnitude.
# Cosine loss kéo student về đúng hướng mà không ràng buộc magnitude.

# %%
class KDLoss(nn.Module):
    """
    L_total = task_weight * L_MagFace  +  kd_weight * L_KD_cosine
    """

    def __init__(self, metadata_path: str, task_weight: float = 1.0, kd_weight: float = 1.0):
        super().__init__()
        self.magface = WeightClassMagLoss(metadata_path)
        self.task_w  = task_weight
        self.kd_w    = kd_weight

    def forward(
        self,
        student_logits,   # [cos_theta, cos_theta_m] từ MagLinear
        student_norm,     # x_norm từ MagLinear
        student_emb,      # [B, 512] — embedding trước MagLinear
        teacher_emb,      # [B, 512] — ID embedding của teacher (no_grad)
        id_labels,        # [B] — ground-truth identity
    ):
        # Task loss
        l_task = self.magface(student_logits, id_labels, student_norm)

        # KD loss — cosine distance trên unit hypersphere
        s_n = F.normalize(student_emb, p=2, dim=1)
        t_n = F.normalize(teacher_emb, p=2, dim=1)
        l_kd = (1.0 - F.cosine_similarity(s_n, t_n, dim=1)).mean()

        total = self.task_w * l_task + self.kd_w * l_kd
        return total, l_task, l_kd


criterion = KDLoss(
    metadata_path=train_csv,
    task_weight=CONFIGURATION['task_weight'],
    kd_weight=CONFIGURATION['kd_weight'],
)
print('KDLoss khởi tạo thành công.')
# Out:
# KDLoss khởi tạo thành công.

# %% [markdown]
# ## 6.1. Projection Head
#
# Student và teacher sống trong hai embedding space khác nhau — ép chúng chia sẻ cùng một space là quá cứng nhắc và thường dẫn đến `loss_kd` cao.
#
# Giải pháp: thêm một MLP nhỏ (**ProjectionHead**) giúp bridge hai space lại.
#
# ```
# student_emb (512-D)  →  projector  →  proj_emb (512-D)  ←→  teacher_emb
# ```
#
# - `student_emb` vẫn đi thẳng vào `MagLinear` (task loss không thay đổi)
# - Chỉ `proj_emb` được dùng cho KD loss
# - Projector **chỉ tồn tại khi train**, bỏ hoàn toàn khi export ONNX

# %%
class ProjectionHead(nn.Module):
    """
    MLP bridge: student embedding space → teacher embedding space.
    Chỉ dùng khi tính KD loss, không tham gia inference / ONNX export.

    Luồng:
        student_emb  →  Linear(512→512) → BN → ReLU → Linear(512→512)
                     →  proj_emb  ←→  teacher_emb  (cosine KD loss)
    """
    def __init__(self, in_dim: int = 512, hidden_dim: int = 512, out_dim: int = 512):
        super().__init__()
        self.proj = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Linear(hidden_dim, out_dim),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.proj(x)


projector = ProjectionHead(in_dim=512, hidden_dim=512, out_dim=512).to(device)
proj_params = sum(p.numel() for p in projector.parameters())
print(f'ProjectionHead params: {proj_params:,}  (train-only, dropped at export)')
# Out:
# ProjectionHead params: 526,336  (train-only, dropped at export)

# %% [markdown]
# ## 7. Training

# %%
def train_epoch(train_dl, teacher, student, projector, criterion, optimizer, device):
    student.train()
    projector.train()
    # teacher.eval() + frozen — không cần đặt lại mỗi epoch

    total_loss = total_task = total_kd = 0.0

    for X, y in train_dl:
        X, y = X.to(device), y.to(device)
        id_labels = y[:, 0]   # chỉ cần identity label

        # Teacher forward — no gradient, không update weights
        with torch.no_grad():
            # get_embedding() → (x_spec, x_fh, x_pose, x_emot, x_gender, x_id)
            teacher_emb = teacher.get_embedding(X)[-1]   # x_id: [B, 512]

        # Student forward — một lần duy nhất để lấy cả embedding lẫn logits
        feat         = student.backbone(X)          # [B, 512, H, W]
        student_emb  = student.embedding(feat)      # [B, 512]
        proj_emb     = projector(student_emb)       # [B, 512] — bridge to teacher space
        logits, norm = student.maglinear(student_emb)

        # Loss tổng hợp
        # task loss dùng student_emb gốc (không qua projector)
        # KD loss dùng proj_emb để không ràng buộc student_emb phải giống teacher
        loss, l_task, l_kd = criterion(
            logits, norm, proj_emb, teacher_emb, id_labels
        )

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        total_task += l_task.item()
        total_kd   += l_kd.item()

    n = len(train_dl)
    return total_loss / n, total_task / n, total_kd / n


def display_metrics(epoch, train_metrics, test_metrics):
    rows = []
    for k in train_metrics:
        tv = train_metrics[k]
        ev = test_metrics.get(k, '-')
        fmt = lambda v: f'{v:.4f}' if isinstance(v, float) else str(v)
        rows.append([k, fmt(tv), fmt(ev)])
    print(f'\nEp {epoch}:')
    print(tabulate(rows, headers=['Metric', 'Train', 'Test'], tablefmt='fancy_grid'))

# %%
optimizer = Adam(
    list(student.parameters()) + list(projector.parameters()),
    lr=CONFIGURATION['base_lr'],
)
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=20, T_mult=2, eta_min=1e-6)

manager = ExperimentManager(CONFIGURATION)
manager.log_text(
    f"Teacher: {CONFIGURATION['teacher_backbone']} | "
    f"Student: {CONFIGURATION['backbone']} | "
    f"Modality: {CONFIGURATION['type']} | "
    f"kd_weight={CONFIGURATION['kd_weight']} task_weight={CONFIGURATION['task_weight']} | "
    f"projector=True"
)

ckpt_saver = ModelCheckpoint(
    output_dir=manager.ckpt_dir,
    mode='max',
    best_metric_name='auc_id_cosine',
)
early_stopping = MultiMetricEarlyStopping(
    monitor_keys=['auc_id_cosine'],
    patience=10,
    mode='max',
    verbose=1,
    save_dir=manager.ckpt_dir,
    start_from_epoch=5,
)

writer = SummaryWriter(log_dir=manager.log_dir)
print(f'Experiment dir: {manager.exp_dir}')
print(f'Checkpoint dir: {manager.ckpt_dir}')
print('(Tất cả được ghi thẳng vào Google Drive)')
# Out:
# KHOI TAO THI NGHIEM: KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-15)
# Luu tru tai: /content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-15)
# Thoi gian: 2026-05-30 14:12:40
# --------------------------------------------------
# Teacher: convnextv2_tiny | Student: mobilenetv3_large_100 | Modality: albedo | kd_weight=10.0 task_weight=1.0 | projector=True
# Experiment dir: /content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-15)
# Checkpoint dir: /content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-15)/checkpoints
# (Tất cả được ghi thẳng vào Google Drive)

# %%
START_EPOCH = 0

manager.log_text('BAT DAU KNOWLEDGE DISTILLATION (với ProjectionHead)')

for epoch in range(START_EPOCH, CONFIGURATION['epochs']):
    manager.log_text(f'\n--- Epoch {epoch+1}/{CONFIGURATION["epochs"]} ---')

    # Train
    train_loss, train_task, train_kd = train_epoch(
        train_dl, teacher, student, projector, criterion, optimizer, device
    )

    # AUC — dùng student.get_embedding() trực tiếp (không qua projector)
    train_auc = compute_id_auc(train_dl, student, device)
    test_auc  = compute_id_auc(test_dl,  student, device)

    train_metrics = {
        'loss':             train_loss,
        'loss_task':        train_task,
        'loss_kd':          train_kd,
        'auc_id_cosine':    train_auc['id_cosine'],
        'auc_id_euclidean': train_auc['id_euclidean'],
    }
    test_metrics = {
        'auc_id_cosine':    test_auc['id_cosine'],
        'auc_id_euclidean': test_auc['id_euclidean'],
    }

    # TensorBoard
    writer.add_scalar('Loss/total', train_loss, epoch + 1)
    writer.add_scalar('Loss/task',  train_task, epoch + 1)
    writer.add_scalar('Loss/kd',    train_kd,   epoch + 1)
    writer.add_scalars('AUC/cosine',
        {'train': train_auc['id_cosine'],    'test': test_auc['id_cosine']},    epoch + 1)
    writer.add_scalars('AUC/euclidean',
        {'train': train_auc['id_euclidean'], 'test': test_auc['id_euclidean']}, epoch + 1)

    # Console + file log
    display_metrics(epoch + 1, train_metrics, test_metrics)
    manager.log_metrics(epoch + 1, {**train_metrics, **test_metrics})

    # Checkpoint (lưu cả projector state để có thể resume)
    ckpt_saver(
        student, optimizer, epoch + 1, test_metrics, scheduler,
        extra_state={'projector_state_dict': projector.state_dict()},
    )
    early_stopping(test_metrics, student, epoch + 1)
    scheduler.step(epoch)

    if early_stopping.early_stop:
        manager.log_text('Early stopping triggered.')
        break

writer.close()
manager.log_text('KNOWLEDGE DISTILLATION HOAN TAT.')
# Out:
# BAT DAU KNOWLEDGE DISTILLATION (với ProjectionHead)
#
# --- Epoch 1/60 ---
#
# Ep 1:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 38.6799 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 29.2111 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9469 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9271 │ 0.8890 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9271 │ 0.8890 │
# ╘══════════════════╧═════════╧════════╛
# Ep 1: loss: 38.6799, loss_task: 29.2111, loss_kd: 0.9469, auc_id_cosine: 0.8890, auc_id_euclidean: 0.8890
# --> SAVE BEST MODEL (auc_id_cosine: 0.8890)
#
# --- Epoch 2/60 ---
#
# Ep 2:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 40.4601 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 31.5981 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.8862 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9354 │ 0.9071 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9354 │ 0.9071 │
# ╘══════════════════╧═════════╧════════╛
# Ep 2: loss: 40.4601, loss_task: 31.5981, loss_kd: 0.8862, auc_id_cosine: 0.9071, auc_id_euclidean: 0.9071
# --> SAVE BEST MODEL (auc_id_cosine: 0.9071)
#
# --- Epoch 3/60 ---
#
# Ep 3:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 38.1795 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 29.7882 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.8391 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9493 │ 0.9194 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9493 │ 0.9194 │
# ╘══════════════════╧═════════╧════════╛
# Ep 3: loss: 38.1795, loss_task: 29.7882, loss_kd: 0.8391, auc_id_cosine: 0.9194, auc_id_euclidean: 0.9194
# --> SAVE BEST MODEL (auc_id_cosine: 0.9194)
#
# --- Epoch 4/60 ---
#
# Ep 4:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 35.4665 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 27.5019 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.7965 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9639 │ 0.9274 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9639 │ 0.9274 │
# ╘══════════════════╧═════════╧════════╛
# Ep 4: loss: 35.4665, loss_task: 27.5019, loss_kd: 0.7965, auc_id_cosine: 0.9274, auc_id_euclidean: 0.9274
# --> SAVE BEST MODEL (auc_id_cosine: 0.9274)
#
# --- Epoch 5/60 ---
#
# Ep 5:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 32.4644 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 24.926  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.7538 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9645 │ 0.9284 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9645 │ 0.9284 │
# ╘══════════════════╧═════════╧════════╛
# Ep 5: loss: 32.4644, loss_task: 24.9260, loss_kd: 0.7538, auc_id_cosine: 0.9284, auc_id_euclidean: 0.9284
# --> SAVE BEST MODEL (auc_id_cosine: 0.9284)
# 	Saved best model weights for 'auc_id_cosine' at epoch 5 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_5.pth'
#
# --- Epoch 6/60 ---
#
# Ep 6:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 29.2804 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 22.091  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.7189 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.979  │ 0.9305 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.979  │ 0.9305 │
# ╘══════════════════╧═════════╧════════╛
# Ep 6: loss: 29.2804, loss_task: 22.0910, loss_kd: 0.7189, auc_id_cosine: 0.9305, auc_id_euclidean: 0.9305
# --> SAVE BEST MODEL (auc_id_cosine: 0.9305)
# 	Saved best model weights for 'auc_id_cosine' at epoch 6 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_6.pth'
#
# --- Epoch 7/60 ---
#
# Ep 7:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 27.0583 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 20.1069 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.6951 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9775 │ 0.9364 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9775 │ 0.9364 │
# ╘══════════════════╧═════════╧════════╛
# Ep 7: loss: 27.0583, loss_task: 20.1069, loss_kd: 0.6951, auc_id_cosine: 0.9364, auc_id_euclidean: 0.9364
# --> SAVE BEST MODEL (auc_id_cosine: 0.9364)
# 	Saved best model weights for 'auc_id_cosine' at epoch 7 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_7.pth'
#
# --- Epoch 8/60 ---
#
# Ep 8:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 24.0885 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 17.479  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.661  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9836 │ 0.9382 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9836 │ 0.9382 │
# ╘══════════════════╧═════════╧════════╛
# Ep 8: loss: 24.0885, loss_task: 17.4790, loss_kd: 0.6610, auc_id_cosine: 0.9382, auc_id_euclidean: 0.9382
# --> SAVE BEST MODEL (auc_id_cosine: 0.9382)
# 	Saved best model weights for 'auc_id_cosine' at epoch 8 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_8.pth'
#
# --- Epoch 9/60 ---
#
# Ep 9:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 22.2045 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 15.8188 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.6386 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.986  │ 0.9395 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.986  │ 0.9395 │
# ╘══════════════════╧═════════╧════════╛
# Ep 9: loss: 22.2045, loss_task: 15.8188, loss_kd: 0.6386, auc_id_cosine: 0.9395, auc_id_euclidean: 0.9395
# --> SAVE BEST MODEL (auc_id_cosine: 0.9395)
# 	Saved best model weights for 'auc_id_cosine' at epoch 9 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_9.pth'
#
# --- Epoch 10/60 ---
#
# Ep 10:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 20.2407 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 14.0855 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.6155 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9888 │ 0.9438 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9888 │ 0.9438 │
# ╘══════════════════╧═════════╧════════╛
# Ep 10: loss: 20.2407, loss_task: 14.0855, loss_kd: 0.6155, auc_id_cosine: 0.9438, auc_id_euclidean: 0.9438
# --> SAVE BEST MODEL (auc_id_cosine: 0.9438)
# 	Saved best model weights for 'auc_id_cosine' at epoch 10 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_10.pth'
#
# --- Epoch 11/60 ---
#
# Ep 11:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 18.466  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 12.5428 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5923 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9897 │ 0.9469 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9897 │ 0.9469 │
# ╘══════════════════╧═════════╧════════╛
# Ep 11: loss: 18.4660, loss_task: 12.5428, loss_kd: 0.5923, auc_id_cosine: 0.9469, auc_id_euclidean: 0.9469
# --> SAVE BEST MODEL (auc_id_cosine: 0.9469)
# 	Saved best model weights for 'auc_id_cosine' at epoch 11 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_11.pth'
#
# --- Epoch 12/60 ---
#
# Ep 12:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 17.5311 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 11.7363 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5795 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9907 │ 0.9470 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9907 │ 0.9470 │
# ╘══════════════════╧═════════╧════════╛
# Ep 12: loss: 17.5311, loss_task: 11.7363, loss_kd: 0.5795, auc_id_cosine: 0.9470, auc_id_euclidean: 0.9470
# --> SAVE BEST MODEL (auc_id_cosine: 0.9470)
# 	Saved best model weights for 'auc_id_cosine' at epoch 12 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_12.pth'
#
# --- Epoch 13/60 ---
#
# Ep 13:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 16.5311 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 10.8861 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5645 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9916 │ 0.9494 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9916 │ 0.9494 │
# ╘══════════════════╧═════════╧════════╛
# Ep 13: loss: 16.5311, loss_task: 10.8861, loss_kd: 0.5645, auc_id_cosine: 0.9494, auc_id_euclidean: 0.9494
# --> SAVE BEST MODEL (auc_id_cosine: 0.9494)
# 	Saved best model weights for 'auc_id_cosine' at epoch 13 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_13.pth'
#
# --- Epoch 14/60 ---
#
# Ep 14:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 15.5697 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 10.076  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5494 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9907 │ 0.9488 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9907 │ 0.9488 │
# ╘══════════════════╧═════════╧════════╛
# Ep 14: loss: 15.5697, loss_task: 10.0760, loss_kd: 0.5494, auc_id_cosine: 0.9488, auc_id_euclidean: 0.9488
# 	Epoch 14: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 15/60 ---
#
# Ep 15:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 15.2139 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.8114 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5402 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9917 │ 0.9499 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9917 │ 0.9499 │
# ╘══════════════════╧═════════╧════════╛
# Ep 15: loss: 15.2139, loss_task: 9.8114, loss_kd: 0.5402, auc_id_cosine: 0.9499, auc_id_euclidean: 0.9499
# --> SAVE BEST MODEL (auc_id_cosine: 0.9499)
# 	Saved best model weights for 'auc_id_cosine' at epoch 15 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_15.pth'
#
# --- Epoch 16/60 ---
#
# Ep 16:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 14.8581 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.5064 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5352 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9937 │ 0.9483 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9937 │ 0.9483 │
# ╘══════════════════╧═════════╧════════╛
# Ep 16: loss: 14.8581, loss_task: 9.5064, loss_kd: 0.5352, auc_id_cosine: 0.9483, auc_id_euclidean: 0.9483
# 	Epoch 16: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 17/60 ---
#
# Ep 17:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 14.4823 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.1761 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5306 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9924 │ 0.9500 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9924 │ 0.9500 │
# ╘══════════════════╧═════════╧════════╛
# Ep 17: loss: 14.4823, loss_task: 9.1761, loss_kd: 0.5306, auc_id_cosine: 0.9500, auc_id_euclidean: 0.9500
# --> SAVE BEST MODEL (auc_id_cosine: 0.9500)
# 	Saved best model weights for 'auc_id_cosine' at epoch 17 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_17.pth'
#
# --- Epoch 18/60 ---
#
# Ep 18:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 14.47   │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.1993 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5271 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9945 │ 0.9498 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9945 │ 0.9498 │
# ╘══════════════════╧═════════╧════════╛
# Ep 18: loss: 14.4700, loss_task: 9.1993, loss_kd: 0.5271, auc_id_cosine: 0.9498, auc_id_euclidean: 0.9498
# 	Epoch 18: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 19/60 ---
#
# Ep 19:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 14.3185 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.0858 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5233 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9925 │ 0.9518 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9925 │ 0.9518 │
# ╘══════════════════╧═════════╧════════╛
# Ep 19: loss: 14.3185, loss_task: 9.0858, loss_kd: 0.5233, auc_id_cosine: 0.9518, auc_id_euclidean: 0.9518
# --> SAVE BEST MODEL (auc_id_cosine: 0.9518)
# 	Saved best model weights for 'auc_id_cosine' at epoch 19 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_19.pth'
#
# --- Epoch 20/60 ---
#
# Ep 20:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 13.8209 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  8.6356 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5185 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9919 │ 0.9517 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9919 │ 0.9517 │
# ╘══════════════════╧═════════╧════════╛
# Ep 20: loss: 13.8209, loss_task: 8.6356, loss_kd: 0.5185, auc_id_cosine: 0.9517, auc_id_euclidean: 0.9517
# 	Epoch 20: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 21/60 ---
#
# Ep 21:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 14.0282 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  8.8099 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5218 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9929 │ 0.9502 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9929 │ 0.9502 │
# ╘══════════════════╧═════════╧════════╛
# Ep 21: loss: 14.0282, loss_task: 8.8099, loss_kd: 0.5218, auc_id_cosine: 0.9502, auc_id_euclidean: 0.9502
# 	Epoch 21: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 22/60 ---
#
# Ep 22:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 13.5291 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  8.4349 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5094 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9907 │ 0.9555 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9907 │ 0.9555 │
# ╘══════════════════╧═════════╧════════╛
# Ep 22: loss: 13.5291, loss_task: 8.4349, loss_kd: 0.5094, auc_id_cosine: 0.9555, auc_id_euclidean: 0.9555
# --> SAVE BEST MODEL (auc_id_cosine: 0.9555)
# 	Saved best model weights for 'auc_id_cosine' at epoch 22 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_22.pth'
#
# --- Epoch 23/60 ---
#
# Ep 23:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 12.6705 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  7.7738 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.4897 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9965 │ 0.9570 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9965 │ 0.9570 │
# ╘══════════════════╧═════════╧════════╛
# Ep 23: loss: 12.6705, loss_task: 7.7738, loss_kd: 0.4897, auc_id_cosine: 0.9570, auc_id_euclidean: 0.9570
# --> SAVE BEST MODEL (auc_id_cosine: 0.9570)
# 	Saved best model weights for 'auc_id_cosine' at epoch 23 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_23.pth'
#
# --- Epoch 24/60 ---
#
# Ep 24:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 11.6732 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  6.9857 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.4687 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9954 │ 0.9597 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9954 │ 0.9597 │
# ╘══════════════════╧═════════╧════════╛
# Ep 24: loss: 11.6732, loss_task: 6.9857, loss_kd: 0.4687, auc_id_cosine: 0.9597, auc_id_euclidean: 0.9597
# --> SAVE BEST MODEL (auc_id_cosine: 0.9597)
# 	Saved best model weights for 'auc_id_cosine' at epoch 24 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_24.pth'
#
# --- Epoch 25/60 ---
#
# Ep 25:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 10.8017 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  6.3315 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.447  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9959 │ 0.9579 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9959 │ 0.9579 │
# ╘══════════════════╧═════════╧════════╛
# Ep 25: loss: 10.8017, loss_task: 6.3315, loss_kd: 0.4470, auc_id_cosine: 0.9579, auc_id_euclidean: 0.9579
# 	Epoch 25: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 26/60 ---
#
# Ep 26:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  9.9539 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  5.6756 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.4278 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9956 │ 0.9611 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9956 │ 0.9611 │
# ╘══════════════════╧═════════╧════════╛
# Ep 26: loss: 9.9539, loss_task: 5.6756, loss_kd: 0.4278, auc_id_cosine: 0.9611, auc_id_euclidean: 0.9611
# --> SAVE BEST MODEL (auc_id_cosine: 0.9611)
# 	Saved best model weights for 'auc_id_cosine' at epoch 26 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_26.pth'
#
# --- Epoch 27/60 ---
#
# Ep 27:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  9.4178 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  5.3069 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.4111 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9963 │ 0.9620 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9963 │ 0.9620 │
# ╘══════════════════╧═════════╧════════╛
# Ep 27: loss: 9.4178, loss_task: 5.3069, loss_kd: 0.4111, auc_id_cosine: 0.9620, auc_id_euclidean: 0.9620
# --> SAVE BEST MODEL (auc_id_cosine: 0.9620)
# 	Saved best model weights for 'auc_id_cosine' at epoch 27 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_27.pth'
#
# --- Epoch 28/60 ---
#
# Ep 28:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  8.9419 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  4.9945 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3947 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9974 │ 0.9659 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9974 │ 0.9659 │
# ╘══════════════════╧═════════╧════════╛
# Ep 28: loss: 8.9419, loss_task: 4.9945, loss_kd: 0.3947, auc_id_cosine: 0.9659, auc_id_euclidean: 0.9659
# --> SAVE BEST MODEL (auc_id_cosine: 0.9659)
# 	Saved best model weights for 'auc_id_cosine' at epoch 28 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_28.pth'
#
# --- Epoch 29/60 ---
#
# Ep 29:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  8.3384 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  4.5211 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3817 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9977 │ 0.9648 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9977 │ 0.9648 │
# ╘══════════════════╧═════════╧════════╛
# Ep 29: loss: 8.3384, loss_task: 4.5211, loss_kd: 0.3817, auc_id_cosine: 0.9648, auc_id_euclidean: 0.9648
# 	Epoch 29: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 30/60 ---
#
# Ep 30:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  8.0857 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  4.3968 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3689 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9991 │ 0.9663 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9991 │ 0.9663 │
# ╘══════════════════╧═════════╧════════╛
# Ep 30: loss: 8.0857, loss_task: 4.3968, loss_kd: 0.3689, auc_id_cosine: 0.9663, auc_id_euclidean: 0.9663
# --> SAVE BEST MODEL (auc_id_cosine: 0.9663)
# 	Saved best model weights for 'auc_id_cosine' at epoch 30 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_30.pth'
#
# --- Epoch 31/60 ---
#
# Ep 31:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  7.7384 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  4.1867 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3552 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9984 │ 0.9655 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9984 │ 0.9655 │
# ╘══════════════════╧═════════╧════════╛
# Ep 31: loss: 7.7384, loss_task: 4.1867, loss_kd: 0.3552, auc_id_cosine: 0.9655, auc_id_euclidean: 0.9655
# 	Epoch 31: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 32/60 ---
#
# Ep 32:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  7.546  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  4.0315 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3515 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9988 │ 0.9682 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9988 │ 0.9682 │
# ╘══════════════════╧═════════╧════════╛
# Ep 32: loss: 7.5460, loss_task: 4.0315, loss_kd: 0.3515, auc_id_cosine: 0.9682, auc_id_euclidean: 0.9682
# --> SAVE BEST MODEL (auc_id_cosine: 0.9682)
# 	Saved best model weights for 'auc_id_cosine' at epoch 32 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_32.pth'
#
# --- Epoch 33/60 ---
#
# Ep 33:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  7.1663 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.8019 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3364 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9988 │ 0.9688 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9988 │ 0.9688 │
# ╘══════════════════╧═════════╧════════╛
# Ep 33: loss: 7.1663, loss_task: 3.8019, loss_kd: 0.3364, auc_id_cosine: 0.9688, auc_id_euclidean: 0.9688
# --> SAVE BEST MODEL (auc_id_cosine: 0.9688)
# 	Saved best model weights for 'auc_id_cosine' at epoch 33 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_33.pth'
#
# --- Epoch 34/60 ---
#
# Ep 34:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.856  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.6205 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3235 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.999  │ 0.9722 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.999  │ 0.9722 │
# ╘══════════════════╧═════════╧════════╛
# Ep 34: loss: 6.8560, loss_task: 3.6205, loss_kd: 0.3235, auc_id_cosine: 0.9722, auc_id_euclidean: 0.9722
# --> SAVE BEST MODEL (auc_id_cosine: 0.9722)
# 	Saved best model weights for 'auc_id_cosine' at epoch 34 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_34.pth'
#
# --- Epoch 35/60 ---
#
# Ep 35:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.4942 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.3791 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3115 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9993 │ 0.9698 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9993 │ 0.9698 │
# ╘══════════════════╧═════════╧════════╛
# Ep 35: loss: 6.4942, loss_task: 3.3791, loss_kd: 0.3115, auc_id_cosine: 0.9698, auc_id_euclidean: 0.9698
# 	Epoch 35: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 36/60 ---
#
# Ep 36:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.2925 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.2749 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3018 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9993 │ 0.9700 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9993 │ 0.9700 │
# ╘══════════════════╧═════════╧════════╛
# Ep 36: loss: 6.2925, loss_task: 3.2749, loss_kd: 0.3018, auc_id_cosine: 0.9700, auc_id_euclidean: 0.9700
# 	Epoch 36: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 37/60 ---
#
# Ep 37:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.1074 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.1343 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2973 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9998 │ 0.9724 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9998 │ 0.9724 │
# ╘══════════════════╧═════════╧════════╛
# Ep 37: loss: 6.1074, loss_task: 3.1343, loss_kd: 0.2973, auc_id_cosine: 0.9724, auc_id_euclidean: 0.9724
# --> SAVE BEST MODEL (auc_id_cosine: 0.9724)
# 	Saved best model weights for 'auc_id_cosine' at epoch 37 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_37.pth'
#
# --- Epoch 38/60 ---
#
# Ep 38:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.9252 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.0457 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.288  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9991 │ 0.9710 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9991 │ 0.9710 │
# ╘══════════════════╧═════════╧════════╛
# Ep 38: loss: 5.9252, loss_task: 3.0457, loss_kd: 0.2880, auc_id_cosine: 0.9710, auc_id_euclidean: 0.9710
# 	Epoch 38: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 39/60 ---
#
# Ep 39:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.8014 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.9703 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2831 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9998 │ 0.9699 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9998 │ 0.9699 │
# ╘══════════════════╧═════════╧════════╛
# Ep 39: loss: 5.8014, loss_task: 2.9703, loss_kd: 0.2831, auc_id_cosine: 0.9699, auc_id_euclidean: 0.9699
# 	Epoch 39: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 40/60 ---
#
# Ep 40:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.6809 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.9063 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2775 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9995 │ 0.9704 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9995 │ 0.9704 │
# ╘══════════════════╧═════════╧════════╛
# Ep 40: loss: 5.6809, loss_task: 2.9063, loss_kd: 0.2775, auc_id_cosine: 0.9704, auc_id_euclidean: 0.9704
# 	Epoch 40: EarlyStopping counter for 'auc_id_cosine': 3/10
#
# --- Epoch 41/60 ---
#
# Ep 41:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.5965 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.8451 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2751 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9719 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9719 │
# ╘══════════════════╧═════════╧════════╛
# Ep 41: loss: 5.5965, loss_task: 2.8451, loss_kd: 0.2751, auc_id_cosine: 0.9719, auc_id_euclidean: 0.9719
# 	Epoch 41: EarlyStopping counter for 'auc_id_cosine': 4/10
#
# --- Epoch 42/60 ---
#
# Ep 42:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.3692 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.6877 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2681 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9998 │ 0.9728 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9998 │ 0.9728 │
# ╘══════════════════╧═════════╧════════╛
# Ep 42: loss: 5.3692, loss_task: 2.6877, loss_kd: 0.2681, auc_id_cosine: 0.9728, auc_id_euclidean: 0.9728
# --> SAVE BEST MODEL (auc_id_cosine: 0.9728)
# 	Saved best model weights for 'auc_id_cosine' at epoch 42 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_42.pth'
#
# --- Epoch 43/60 ---
#
# Ep 43:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.4035 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.7548 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2649 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9723 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9723 │
# ╘══════════════════╧═════════╧════════╛
# Ep 43: loss: 5.4035, loss_task: 2.7548, loss_kd: 0.2649, auc_id_cosine: 0.9723, auc_id_euclidean: 0.9723
# 	Epoch 43: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 44/60 ---
#
# Ep 44:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.3097 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.6916 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2618 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9724 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9724 │
# ╘══════════════════╧═════════╧════════╛
# Ep 44: loss: 5.3097, loss_task: 2.6916, loss_kd: 0.2618, auc_id_cosine: 0.9724, auc_id_euclidean: 0.9724
# 	Epoch 44: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 45/60 ---
#
# Ep 45:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.2427 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.6811 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2562 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9998 │ 0.9726 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9998 │ 0.9726 │
# ╘══════════════════╧═════════╧════════╛
# Ep 45: loss: 5.2427, loss_task: 2.6811, loss_kd: 0.2562, auc_id_cosine: 0.9726, auc_id_euclidean: 0.9726
# 	Epoch 45: EarlyStopping counter for 'auc_id_cosine': 3/10
#
# --- Epoch 46/60 ---
#
# Ep 46:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.1936 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.6575 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2536 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9724 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9724 │
# ╘══════════════════╧═════════╧════════╛
# Ep 46: loss: 5.1936, loss_task: 2.6575, loss_kd: 0.2536, auc_id_cosine: 0.9724, auc_id_euclidean: 0.9724
# 	Epoch 46: EarlyStopping counter for 'auc_id_cosine': 4/10
#
# --- Epoch 47/60 ---
#
# Ep 47:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.1888 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.6585 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.253  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9998 │ 0.9726 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9998 │ 0.9726 │
# ╘══════════════════╧═════════╧════════╛
# Ep 47: loss: 5.1888, loss_task: 2.6585, loss_kd: 0.2530, auc_id_cosine: 0.9726, auc_id_euclidean: 0.9726
# 	Epoch 47: EarlyStopping counter for 'auc_id_cosine': 5/10
#
# --- Epoch 48/60 ---
#
# Ep 48:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.0855 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.5818 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2504 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9993 │ 0.9731 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9993 │ 0.9731 │
# ╘══════════════════╧═════════╧════════╛
# Ep 48: loss: 5.0855, loss_task: 2.5818, loss_kd: 0.2504, auc_id_cosine: 0.9731, auc_id_euclidean: 0.9731
# --> SAVE BEST MODEL (auc_id_cosine: 0.9731)
# 	Saved best model weights for 'auc_id_cosine' at epoch 48 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_48.pth'
#
# --- Epoch 49/60 ---
#
# Ep 49:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.8823 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4508 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2431 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9727 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9727 │
# ╘══════════════════╧═════════╧════════╛
# Ep 49: loss: 4.8823, loss_task: 2.4508, loss_kd: 0.2431, auc_id_cosine: 0.9727, auc_id_euclidean: 0.9727
# 	Epoch 49: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 50/60 ---
#
# Ep 50:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.8833 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4707 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2413 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9995 │ 0.9733 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9995 │ 0.9733 │
# ╘══════════════════╧═════════╧════════╛
# Ep 50: loss: 4.8833, loss_task: 2.4707, loss_kd: 0.2413, auc_id_cosine: 0.9733, auc_id_euclidean: 0.9733
# --> SAVE BEST MODEL (auc_id_cosine: 0.9733)
# 	Saved best model weights for 'auc_id_cosine' at epoch 50 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_50.pth'
#
# --- Epoch 51/60 ---
#
# Ep 51:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.8809 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4632 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2418 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9993 │ 0.9744 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9993 │ 0.9744 │
# ╘══════════════════╧═════════╧════════╛
# Ep 51: loss: 4.8809, loss_task: 2.4632, loss_kd: 0.2418, auc_id_cosine: 0.9744, auc_id_euclidean: 0.9744
# --> SAVE BEST MODEL (auc_id_cosine: 0.9744)
# 	Saved best model weights for 'auc_id_cosine' at epoch 51 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_51.pth'
#
# --- Epoch 52/60 ---
#
# Ep 52:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.7679 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.3723 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2396 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9748 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9748 │
# ╘══════════════════╧═════════╧════════╛
# Ep 52: loss: 4.7679, loss_task: 2.3723, loss_kd: 0.2396, auc_id_cosine: 0.9748, auc_id_euclidean: 0.9748
# --> SAVE BEST MODEL (auc_id_cosine: 0.9748)
# 	Saved best model weights for 'auc_id_cosine' at epoch 52 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-10)/checkpoints/best_auc_id_cosine_52.pth'
#
# --- Epoch 53/60 ---
#
# Ep 53:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.9282 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.531  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2397 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9731 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9731 │
# ╘══════════════════╧═════════╧════════╛
# Ep 53: loss: 4.9282, loss_task: 2.5310, loss_kd: 0.2397, auc_id_cosine: 0.9731, auc_id_euclidean: 0.9731
# 	Epoch 53: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 54/60 ---
#
# Ep 54:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.9071 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.5209 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2386 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9996 │ 0.9732 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9996 │ 0.9732 │
# ╘══════════════════╧═════════╧════════╛
# Ep 54: loss: 4.9071, loss_task: 2.5209, loss_kd: 0.2386, auc_id_cosine: 0.9732, auc_id_euclidean: 0.9732
# 	Epoch 54: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 55/60 ---
#
# Ep 55:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.9366 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.5353 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2401 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9992 │ 0.9744 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9992 │ 0.9744 │
# ╘══════════════════╧═════════╧════════╛
# Ep 55: loss: 4.9366, loss_task: 2.5353, loss_kd: 0.2401, auc_id_cosine: 0.9744, auc_id_euclidean: 0.9744
# 	Epoch 55: EarlyStopping counter for 'auc_id_cosine': 3/10
#
# --- Epoch 56/60 ---
#
# Ep 56:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.7607 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4147 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2346 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  1      │ 0.9742 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  1      │ 0.9742 │
# ╘══════════════════╧═════════╧════════╛
# Ep 56: loss: 4.7607, loss_task: 2.4147, loss_kd: 0.2346, auc_id_cosine: 0.9742, auc_id_euclidean: 0.9742
# 	Epoch 56: EarlyStopping counter for 'auc_id_cosine': 4/10
#
# --- Epoch 57/60 ---
#
# Ep 57:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.7278 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.393  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2335 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9996 │ 0.9734 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9996 │ 0.9734 │
# ╘══════════════════╧═════════╧════════╛
# Ep 57: loss: 4.7278, loss_task: 2.3930, loss_kd: 0.2335, auc_id_cosine: 0.9734, auc_id_euclidean: 0.9734
# 	Epoch 57: EarlyStopping counter for 'auc_id_cosine': 5/10
#
# --- Epoch 58/60 ---
#
# Ep 58:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.8273 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4746 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2353 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9992 │ 0.9743 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9992 │ 0.9743 │
# ╘══════════════════╧═════════╧════════╛
# Ep 58: loss: 4.8273, loss_task: 2.4746, loss_kd: 0.2353, auc_id_cosine: 0.9743, auc_id_euclidean: 0.9743
# 	Epoch 58: EarlyStopping counter for 'auc_id_cosine': 6/10
#
# --- Epoch 59/60 ---
#
# Ep 59:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.7948 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4274 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2367 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9998 │ 0.9735 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9998 │ 0.9735 │
# ╘══════════════════╧═════════╧════════╛
# Ep 59: loss: 4.7948, loss_task: 2.4274, loss_kd: 0.2367, auc_id_cosine: 0.9735, auc_id_euclidean: 0.9735
# 	Epoch 59: EarlyStopping counter for 'auc_id_cosine': 7/10
#
# --- Epoch 60/60 ---
#
# Ep 60:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.7272 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.377  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.235  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9998 │ 0.9736 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9998 │ 0.9736 │
# ╘══════════════════╧═════════╧════════╛
# Ep 60: loss: 4.7272, loss_task: 2.3770, loss_kd: 0.2350, auc_id_cosine: 0.9736, auc_id_euclidean: 0.9736
# 	Epoch 60: EarlyStopping counter for 'auc_id_cosine': 8/10
# KNOWLEDGE DISTILLATION HOAN TAT.

# %% [markdown]
# ## 8. Resume Training từ Checkpoint
#
# > Chạy cell này khi Colab disconnect và muốn tiếp tục train.
# > Checkpoint đã được ghi thẳng vào Drive nên không bị mất.
# >
# > **Cách dùng:** Chạy cell Setup → Imports → Data → Teacher → Student → Loss → Setup Train,
# > sau đó chạy cell này (không chạy cell fit ở trên), rồi chạy lại cell fit.

# %%
CKPT_PATH = os.path.join(manager.ckpt_dir, 'last_model.pth')

if not os.path.exists(CKPT_PATH):
    raise FileNotFoundError(f'Không tìm thấy checkpoint: {CKPT_PATH}')

checkpoint = torch.load(CKPT_PATH, map_location=device, weights_only=False)


student.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
if 'scheduler_state_dict' in checkpoint:
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
if 'projector_state_dict' in checkpoint:
    projector.load_state_dict(checkpoint['projector_state_dict'])
    print('Projector state loaded.')
else:
    print('Không tìm thấy projector_state_dict — projector khởi tạo ngẫu nhiên.')

START_EPOCH = checkpoint['epoch']
print(f'Resume từ epoch {START_EPOCH} — chạy lại cell "cell-fit" để tiếp tục.')
# Out:
# Projector state loaded.
# Resume từ epoch 40 — chạy lại cell "cell-fit" để tiếp tục.

# %% [markdown]
# ## 9. Đánh giá Final

# %%
best_ckpt_path = os.path.join(manager.ckpt_dir, 'best_model.pth')
best_ckpt = torch.load(best_ckpt_path, map_location=device, weights_only=False)
student.load_state_dict(best_ckpt['model_state_dict'])
student.eval()
# print(f"Best model từ epoch {best_ckpt.get('epoch', '?')}")

student_gp_auc   = compute_id_auc_gallery_probe(gallery_dl, probe_dl, student, device)
student_gp_rank1 = compute_rank1_gallery_probe(gallery_dl, probe_dl, student, device)

rows = [
    ['Cosine AUC    (gallery→probe)', f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)', f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)', f"{student_gp_rank1:.4f}"],
]
print(f"\nStudent ({CONFIGURATION['backbone']}) — KD from {CONFIGURATION['teacher_backbone']}")
print(tabulate(rows, headers=['Metric', 'Value'], tablefmt='fancy_grid'))

# So sánh Teacher vs Student
compare_rows = [
    ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
    ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
    ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
]
print('\n--- Teacher vs Student (KD) ---')
print(tabulate(compare_rows, headers=['Metric', 'Teacher', 'Student (KD)'], tablefmt='fancy_grid'))
# Out:
# Student (mobilenetv3_large_100) — KD from convnextv2_tiny
# ╒═══════════════════════════════╤═════════╕
# │ Metric                        │   Value │
# ╞═══════════════════════════════╪═════════╡
# │ Cosine AUC    (gallery→probe) │  0.9718 │
# ├───────────────────────────────┼─────────┤
# │ Euclidean AUC (gallery→probe) │  0.9718 │
# ├───────────────────────────────┼─────────┤
# │ Rank-1 Acc    (gallery→probe) │  0.7569 │
# ╘═══════════════════════════════╧═════════╛
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5091/1905580024.py in <cell line: 0>()
#      20     ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
#      21     ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
# ---> 22     ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
#      23     ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
#      24     ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
#
# NameError: name 'teacher_gp_auc' is not defined

# %% [markdown]
# ## weight 1-3

# %%
best_ckpt_path = '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-3)/checkpoints/best_model.pth'
best_ckpt = torch.load(best_ckpt_path, map_location=device, weights_only=False)
student.load_state_dict(best_ckpt['model_state_dict'])
student.eval()
# print(f"Best model từ epoch {best_ckpt.get('epoch', '?')}")

student_gp_auc   = compute_id_auc_gallery_probe(gallery_dl, probe_dl, student, device)
student_gp_rank1 = compute_rank1_gallery_probe(gallery_dl, probe_dl, student, device)

rows = [
    ['Cosine AUC    (gallery→probe)', f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)', f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)', f"{student_gp_rank1:.4f}"],
]
print(f"\nStudent ({CONFIGURATION['backbone']}) — KD from {CONFIGURATION['teacher_backbone']}")
print(tabulate(rows, headers=['Metric', 'Value'], tablefmt='fancy_grid'))

# So sánh Teacher vs Student
compare_rows = [
    ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
    ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
    ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
]
print('\n--- Teacher vs Student (KD) ---')
print(tabulate(compare_rows, headers=['Metric', 'Teacher', 'Student (KD)'], tablefmt='fancy_grid'))
# Out:
# Student (mobilenetv3_large_100) — KD from convnextv2_tiny
# ╒═══════════════════════════════╤═════════╕
# │ Metric                        │   Value │
# ╞═══════════════════════════════╪═════════╡
# │ Cosine AUC    (gallery→probe) │  0.9741 │
# ├───────────────────────────────┼─────────┤
# │ Euclidean AUC (gallery→probe) │  0.9741 │
# ├───────────────────────────────┼─────────┤
# │ Rank-1 Acc    (gallery→probe) │  0.7465 │
# ╘═══════════════════════════════╧═════════╛
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1172/2421165392.py in <cell line: 0>()
#      20     ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
#      21     ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
# ---> 22     ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
#      23     ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
#      24     ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
#
# NameError: name 'teacher_gp_auc' is not defined

# %%
best_ckpt_path = '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-3)/checkpoints/last_model.pth'
best_ckpt = torch.load(best_ckpt_path, map_location=device, weights_only=False)
student.load_state_dict(best_ckpt['model_state_dict'])
student.eval()
# print(f"Best model từ epoch {best_ckpt.get('epoch', '?')}")

student_gp_auc   = compute_id_auc_gallery_probe(gallery_dl, probe_dl, student, device)
student_gp_rank1 = compute_rank1_gallery_probe(gallery_dl, probe_dl, student, device)

rows = [
    ['Cosine AUC    (gallery→probe)', f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)', f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)', f"{student_gp_rank1:.4f}"],
]
print(f"\nStudent ({CONFIGURATION['backbone']}) — KD from {CONFIGURATION['teacher_backbone']}")
print(tabulate(rows, headers=['Metric', 'Value'], tablefmt='fancy_grid'))

# So sánh Teacher vs Student
compare_rows = [
    ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
    ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
    ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
]
print('\n--- Teacher vs Student (KD) ---')
print(tabulate(compare_rows, headers=['Metric', 'Teacher', 'Student (KD)'], tablefmt='fancy_grid'))
# Out:
# Student (mobilenetv3_large_100) — KD from convnextv2_tiny
# ╒═══════════════════════════════╤═════════╕
# │ Metric                        │   Value │
# ╞═══════════════════════════════╪═════════╡
# │ Cosine AUC    (gallery→probe) │  0.9739 │
# ├───────────────────────────────┼─────────┤
# │ Euclidean AUC (gallery→probe) │  0.9739 │
# ├───────────────────────────────┼─────────┤
# │ Rank-1 Acc    (gallery→probe) │  0.7431 │
# ╘═══════════════════════════════╧═════════╛
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1172/3910338216.py in <cell line: 0>()
#      20     ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
#      21     ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
# ---> 22     ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
#      23     ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
#      24     ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
#
# NameError: name 'teacher_gp_auc' is not defined

# %% [markdown]
# ## weight 1-1 ??

# %%
best_ckpt_path = '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector/checkpoints/best_model.pth'
best_ckpt = torch.load(best_ckpt_path, map_location=device, weights_only=False)
student.load_state_dict(best_ckpt['model_state_dict'])
student.eval()
# print(f"Best model từ epoch {best_ckpt.get('epoch', '?')}")

student_gp_auc   = compute_id_auc_gallery_probe(gallery_dl, probe_dl, student, device)
student_gp_rank1 = compute_rank1_gallery_probe(gallery_dl, probe_dl, student, device)

rows = [
    ['Cosine AUC    (gallery→probe)', f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)', f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)', f"{student_gp_rank1:.4f}"],
]
print(f"\nStudent ({CONFIGURATION['backbone']}) — KD from {CONFIGURATION['teacher_backbone']}")
print(tabulate(rows, headers=['Metric', 'Value'], tablefmt='fancy_grid'))

# So sánh Teacher vs Student
compare_rows = [
    ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
    ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
    ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
]
print('\n--- Teacher vs Student (KD) ---')
print(tabulate(compare_rows, headers=['Metric', 'Teacher', 'Student (KD)'], tablefmt='fancy_grid'))
# Out:
# Student (mobilenetv3_large_100) — KD from convnextv2_tiny
# ╒═══════════════════════════════╤═════════╕
# │ Metric                        │   Value │
# ╞═══════════════════════════════╪═════════╡
# │ Cosine AUC    (gallery→probe) │  0.9691 │
# ├───────────────────────────────┼─────────┤
# │ Euclidean AUC (gallery→probe) │  0.9691 │
# ├───────────────────────────────┼─────────┤
# │ Rank-1 Acc    (gallery→probe) │  0.7569 │
# ╘═══════════════════════════════╧═════════╛
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_776/419274408.py in <cell line: 0>()
#      20     ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
#      21     ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
# ---> 22     ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
#      23     ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
#      24     ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
#
# NameError: name 'teacher_gp_auc' is not defined

# %% [markdown]
# ## 10. Export ONNX
#
# Export phần inference (backbone + embedding + L2 normalize, bỏ MagLinear)
# để chuẩn bị quantize INT8 deploy edge device.

# %%
class InferenceWrapper(nn.Module):
    """Backbone + embedding + L2 normalize — không có MagLinear."""
    def __init__(self, model):
        super().__init__()
        self.backbone  = model.backbone
        self.embedding = model.embedding

    def forward(self, x):
        emb = self.embedding(self.backbone(x))
        return F.normalize(emb, p=2, dim=1)


inference_model = InferenceWrapper(student).eval().cpu()
dummy_input = torch.randn(1, 3, 112, 112)

# Lưu vào Drive để không mất
onnx_path = os.path.join(manager.ckpt_dir, 'kd_mobilenetv3_fr.onnx')

torch.onnx.export(
    inference_model,
    dummy_input,
    onnx_path,
    input_names=['input'],
    output_names=['embedding'],
    dynamic_axes={'input': {0: 'batch'}, 'embedding': {0: 'batch'}},
    opset_version=17,
)
print(f'Exported ONNX: {onnx_path}')
