# %% [markdown]
# # Knowledge Distillation: ConvNeXt V2 → MobileNetV3 (Colab)
#
# **Mục tiêu:** Dùng ID embedding 512-D của teacher ConvNeXt V2 (đã train MTL) để hướng dẫn student MobileNetV3 học compact embedding cho face recognition.
#
# | | Teacher | Student |
# |---|---|---|
# | Model | `MTLFaceRecognition` (ConvNeXt V2) | `FaceRecognitionMobileNetV3` |
# | Params | ~28M | ~5M |
# | Embedding dùng cho KD | `x_id` (512-D, tầng cuối) | 512-D |
# | Mode | **Frozen** | **Trainable** |
#
# **KD Loss:**
# ```
# L_total = α · L_MagFace(student)  +  β · L_KD
# L_KD    = mean(1 - cosine_sim(norm(s_emb), norm(t_emb)))
# ```
#
# **Cách dùng:**
# 1. Mount Google Drive (cell 1)
# 2. Sửa `CONFIGURATION` và `TEACHER_CKPT` (cell Config)
# 3. Chạy từ trên xuống

# %% [markdown]
# ## 1. Mount Drive & Setup môi trường

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

REPO_URL    = 'https://github.com/NguyenXuanBinh22/DATN.git'
REPO_BRANCH = 'convnext-v2-dev'
REPO_DIR    = '/content/FR_Photometric_Stereo'

if not os.path.exists(REPO_DIR):
    os.system(f'git clone -b {REPO_BRANCH} {REPO_URL} {REPO_DIR}')
else:
    os.system(f'git -C {REPO_DIR} pull origin {REPO_BRANCH}')
    print('Repo đã tồn tại, đã pull latest.')

# %cd {REPO_DIR}
print(f'Working dir: {os.getcwd()}')

os.system('pip install -q albumentations==1.3.1 timm tabulate termcolor')
# Out:
# Mounted at /content/drive
# /content/FR_Photometric_Stereo
# Working dir: /content/FR_Photometric_Stereo
# 0

# %% [markdown]
# ## 2. Imports & Cấu hình

# %%
# %cd /content/FR_Photometric_Stereo
import warnings
warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import albumentations as A
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
from torch.utils.tensorboard import SummaryWriter
from tabulate import tabulate

from going_modular.dataloader.multitask import create_multitask_datafetcher, create_eval_loaders
from going_modular.model.MTLFaceRecognition import MTLFaceRecognition
from going_modular.model.FaceRecognitionMobileNetV3 import FaceRecognitionMobileNetV3
from going_modular.loss.WeightClassMagLoss import WeightClassMagLoss
from going_modular.utils.transforms import RandomResizedCropRect, GaussianNoise
from going_modular.utils.roc_auc_id import (
    compute_id_auc, compute_rank1,
    compute_id_auc_gallery_probe, compute_rank1_gallery_probe,
)
from going_modular.utils.MultiMetricEarlyStopping import MultiMetricEarlyStopping
from going_modular.utils.ModelCheckPoint import ModelCheckpoint
from going_modular.utils.ExperimentManager import ExperimentManager

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(42)
print(f'Device: {device}')
if device == 'cuda':
    print(f'GPU: {torch.cuda.get_device_name(0)}')
# Out:
# /content/FR_Photometric_Stereo
# Device: cuda
# GPU: NVIDIA A100-SXM4-80GB

# %%
# ════════════════════════════════════════════════════════════
#  CẤU HÌNH — chỉnh sửa ở đây
# ════════════════════════════════════════════════════════════

# Đường dẫn dataset trên Google Drive
DRIVE_DATASET_DIR = '/content/drive/MyDrive/Photometric_DB_Full/'

# Checkpoint teacher ConvNeXt V2 đã train (best_model.pth hoặc last_model.pth)
# Ví dụ: '/content/drive/MyDrive/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth'
TEACHER_CKPT = '/content/drive/MyDrive/Photometric_DB_Full/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth'

EXPERIMENT_NAME = 'KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)'

CONFIGURATION = {
    'note':        EXPERIMENT_NAME,
    'dataset_dir': DRIVE_DATASET_DIR,

    # Ghi checkpoint và log vào Drive để không mất khi Colab disconnect
    'output_dir':  '/content/drive/MyDrive/',

    # Modality: 'albedo' | 'normalmap' | 'depthmap'
    # Phải giống modality mà teacher đã được train
    'type':        'albedo',

    # Teacher backbone (để tái tạo đúng kiến trúc khi load checkpoint)
    'teacher_backbone': 'convnextv2_tiny',

    # Student backbone
    'backbone':    'mobilenetv3_large_100',

    'use_sampler': True,   # PK Sampler — mỗi batch gồm batch_size identity khác nhau
    'device':      device,
    'epochs':      60,
    'batch_size':  32,
    'image_size':  112,
    'base_lr':     1e-4,
    'num_classes': None,   # tự động lấy từ CSV

    # Trọng số loss
    # L_total = task_weight * L_MagFace + kd_weight * L_KD
    'task_weight': 1.0,
    'kd_weight':   1.0,
}

print(f"Dataset dir : {CONFIGURATION['dataset_dir']}")
print(f"Output dir  : {CONFIGURATION['output_dir']}")
print(f"Teacher ckpt: {TEACHER_CKPT}")
# Out:
# Dataset dir : /content/drive/MyDrive/Photometric_DB_Full/
# Output dir  : /content/drive/MyDrive/
# Teacher ckpt: /content/drive/MyDrive/Photometric_DB_Full/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth

# %% [markdown]
# ## 3. Data Loading
#
# Dùng **cùng transform** với ConvNeXt V2 để student và teacher nhận cùng input trong mỗi batch.

# %%
dataset_dir = CONFIGURATION['dataset_dir']

# Tìm CSV — hỗ trợ cả hai cấu trúc thư mục
train_csv = os.path.join(dataset_dir, 'train_split.csv')
if not os.path.exists(train_csv):
    train_csv = os.path.join(dataset_dir, 'dataset', 'train_split.csv')
if not os.path.exists(train_csv):
    train_csv = os.path.join(dataset_dir, 'train_set.csv')
if not os.path.exists(train_csv):
    raise FileNotFoundError(
        f'Không tìm thấy CSV train tại {dataset_dir}.\n'
        f'Kiểm tra lại DRIVE_DATASET_DIR.'
    )
print(f'Train CSV: {train_csv}')

df_train = pd.read_csv(train_csv)
CONFIGURATION['num_classes'] = int(df_train['id'].nunique())
print(f'num_classes : {CONFIGURATION["num_classes"]}')
print(f'Số mẫu train: {len(df_train)}')

# Transform — giống hệt ConvNeXt V2 pipeline
train_transform = A.Compose([
    RandomResizedCropRect(CONFIGURATION['image_size']),
    GaussianNoise(p=0.2),
    A.HorizontalFlip(p=0.5),
])
test_transform = A.Compose([
    A.Resize(CONFIGURATION['image_size'], CONFIGURATION['image_size']),
])

# Training dataloader — probe_split.csv dùng để monitor AUC trong vòng lặp train
train_dl, test_dl, _ = create_multitask_datafetcher(
    CONFIGURATION, train_transform, test_transform, 'train_split.csv', 'probe_split.csv'
)
print(f'Train batches: {len(train_dl)} | Test batches (probe): {len(test_dl)}')

# Gallery-probe loaders — CHỈ dùng cho đánh giá cuối, không dùng trong training
# gallery_split.csv: reference set | probe_split.csv: query set
gallery_dl, probe_dl = create_eval_loaders(CONFIGURATION, test_transform)
# Out:
# Train CSV: /content/drive/MyDrive/Photometric_DB_Full/train_split.csv
# num_classes : 352
# Số mẫu train: 2622
# >>> SingleLoader: MODE = PK SAMPLER
# Train batches: 81 | Test batches (probe): 9
# Gallery: 68 ảnh | Probe: 288 ảnh
# Shared identity space: 68 identities

# %% [markdown]
# ## 4. Teacher Model (ConvNeXt V2 — Frozen)
#
# Load checkpoint đã train, freeze toàn bộ weights.
# Chỉ dùng `get_embedding(x)[-1]` để lấy **ID embedding** (`x_id`, tầng embedding cuối).

# %%
if not os.path.exists(TEACHER_CKPT):
    raise FileNotFoundError(
        f'Không tìm thấy teacher checkpoint: {TEACHER_CKPT}\n'
        f'Kiểm tra lại biến TEACHER_CKPT.'
    )

# Khởi tạo teacher với đúng kiến trúc
teacher = MTLFaceRecognition(
    backbone=CONFIGURATION['teacher_backbone'],
    num_classes=CONFIGURATION['num_classes'],
)

# Load weights
ckpt = torch.load(TEACHER_CKPT, map_location=device, weights_only=False)
state_dict = ckpt['model_state_dict']

# Remove keys related to the id_head.maglinear layer to avoid size mismatch errors
# This layer is not needed as the teacher is used for feature extraction only
keys_to_remove = [k for k in state_dict.keys() if 'id_head.maglinear' in k]
for k in keys_to_remove:
    del state_dict[k]

teacher.load_state_dict(ckpt['model_state_dict'], strict=False)  # strict=False để bỏ qua nếu có layers mới (như classifier)
print(f"Teacher loaded — epoch {ckpt.get('epoch', '?')}")

# Freeze hoàn toàn
teacher.to(device)
teacher.eval()
for p in teacher.parameters():
    p.requires_grad = False

teacher_params = sum(p.numel() for p in teacher.parameters())
print(f'Teacher params: {teacher_params:,} (tất cả frozen)')

# Smoke test — kiểm tra embedding shape
with torch.no_grad():
    _dummy = torch.randn(2, 3, 112, 112).to(device)
    # get_embedding() trả về (x_spec, x_fh, x_pose, x_emot, x_gender, x_id)
    _t_emb = teacher.get_embedding(_dummy)[-1]   # x_id
    print(f'Teacher ID embedding shape: {_t_emb.shape}')   # mong đợi [2, 512]
# Out:
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# Teacher loaded — epoch 28
# Teacher params: 45,670,280 (tất cả frozen)
# Teacher ID embedding shape: torch.Size([2, 512])

# %% [markdown]
# ## 4.1. Đánh giá Teacher Model (baseline)
#
# Đo AUC của teacher trên train/test set **trước khi distillation** để có baseline so sánh với student sau này.

# %%
class _TeacherEvalWrapper(torch.nn.Module):
    """MTLFaceRecognition.get_embedding() trả về tuple — wrapper giữ lại x_id (index -1)."""
    def __init__(self, teacher):
        super().__init__()
        self._teacher = teacher

    def get_embedding(self, x):
        return self._teacher.get_embedding(x)[-1]   # x_id: [B, 512]


teacher_wrapper = _TeacherEvalWrapper(teacher).to(device)
teacher_wrapper.eval()

teacher_gp_auc   = compute_id_auc_gallery_probe(gallery_dl, probe_dl, teacher_wrapper, device)
teacher_gp_rank1 = compute_rank1_gallery_probe(gallery_dl, probe_dl, teacher_wrapper, device)

rows = [
    ['Cosine AUC    (gallery→probe)', f"{teacher_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)', f"{teacher_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)', f"{teacher_gp_rank1:.4f}"],
]
print(f"Teacher ({CONFIGURATION['teacher_backbone']}) — weight: {TEACHER_CKPT}")
print(tabulate(rows, headers=['Metric', 'Value'], tablefmt='fancy_grid'))
# Out:
# Teacher (convnextv2_tiny) — weight: /content/drive/MyDrive/Photometric_DB_Full/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth
# ╒═══════════════════════════════╤═════════╕
# │ Metric                        │   Value │
# ╞═══════════════════════════════╪═════════╡
# │ Cosine AUC    (gallery→probe) │  0.9761 │
# ├───────────────────────────────┼─────────┤
# │ Euclidean AUC (gallery→probe) │  0.9761 │
# ├───────────────────────────────┼─────────┤
# │ Rank-1 Acc    (gallery→probe) │  0.8021 │
# ╘═══════════════════════════════╧═════════╛

# %% [markdown]
# ## 5. Student Model (MobileNetV3 — Trainable)

# %%
student = FaceRecognitionMobileNetV3(
    num_classes=CONFIGURATION['num_classes'],
    backbone=CONFIGURATION['backbone'],
)
student.to(device)

total_p     = sum(p.numel() for p in student.parameters())
trainable_p = sum(p.numel() for p in student.parameters() if p.requires_grad)
print(f'Student total params    : {total_p:,}')
print(f'Student trainable params: {trainable_p:,}')

# Smoke test
with torch.no_grad():
    _s_emb = student.get_embedding(_dummy)
    print(f'Student embedding shape: {_s_emb.shape}')   # mong đợi [2, 512]
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/22.1M [00:00<?, ?B/s]
# WARNING:timm.models._builder:Unexpected keys (classifier.bias, classifier.weight, conv_head.bias, conv_head.weight) found while loading pretrained weights. This may be expected if model is being adapted.
# Student total params    : 3,646,256
# Student trainable params: 3,646,256
# Student embedding shape: torch.Size([2, 512])

# %% [markdown]
# ## 6. Knowledge Distillation Loss
#
# ```
# L_total = α · L_MagFace  +  β · L_KD
#
# L_MagFace : WeightClassMagFace — phân biệt class boundaries cho student
# L_KD      : Cosine distance giữa student emb và teacher ID emb
#            = mean(1 - cos_sim(norm(s_emb), norm(t_emb)))
# ```
#
# **Tại sao cosine loss:**
# Face verification so sánh *hướng* của embedding (cosine sim), không phải magnitude.
# Cosine loss kéo student về đúng hướng mà không ràng buộc magnitude.

# %%
class KDLoss(nn.Module):
    """
    L_total = task_weight * L_MagFace  +  kd_weight * L_KD_cosine
    """

    def __init__(self, metadata_path: str, task_weight: float = 1.0, kd_weight: float = 1.0):
        super().__init__()
        self.magface = WeightClassMagLoss(metadata_path)
        self.task_w  = task_weight
        self.kd_w    = kd_weight

    def forward(
        self,
        student_logits,   # [cos_theta, cos_theta_m] từ MagLinear
        student_norm,     # x_norm từ MagLinear
        student_emb,      # [B, 512] — embedding trước MagLinear
        teacher_emb,      # [B, 512] — ID embedding của teacher (no_grad)
        id_labels,        # [B] — ground-truth identity
    ):
        # Task loss
        l_task = self.magface(student_logits, id_labels, student_norm)

        # KD loss — cosine distance trên unit hypersphere
        s_n = F.normalize(student_emb, p=2, dim=1)
        t_n = F.normalize(teacher_emb, p=2, dim=1)
        l_kd = (1.0 - F.cosine_similarity(s_n, t_n, dim=1)).mean()

        total = self.task_w * l_task + self.kd_w * l_kd
        return total, l_task, l_kd


criterion = KDLoss(
    metadata_path=train_csv,
    task_weight=CONFIGURATION['task_weight'],
    kd_weight=CONFIGURATION['kd_weight'],
)
print('KDLoss khởi tạo thành công.')
# Out:
# KDLoss khởi tạo thành công.

# %% [markdown]
# ## 6.1. Projection Head
#
# Student và teacher sống trong hai embedding space khác nhau — ép chúng chia sẻ cùng một space là quá cứng nhắc và thường dẫn đến `loss_kd` cao.
#
# Giải pháp: thêm một MLP nhỏ (**ProjectionHead**) giúp bridge hai space lại.
#
# ```
# student_emb (512-D)  →  projector  →  proj_emb (512-D)  ←→  teacher_emb
# ```
#
# - `student_emb` vẫn đi thẳng vào `MagLinear` (task loss không thay đổi)
# - Chỉ `proj_emb` được dùng cho KD loss
# - Projector **chỉ tồn tại khi train**, bỏ hoàn toàn khi export ONNX

# %%
class ProjectionHead(nn.Module):
    """
    MLP bridge: student embedding space → teacher embedding space.
    Chỉ dùng khi tính KD loss, không tham gia inference / ONNX export.

    Luồng:
        student_emb  →  Linear(512→512) → BN → ReLU → Linear(512→512)
                     →  proj_emb  ←→  teacher_emb  (cosine KD loss)
    """
    def __init__(self, in_dim: int = 512, hidden_dim: int = 512, out_dim: int = 512):
        super().__init__()
        self.proj = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Linear(hidden_dim, out_dim),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.proj(x)


projector = ProjectionHead(in_dim=512, hidden_dim=512, out_dim=512).to(device)
proj_params = sum(p.numel() for p in projector.parameters())
print(f'ProjectionHead params: {proj_params:,}  (train-only, dropped at export)')
# Out:
# ProjectionHead params: 526,336  (train-only, dropped at export)

# %% [markdown]
# ## 7. Training

# %%
def train_epoch(train_dl, teacher, student, projector, criterion, optimizer, device):
    student.train()
    projector.train()
    # teacher.eval() + frozen — không cần đặt lại mỗi epoch

    total_loss = total_task = total_kd = 0.0

    for X, y in train_dl:
        X, y = X.to(device), y.to(device)
        id_labels = y[:, 0]   # chỉ cần identity label

        # Teacher forward — no gradient, không update weights
        with torch.no_grad():
            # get_embedding() → (x_spec, x_fh, x_pose, x_emot, x_gender, x_id)
            teacher_emb = teacher.get_embedding(X)[-1]   # x_id: [B, 512]

        # Student forward — một lần duy nhất để lấy cả embedding lẫn logits
        feat         = student.backbone(X)          # [B, 512, H, W]
        student_emb  = student.embedding(feat)      # [B, 512]
        proj_emb     = projector(student_emb)       # [B, 512] — bridge to teacher space
        logits, norm = student.maglinear(student_emb)

        # Loss tổng hợp
        # task loss dùng student_emb gốc (không qua projector)
        # KD loss dùng proj_emb để không ràng buộc student_emb phải giống teacher
        loss, l_task, l_kd = criterion(
            logits, norm, proj_emb, teacher_emb, id_labels
        )

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        total_task += l_task.item()
        total_kd   += l_kd.item()

    n = len(train_dl)
    return total_loss / n, total_task / n, total_kd / n


def display_metrics(epoch, train_metrics, test_metrics):
    rows = []
    for k in train_metrics:
        tv = train_metrics[k]
        ev = test_metrics.get(k, '-')
        fmt = lambda v: f'{v:.4f}' if isinstance(v, float) else str(v)
        rows.append([k, fmt(tv), fmt(ev)])
    print(f'\nEp {epoch}:')
    print(tabulate(rows, headers=['Metric', 'Train', 'Test'], tablefmt='fancy_grid'))

# %%
optimizer = Adam(
    list(student.parameters()) + list(projector.parameters()),
    lr=CONFIGURATION['base_lr'],
)
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=20, T_mult=2, eta_min=1e-6)

manager = ExperimentManager(CONFIGURATION)
manager.log_text(
    f"Teacher: {CONFIGURATION['teacher_backbone']} | "
    f"Student: {CONFIGURATION['backbone']} | "
    f"Modality: {CONFIGURATION['type']} | "
    f"kd_weight={CONFIGURATION['kd_weight']} task_weight={CONFIGURATION['task_weight']} | "
    f"projector=True"
)

ckpt_saver = ModelCheckpoint(
    output_dir=manager.ckpt_dir,
    mode='max',
    best_metric_name='auc_id_cosine',
)
early_stopping = MultiMetricEarlyStopping(
    monitor_keys=['auc_id_cosine'],
    patience=10,
    mode='max',
    verbose=1,
    save_dir=manager.ckpt_dir,
    start_from_epoch=5,
)

writer = SummaryWriter(log_dir=manager.log_dir)
print(f'Experiment dir: {manager.exp_dir}')
print(f'Checkpoint dir: {manager.ckpt_dir}')
print('(Tất cả được ghi thẳng vào Google Drive)')
# Out:
# KHOI TAO THI NGHIEM: KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)
# Luu tru tai: /content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)
# Thoi gian: 2026-05-30 14:28:18
# --------------------------------------------------
# Teacher: convnextv2_tiny | Student: mobilenetv3_large_100 | Modality: albedo | kd_weight=1.0 task_weight=1.0 | projector=True
# Experiment dir: /content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)
# Checkpoint dir: /content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints
# (Tất cả được ghi thẳng vào Google Drive)

# %%
START_EPOCH = 0

manager.log_text('BAT DAU KNOWLEDGE DISTILLATION (với ProjectionHead)')

for epoch in range(START_EPOCH, CONFIGURATION['epochs']):
    manager.log_text(f'\n--- Epoch {epoch+1}/{CONFIGURATION["epochs"]} ---')

    # Train
    train_loss, train_task, train_kd = train_epoch(
        train_dl, teacher, student, projector, criterion, optimizer, device
    )

    # AUC — dùng student.get_embedding() trực tiếp (không qua projector)
    train_auc = compute_id_auc(train_dl, student, device)
    test_auc  = compute_id_auc(test_dl,  student, device)

    train_metrics = {
        'loss':             train_loss,
        'loss_task':        train_task,
        'loss_kd':          train_kd,
        'auc_id_cosine':    train_auc['id_cosine'],
        'auc_id_euclidean': train_auc['id_euclidean'],
    }
    test_metrics = {
        'auc_id_cosine':    test_auc['id_cosine'],
        'auc_id_euclidean': test_auc['id_euclidean'],
    }

    # TensorBoard
    writer.add_scalar('Loss/total', train_loss, epoch + 1)
    writer.add_scalar('Loss/task',  train_task, epoch + 1)
    writer.add_scalar('Loss/kd',    train_kd,   epoch + 1)
    writer.add_scalars('AUC/cosine',
        {'train': train_auc['id_cosine'],    'test': test_auc['id_cosine']},    epoch + 1)
    writer.add_scalars('AUC/euclidean',
        {'train': train_auc['id_euclidean'], 'test': test_auc['id_euclidean']}, epoch + 1)

    # Console + file log
    display_metrics(epoch + 1, train_metrics, test_metrics)
    manager.log_metrics(epoch + 1, {**train_metrics, **test_metrics})

    # Checkpoint (lưu cả projector state để có thể resume)
    ckpt_saver(
        student, optimizer, epoch + 1, test_metrics, scheduler,
        extra_state={'projector_state_dict': projector.state_dict()},
    )
    early_stopping(test_metrics, student, epoch + 1)
    scheduler.step(epoch)

    if early_stopping.early_stop:
        manager.log_text('Early stopping triggered.')
        break

writer.close()
manager.log_text('KNOWLEDGE DISTILLATION HOAN TAT.')
# Out:
# BAT DAU KNOWLEDGE DISTILLATION (với ProjectionHead)
#
# --- Epoch 1/60 ---
#
# Ep 1:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 30.5618 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 29.6076 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9542 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.919  │ 0.9023 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.919  │ 0.9023 │
# ╘══════════════════╧═════════╧════════╛
# Ep 1: loss: 30.5618, loss_task: 29.6076, loss_kd: 0.9542, auc_id_cosine: 0.9023, auc_id_euclidean: 0.9023
# --> SAVE BEST MODEL (auc_id_cosine: 0.9023)
#
# --- Epoch 2/60 ---
#
# Ep 2:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 32.3486 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 31.4569 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.8916 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9373 │ 0.9088 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9373 │ 0.9088 │
# ╘══════════════════╧═════════╧════════╛
# Ep 2: loss: 32.3486, loss_task: 31.4569, loss_kd: 0.8916, auc_id_cosine: 0.9088, auc_id_euclidean: 0.9088
# --> SAVE BEST MODEL (auc_id_cosine: 0.9088)
#
# --- Epoch 3/60 ---
#
# Ep 3:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 30.811  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 29.957  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.854  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9548 │ 0.9228 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9548 │ 0.9228 │
# ╘══════════════════╧═════════╧════════╛
# Ep 3: loss: 30.8110, loss_task: 29.9570, loss_kd: 0.8540, auc_id_cosine: 0.9228, auc_id_euclidean: 0.9228
# --> SAVE BEST MODEL (auc_id_cosine: 0.9228)
#
# --- Epoch 4/60 ---
#
# Ep 4:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 28.2029 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 27.3912 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.8117 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9623 │ 0.9314 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9623 │ 0.9314 │
# ╘══════════════════╧═════════╧════════╛
# Ep 4: loss: 28.2029, loss_task: 27.3912, loss_kd: 0.8117, auc_id_cosine: 0.9314, auc_id_euclidean: 0.9314
# --> SAVE BEST MODEL (auc_id_cosine: 0.9314)
#
# --- Epoch 5/60 ---
#
# Ep 5:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 25.6494 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 24.8749 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.7745 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9751 │ 0.9409 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9751 │ 0.9409 │
# ╘══════════════════╧═════════╧════════╛
# Ep 5: loss: 25.6494, loss_task: 24.8749, loss_kd: 0.7745, auc_id_cosine: 0.9409, auc_id_euclidean: 0.9409
# --> SAVE BEST MODEL (auc_id_cosine: 0.9409)
# 	Saved best model weights for 'auc_id_cosine' at epoch 5 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_5.pth'
#
# --- Epoch 6/60 ---
#
# Ep 6:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 22.6551 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 21.9172 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.7379 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9768 │ 0.9438 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9768 │ 0.9438 │
# ╘══════════════════╧═════════╧════════╛
# Ep 6: loss: 22.6551, loss_task: 21.9172, loss_kd: 0.7379, auc_id_cosine: 0.9438, auc_id_euclidean: 0.9438
# --> SAVE BEST MODEL (auc_id_cosine: 0.9438)
# 	Saved best model weights for 'auc_id_cosine' at epoch 6 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_6.pth'
#
# --- Epoch 7/60 ---
#
# Ep 7:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 20.4736 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 19.7653 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.7082 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.978  │ 0.9452 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.978  │ 0.9452 │
# ╘══════════════════╧═════════╧════════╛
# Ep 7: loss: 20.4736, loss_task: 19.7653, loss_kd: 0.7082, auc_id_cosine: 0.9452, auc_id_euclidean: 0.9452
# --> SAVE BEST MODEL (auc_id_cosine: 0.9452)
# 	Saved best model weights for 'auc_id_cosine' at epoch 7 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_7.pth'
#
# --- Epoch 8/60 ---
#
# Ep 8:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 18.1106 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 17.4287 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.6819 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9816 │ 0.9445 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9816 │ 0.9445 │
# ╘══════════════════╧═════════╧════════╛
# Ep 8: loss: 18.1106, loss_task: 17.4287, loss_kd: 0.6819, auc_id_cosine: 0.9445, auc_id_euclidean: 0.9445
# 	Epoch 8: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 9/60 ---
#
# Ep 9:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 15.8434 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 15.1863 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.6571 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9858 │ 0.9467 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9858 │ 0.9467 │
# ╘══════════════════╧═════════╧════════╛
# Ep 9: loss: 15.8434, loss_task: 15.1863, loss_kd: 0.6571, auc_id_cosine: 0.9467, auc_id_euclidean: 0.9467
# --> SAVE BEST MODEL (auc_id_cosine: 0.9467)
# 	Saved best model weights for 'auc_id_cosine' at epoch 9 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_9.pth'
#
# --- Epoch 10/60 ---
#
# Ep 10:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 14.4681 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 13.831  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.6371 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9884 │ 0.9468 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9884 │ 0.9468 │
# ╘══════════════════╧═════════╧════════╛
# Ep 10: loss: 14.4681, loss_task: 13.8310, loss_kd: 0.6371, auc_id_cosine: 0.9468, auc_id_euclidean: 0.9468
# --> SAVE BEST MODEL (auc_id_cosine: 0.9468)
# 	Saved best model weights for 'auc_id_cosine' at epoch 10 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_10.pth'
#
# --- Epoch 11/60 ---
#
# Ep 11:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 13.3184 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 12.7017 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.6167 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9909 │ 0.9489 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9909 │ 0.9489 │
# ╘══════════════════╧═════════╧════════╛
# Ep 11: loss: 13.3184, loss_task: 12.7017, loss_kd: 0.6167, auc_id_cosine: 0.9489, auc_id_euclidean: 0.9489
# --> SAVE BEST MODEL (auc_id_cosine: 0.9489)
# 	Saved best model weights for 'auc_id_cosine' at epoch 11 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_11.pth'
#
# --- Epoch 12/60 ---
#
# Ep 12:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 12.0173 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 11.4195 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5978 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9914 │ 0.9480 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9914 │ 0.9480 │
# ╘══════════════════╧═════════╧════════╛
# Ep 12: loss: 12.0173, loss_task: 11.4195, loss_kd: 0.5978, auc_id_cosine: 0.9480, auc_id_euclidean: 0.9480
# 	Epoch 12: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 13/60 ---
#
# Ep 13:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 11.5084 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 10.9207 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5876 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9898 │ 0.9471 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9898 │ 0.9471 │
# ╘══════════════════╧═════════╧════════╛
# Ep 13: loss: 11.5084, loss_task: 10.9207, loss_kd: 0.5876, auc_id_cosine: 0.9471, auc_id_euclidean: 0.9471
# 	Epoch 13: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 14/60 ---
#
# Ep 14:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 10.5918 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 10.0196 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5722 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9914 │ 0.9501 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9914 │ 0.9501 │
# ╘══════════════════╧═════════╧════════╛
# Ep 14: loss: 10.5918, loss_task: 10.0196, loss_kd: 0.5722, auc_id_cosine: 0.9501, auc_id_euclidean: 0.9501
# --> SAVE BEST MODEL (auc_id_cosine: 0.9501)
# 	Saved best model weights for 'auc_id_cosine' at epoch 14 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_14.pth'
#
# --- Epoch 15/60 ---
#
# Ep 15:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 10.3739 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.8064 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5676 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9909 │ 0.9495 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9909 │ 0.9495 │
# ╘══════════════════╧═════════╧════════╛
# Ep 15: loss: 10.3739, loss_task: 9.8064, loss_kd: 0.5676, auc_id_cosine: 0.9495, auc_id_euclidean: 0.9495
# 	Epoch 15: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 16/60 ---
#
# Ep 16:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  9.8688 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.3121 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5567 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9902 │ 0.9507 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9902 │ 0.9507 │
# ╘══════════════════╧═════════╧════════╛
# Ep 16: loss: 9.8688, loss_task: 9.3121, loss_kd: 0.5567, auc_id_cosine: 0.9507, auc_id_euclidean: 0.9507
# --> SAVE BEST MODEL (auc_id_cosine: 0.9507)
# 	Saved best model weights for 'auc_id_cosine' at epoch 16 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_16.pth'
#
# --- Epoch 17/60 ---
#
# Ep 17:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  9.8965 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.3419 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5545 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9919 │ 0.9476 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9919 │ 0.9476 │
# ╘══════════════════╧═════════╧════════╛
# Ep 17: loss: 9.8965, loss_task: 9.3419, loss_kd: 0.5545, auc_id_cosine: 0.9476, auc_id_euclidean: 0.9476
# 	Epoch 17: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 18/60 ---
#
# Ep 18:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  9.8366 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.2848 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5518 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9906 │ 0.9485 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9906 │ 0.9485 │
# ╘══════════════════╧═════════╧════════╛
# Ep 18: loss: 9.8366, loss_task: 9.2848, loss_kd: 0.5518, auc_id_cosine: 0.9485, auc_id_euclidean: 0.9485
# 	Epoch 18: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 19/60 ---
#
# Ep 19:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  9.3858 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  8.8391 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5467 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9926 │ 0.9504 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9926 │ 0.9504 │
# ╘══════════════════╧═════════╧════════╛
# Ep 19: loss: 9.3858, loss_task: 8.8391, loss_kd: 0.5467, auc_id_cosine: 0.9504, auc_id_euclidean: 0.9504
# 	Epoch 19: EarlyStopping counter for 'auc_id_cosine': 3/10
#
# --- Epoch 20/60 ---
#
# Ep 20:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  9.4095 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  8.8623 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5471 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9919 │ 0.9491 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9919 │ 0.9491 │
# ╘══════════════════╧═════════╧════════╛
# Ep 20: loss: 9.4095, loss_task: 8.8623, loss_kd: 0.5471, auc_id_cosine: 0.9491, auc_id_euclidean: 0.9491
# 	Epoch 20: EarlyStopping counter for 'auc_id_cosine': 4/10
#
# --- Epoch 21/60 ---
#
# Ep 21:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  9.1032 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  8.562  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5412 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9929 │ 0.9519 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9929 │ 0.9519 │
# ╘══════════════════╧═════════╧════════╛
# Ep 21: loss: 9.1032, loss_task: 8.5620, loss_kd: 0.5412, auc_id_cosine: 0.9519, auc_id_euclidean: 0.9519
# --> SAVE BEST MODEL (auc_id_cosine: 0.9519)
# 	Saved best model weights for 'auc_id_cosine' at epoch 21 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_21.pth'
#
# --- Epoch 22/60 ---
#
# Ep 22:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  8.8015 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  8.2662 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5353 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.995  │ 0.9507 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.995  │ 0.9507 │
# ╘══════════════════╧═════════╧════════╛
# Ep 22: loss: 8.8015, loss_task: 8.2662, loss_kd: 0.5353, auc_id_cosine: 0.9507, auc_id_euclidean: 0.9507
# 	Epoch 22: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 23/60 ---
#
# Ep 23:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  8.36   │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  7.8443 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.5157 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9944 │ 0.9524 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9944 │ 0.9524 │
# ╘══════════════════╧═════════╧════════╛
# Ep 23: loss: 8.3600, loss_task: 7.8443, loss_kd: 0.5157, auc_id_cosine: 0.9524, auc_id_euclidean: 0.9524
# --> SAVE BEST MODEL (auc_id_cosine: 0.9524)
# 	Saved best model weights for 'auc_id_cosine' at epoch 23 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_23.pth'
#
# --- Epoch 24/60 ---
#
# Ep 24:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  7.5748 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  7.0774 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.4974 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9954 │ 0.9547 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9954 │ 0.9547 │
# ╘══════════════════╧═════════╧════════╛
# Ep 24: loss: 7.5748, loss_task: 7.0774, loss_kd: 0.4974, auc_id_cosine: 0.9547, auc_id_euclidean: 0.9547
# --> SAVE BEST MODEL (auc_id_cosine: 0.9547)
# 	Saved best model weights for 'auc_id_cosine' at epoch 24 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_24.pth'
#
# --- Epoch 25/60 ---
#
# Ep 25:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.8065 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  6.3288 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.4778 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9962 │ 0.9554 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9962 │ 0.9554 │
# ╘══════════════════╧═════════╧════════╛
# Ep 25: loss: 6.8065, loss_task: 6.3288, loss_kd: 0.4778, auc_id_cosine: 0.9554, auc_id_euclidean: 0.9554
# --> SAVE BEST MODEL (auc_id_cosine: 0.9554)
# 	Saved best model weights for 'auc_id_cosine' at epoch 25 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_25.pth'
#
# --- Epoch 26/60 ---
#
# Ep 26:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.0921 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  5.6379 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.4541 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9974 │ 0.9584 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9974 │ 0.9584 │
# ╘══════════════════╧═════════╧════════╛
# Ep 26: loss: 6.0921, loss_task: 5.6379, loss_kd: 0.4541, auc_id_cosine: 0.9584, auc_id_euclidean: 0.9584
# --> SAVE BEST MODEL (auc_id_cosine: 0.9584)
# 	Saved best model weights for 'auc_id_cosine' at epoch 26 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_26.pth'
#
# --- Epoch 27/60 ---
#
# Ep 27:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.8509 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  5.4094 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.4415 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9977 │ 0.9575 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9977 │ 0.9575 │
# ╘══════════════════╧═════════╧════════╛
# Ep 27: loss: 5.8509, loss_task: 5.4094, loss_kd: 0.4415, auc_id_cosine: 0.9575, auc_id_euclidean: 0.9575
# 	Epoch 27: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 28/60 ---
#
# Ep 28:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.379  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  4.9555 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.4235 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9982 │ 0.9614 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9982 │ 0.9614 │
# ╘══════════════════╧═════════╧════════╛
# Ep 28: loss: 5.3790, loss_task: 4.9555, loss_kd: 0.4235, auc_id_cosine: 0.9614, auc_id_euclidean: 0.9614
# --> SAVE BEST MODEL (auc_id_cosine: 0.9614)
# 	Saved best model weights for 'auc_id_cosine' at epoch 28 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_28.pth'
#
# --- Epoch 29/60 ---
#
# Ep 29:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.9449 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  4.5321 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.4128 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9974 │ 0.9611 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9974 │ 0.9611 │
# ╘══════════════════╧═════════╧════════╛
# Ep 29: loss: 4.9449, loss_task: 4.5321, loss_kd: 0.4128, auc_id_cosine: 0.9611, auc_id_euclidean: 0.9611
# 	Epoch 29: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 30/60 ---
#
# Ep 30:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.6175 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  4.2197 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3978 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9985 │ 0.9636 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9985 │ 0.9636 │
# ╘══════════════════╧═════════╧════════╛
# Ep 30: loss: 4.6175, loss_task: 4.2197, loss_kd: 0.3978, auc_id_cosine: 0.9636, auc_id_euclidean: 0.9636
# --> SAVE BEST MODEL (auc_id_cosine: 0.9636)
# 	Saved best model weights for 'auc_id_cosine' at epoch 30 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_30.pth'
#
# --- Epoch 31/60 ---
#
# Ep 31:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.3707 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.9879 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3828 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9987 │ 0.9610 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9987 │ 0.9610 │
# ╘══════════════════╧═════════╧════════╛
# Ep 31: loss: 4.3707, loss_task: 3.9879, loss_kd: 0.3828, auc_id_cosine: 0.9610, auc_id_euclidean: 0.9610
# 	Epoch 31: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 32/60 ---
#
# Ep 32:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.185  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.8115 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3735 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9983 │ 0.9630 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9983 │ 0.9630 │
# ╘══════════════════╧═════════╧════════╛
# Ep 32: loss: 4.1850, loss_task: 3.8115, loss_kd: 0.3735, auc_id_cosine: 0.9630, auc_id_euclidean: 0.9630
# 	Epoch 32: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 33/60 ---
#
# Ep 33:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.9934 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.6309 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3625 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9985 │ 0.9632 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9985 │ 0.9632 │
# ╘══════════════════╧═════════╧════════╛
# Ep 33: loss: 3.9934, loss_task: 3.6309, loss_kd: 0.3625, auc_id_cosine: 0.9632, auc_id_euclidean: 0.9632
# 	Epoch 33: EarlyStopping counter for 'auc_id_cosine': 3/10
#
# --- Epoch 34/60 ---
#
# Ep 34:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.9019 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.5484 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3535 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9613 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9613 │
# ╘══════════════════╧═════════╧════════╛
# Ep 34: loss: 3.9019, loss_task: 3.5484, loss_kd: 0.3535, auc_id_cosine: 0.9613, auc_id_euclidean: 0.9613
# 	Epoch 34: EarlyStopping counter for 'auc_id_cosine': 4/10
#
# --- Epoch 35/60 ---
#
# Ep 35:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.9516 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.6022 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3493 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9992 │ 0.9617 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9992 │ 0.9617 │
# ╘══════════════════╧═════════╧════════╛
# Ep 35: loss: 3.9516, loss_task: 3.6022, loss_kd: 0.3493, auc_id_cosine: 0.9617, auc_id_euclidean: 0.9617
# 	Epoch 35: EarlyStopping counter for 'auc_id_cosine': 5/10
#
# --- Epoch 36/60 ---
#
# Ep 36:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.6808 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.3402 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3405 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9995 │ 0.9635 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9995 │ 0.9635 │
# ╘══════════════════╧═════════╧════════╛
# Ep 36: loss: 3.6808, loss_task: 3.3402, loss_kd: 0.3405, auc_id_cosine: 0.9635, auc_id_euclidean: 0.9635
# 	Epoch 36: EarlyStopping counter for 'auc_id_cosine': 6/10
#
# --- Epoch 37/60 ---
#
# Ep 37:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.5293 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.1982 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3311 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9613 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9613 │
# ╘══════════════════╧═════════╧════════╛
# Ep 37: loss: 3.5293, loss_task: 3.1982, loss_kd: 0.3311, auc_id_cosine: 0.9613, auc_id_euclidean: 0.9613
# 	Epoch 37: EarlyStopping counter for 'auc_id_cosine': 7/10
#
# --- Epoch 38/60 ---
#
# Ep 38:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.3505 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.027  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3235 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9996 │ 0.9640 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9996 │ 0.9640 │
# ╘══════════════════╧═════════╧════════╛
# Ep 38: loss: 3.3505, loss_task: 3.0270, loss_kd: 0.3235, auc_id_cosine: 0.9640, auc_id_euclidean: 0.9640
# --> SAVE BEST MODEL (auc_id_cosine: 0.9640)
# 	Saved best model weights for 'auc_id_cosine' at epoch 38 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_38.pth'
#
# --- Epoch 39/60 ---
#
# Ep 39:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.4214 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.1008 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3206 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9996 │ 0.9623 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9996 │ 0.9623 │
# ╘══════════════════╧═════════╧════════╛
# Ep 39: loss: 3.4214, loss_task: 3.1008, loss_kd: 0.3206, auc_id_cosine: 0.9623, auc_id_euclidean: 0.9623
# 	Epoch 39: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 40/60 ---
#
# Ep 40:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.2073 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.8987 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3086 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9996 │ 0.9633 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9996 │ 0.9633 │
# ╘══════════════════╧═════════╧════════╛
# Ep 40: loss: 3.2073, loss_task: 2.8987, loss_kd: 0.3086, auc_id_cosine: 0.9633, auc_id_euclidean: 0.9633
# 	Epoch 40: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 41/60 ---
#
# Ep 41:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.0815 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.7761 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3054 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9996 │ 0.9641 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9996 │ 0.9641 │
# ╘══════════════════╧═════════╧════════╛
# Ep 41: loss: 3.0815, loss_task: 2.7761, loss_kd: 0.3054, auc_id_cosine: 0.9641, auc_id_euclidean: 0.9641
# --> SAVE BEST MODEL (auc_id_cosine: 0.9641)
# 	Saved best model weights for 'auc_id_cosine' at epoch 41 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_41.pth'
#
# --- Epoch 42/60 ---
#
# Ep 42:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.1318 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.8318 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.3    │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9996 │ 0.9634 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9996 │ 0.9634 │
# ╘══════════════════╧═════════╧════════╛
# Ep 42: loss: 3.1318, loss_task: 2.8318, loss_kd: 0.3000, auc_id_cosine: 0.9634, auc_id_euclidean: 0.9634
# 	Epoch 42: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 43/60 ---
#
# Ep 43:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.1701 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.871  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2991 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9994 │ 0.9646 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9994 │ 0.9646 │
# ╘══════════════════╧═════════╧════════╛
# Ep 43: loss: 3.1701, loss_task: 2.8710, loss_kd: 0.2991, auc_id_cosine: 0.9646, auc_id_euclidean: 0.9646
# --> SAVE BEST MODEL (auc_id_cosine: 0.9646)
# 	Saved best model weights for 'auc_id_cosine' at epoch 43 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_43.pth'
#
# --- Epoch 44/60 ---
#
# Ep 44:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  2.9833 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.6923 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.291  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9654 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9654 │
# ╘══════════════════╧═════════╧════════╛
# Ep 44: loss: 2.9833, loss_task: 2.6923, loss_kd: 0.2910, auc_id_cosine: 0.9654, auc_id_euclidean: 0.9654
# --> SAVE BEST MODEL (auc_id_cosine: 0.9654)
# 	Saved best model weights for 'auc_id_cosine' at epoch 44 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_44.pth'
#
# --- Epoch 45/60 ---
#
# Ep 45:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.0951 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.7993 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2958 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9996 │ 0.9636 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9996 │ 0.9636 │
# ╘══════════════════╧═════════╧════════╛
# Ep 45: loss: 3.0951, loss_task: 2.7993, loss_kd: 0.2958, auc_id_cosine: 0.9636, auc_id_euclidean: 0.9636
# 	Epoch 45: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 46/60 ---
#
# Ep 46:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.0804 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.7935 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2869 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9644 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9644 │
# ╘══════════════════╧═════════╧════════╛
# Ep 46: loss: 3.0804, loss_task: 2.7935, loss_kd: 0.2869, auc_id_cosine: 0.9644, auc_id_euclidean: 0.9644
# 	Epoch 46: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 47/60 ---
#
# Ep 47:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  2.9815 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.6938 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2878 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9996 │ 0.9649 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9996 │ 0.9649 │
# ╘══════════════════╧═════════╧════════╛
# Ep 47: loss: 2.9815, loss_task: 2.6938, loss_kd: 0.2878, auc_id_cosine: 0.9649, auc_id_euclidean: 0.9649
# 	Epoch 47: EarlyStopping counter for 'auc_id_cosine': 3/10
#
# --- Epoch 48/60 ---
#
# Ep 48:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  2.9507 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.6686 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2821 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9998 │ 0.9661 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9998 │ 0.9661 │
# ╘══════════════════╧═════════╧════════╛
# Ep 48: loss: 2.9507, loss_task: 2.6686, loss_kd: 0.2821, auc_id_cosine: 0.9661, auc_id_euclidean: 0.9661
# --> SAVE BEST MODEL (auc_id_cosine: 0.9661)
# 	Saved best model weights for 'auc_id_cosine' at epoch 48 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_projector(weight1-1)/checkpoints/best_auc_id_cosine_48.pth'
#
# --- Epoch 49/60 ---
#
# Ep 49:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  2.8223 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.5439 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2784 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9993 │ 0.9655 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9993 │ 0.9655 │
# ╘══════════════════╧═════════╧════════╛
# Ep 49: loss: 2.8223, loss_task: 2.5439, loss_kd: 0.2784, auc_id_cosine: 0.9655, auc_id_euclidean: 0.9655
# 	Epoch 49: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 50/60 ---
#
# Ep 50:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  2.8369 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.5591 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2778 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9996 │ 0.9645 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9996 │ 0.9645 │
# ╘══════════════════╧═════════╧════════╛
# Ep 50: loss: 2.8369, loss_task: 2.5591, loss_kd: 0.2778, auc_id_cosine: 0.9645, auc_id_euclidean: 0.9645
# 	Epoch 50: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 51/60 ---
#
# Ep 51:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  2.7529 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4812 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2717 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9659 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9659 │
# ╘══════════════════╧═════════╧════════╛
# Ep 51: loss: 2.7529, loss_task: 2.4812, loss_kd: 0.2717, auc_id_cosine: 0.9659, auc_id_euclidean: 0.9659
# 	Epoch 51: EarlyStopping counter for 'auc_id_cosine': 3/10
#
# --- Epoch 52/60 ---
#
# Ep 52:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  2.7692 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4972 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2721 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9652 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9652 │
# ╘══════════════════╧═════════╧════════╛
# Ep 52: loss: 2.7692, loss_task: 2.4972, loss_kd: 0.2721, auc_id_cosine: 0.9652, auc_id_euclidean: 0.9652
# 	Epoch 52: EarlyStopping counter for 'auc_id_cosine': 4/10
#
# --- Epoch 53/60 ---
#
# Ep 53:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  2.7895 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.5156 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2739 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9998 │ 0.9635 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9998 │ 0.9635 │
# ╘══════════════════╧═════════╧════════╛
# Ep 53: loss: 2.7895, loss_task: 2.5156, loss_kd: 0.2739, auc_id_cosine: 0.9635, auc_id_euclidean: 0.9635
# 	Epoch 53: EarlyStopping counter for 'auc_id_cosine': 5/10
#
# --- Epoch 54/60 ---
#
# Ep 54:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  2.8364 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.559  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2774 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9654 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9654 │
# ╘══════════════════╧═════════╧════════╛
# Ep 54: loss: 2.8364, loss_task: 2.5590, loss_kd: 0.2774, auc_id_cosine: 0.9654, auc_id_euclidean: 0.9654
# 	Epoch 54: EarlyStopping counter for 'auc_id_cosine': 6/10
#
# --- Epoch 55/60 ---
#
# Ep 55:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  2.7535 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4806 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2729 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9998 │ 0.9648 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9998 │ 0.9648 │
# ╘══════════════════╧═════════╧════════╛
# Ep 55: loss: 2.7535, loss_task: 2.4806, loss_kd: 0.2729, auc_id_cosine: 0.9648, auc_id_euclidean: 0.9648
# 	Epoch 55: EarlyStopping counter for 'auc_id_cosine': 7/10
#
# --- Epoch 56/60 ---
#
# Ep 56:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  2.7166 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4458 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2708 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9646 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9646 │
# ╘══════════════════╧═════════╧════════╛
# Ep 56: loss: 2.7166, loss_task: 2.4458, loss_kd: 0.2708, auc_id_cosine: 0.9646, auc_id_euclidean: 0.9646
# 	Epoch 56: EarlyStopping counter for 'auc_id_cosine': 8/10
#
# --- Epoch 57/60 ---
#
# Ep 57:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  2.7459 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4737 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.2722 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9629 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9629 │
# ╘══════════════════╧═════════╧════════╛
# Ep 57: loss: 2.7459, loss_task: 2.4737, loss_kd: 0.2722, auc_id_cosine: 0.9629, auc_id_euclidean: 0.9629
# 	Epoch 57: EarlyStopping counter for 'auc_id_cosine': 9/10
#
# --- Epoch 58/60 ---
#
# Ep 58:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  2.7241 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.4561 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.268  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9999 │ 0.9645 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9999 │ 0.9645 │
# ╘══════════════════╧═════════╧════════╛
# Ep 58: loss: 2.7241, loss_task: 2.4561, loss_kd: 0.2680, auc_id_cosine: 0.9645, auc_id_euclidean: 0.9645
# 	Epoch 58: EarlyStopping counter for 'auc_id_cosine': 10/10
# 	Early stopping triggered at epoch 58 as all metrics exceeded patience.
# Early stopping triggered.
# KNOWLEDGE DISTILLATION HOAN TAT.

# %% [markdown]
# ## 8. Resume Training từ Checkpoint
#
# > Chạy cell này khi Colab disconnect và muốn tiếp tục train.
# > Checkpoint đã được ghi thẳng vào Drive nên không bị mất.
# >
# > **Cách dùng:** Chạy cell Setup → Imports → Data → Teacher → Student → Loss → Setup Train,
# > sau đó chạy cell này (không chạy cell fit ở trên), rồi chạy lại cell fit.

# %%
CKPT_PATH = os.path.join(manager.ckpt_dir, 'last_model.pth')

if not os.path.exists(CKPT_PATH):
    raise FileNotFoundError(f'Không tìm thấy checkpoint: {CKPT_PATH}')

checkpoint = torch.load(CKPT_PATH, map_location=device, weights_only=False)


student.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
if 'scheduler_state_dict' in checkpoint:
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
if 'projector_state_dict' in checkpoint:
    projector.load_state_dict(checkpoint['projector_state_dict'])
    print('Projector state loaded.')
else:
    print('Không tìm thấy projector_state_dict — projector khởi tạo ngẫu nhiên.')

START_EPOCH = checkpoint['epoch']
print(f'Resume từ epoch {START_EPOCH} — chạy lại cell "cell-fit" để tiếp tục.')
# Out:
# Projector state loaded.
# Resume từ epoch 40 — chạy lại cell "cell-fit" để tiếp tục.

# %% [markdown]
# ## 9. Đánh giá Final

# %%
best_ckpt_path = os.path.join(manager.ckpt_dir, 'best_model.pth')
best_ckpt = torch.load(best_ckpt_path, map_location=device, weights_only=False)
student.load_state_dict(best_ckpt['model_state_dict'])
student.eval()
# print(f"Best model từ epoch {best_ckpt.get('epoch', '?')}")

student_gp_auc   = compute_id_auc_gallery_probe(gallery_dl, probe_dl, student, device)
student_gp_rank1 = compute_rank1_gallery_probe(gallery_dl, probe_dl, student, device)

rows = [
    ['Cosine AUC    (gallery→probe)', f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)', f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)', f"{student_gp_rank1:.4f}"],
]
print(f"\nStudent ({CONFIGURATION['backbone']}) — KD from {CONFIGURATION['teacher_backbone']}")
print(tabulate(rows, headers=['Metric', 'Value'], tablefmt='fancy_grid'))

# So sánh Teacher vs Student
compare_rows = [
    ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
    ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
    ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
]
print('\n--- Teacher vs Student (KD) ---')
print(tabulate(compare_rows, headers=['Metric', 'Teacher', 'Student (KD)'], tablefmt='fancy_grid'))
# Out:
# Student (mobilenetv3_large_100) — KD from convnextv2_tiny
# ╒═══════════════════════════════╤═════════╕
# │ Metric                        │   Value │
# ╞═══════════════════════════════╪═════════╡
# │ Cosine AUC    (gallery→probe) │  0.972  │
# ├───────────────────────────────┼─────────┤
# │ Euclidean AUC (gallery→probe) │  0.972  │
# ├───────────────────────────────┼─────────┤
# │ Rank-1 Acc    (gallery→probe) │  0.7431 │
# ╘═══════════════════════════════╧═════════╛
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2096/1905580024.py in <cell line: 0>()
#      20     ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
#      21     ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
# ---> 22     ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
#      23     ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
#      24     ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
#
# NameError: name 'teacher_gp_auc' is not defined

# %% [markdown]
# ## 10. Export ONNX
#
# Export phần inference (backbone + embedding + L2 normalize, bỏ MagLinear)
# để chuẩn bị quantize INT8 deploy edge device.

# %%
class InferenceWrapper(nn.Module):
    """Backbone + embedding + L2 normalize — không có MagLinear."""
    def __init__(self, model):
        super().__init__()
        self.backbone  = model.backbone
        self.embedding = model.embedding

    def forward(self, x):
        emb = self.embedding(self.backbone(x))
        return F.normalize(emb, p=2, dim=1)


inference_model = InferenceWrapper(student).eval().cpu()
dummy_input = torch.randn(1, 3, 112, 112)

# Lưu vào Drive để không mất
onnx_path = os.path.join(manager.ckpt_dir, 'kd_mobilenetv3_fr.onnx')

torch.onnx.export(
    inference_model,
    dummy_input,
    onnx_path,
    input_names=['input'],
    output_names=['embedding'],
    dynamic_axes={'input': {0: 'batch'}, 'embedding': {0: 'batch'}},
    opset_version=17,
)
print(f'Exported ONNX: {onnx_path}')

# %%
best_ckpt_path = os.path.join(manager.ckpt_dir, 'best_model.pth')
best_ckpt = torch.load(best_ckpt_path, map_location=device, weights_only=False)
student.load_state_dict(best_ckpt['model_state_dict'])
student.eval()
print(f"Best model từ epoch {best_ckpt.get('epoch', '?')}")

student_gp_auc   = compute_id_auc_gallery_probe(gallery_dl, probe_dl, student, device)
student_gp_rank1 = compute_rank1_gallery_probe(gallery_dl, probe_dl, student, device)

rows = [
    ['Cosine AUC    (gallery→probe)', f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)', f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)', f"{student_gp_rank1:.4f}"],
]
print(f"\nStudent ({CONFIGURATION['backbone']}) — KD from {CONFIGURATION['teacher_backbone']}")
print(tabulate(rows, headers=['Metric', 'Value'], tablefmt='fancy_grid'))

# So sánh Teacher vs Student
compare_rows = [
    ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
    ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
    ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
]
print('\n--- Teacher vs Student (KD) ---')
print(tabulate(compare_rows, headers=['Metric', 'Teacher', 'Student (KD)'], tablefmt='fancy_grid'))
# Out:
# Best model từ epoch 48
#
# Student (mobilenetv3_large_100) — KD from convnextv2_tiny
# ╒═══════════════════════════════╤═════════╕
# │ Metric                        │   Value │
# ╞═══════════════════════════════╪═════════╡
# │ Cosine AUC    (gallery→probe) │  0.9739 │
# ├───────────────────────────────┼─────────┤
# │ Euclidean AUC (gallery→probe) │  0.9739 │
# ├───────────────────────────────┼─────────┤
# │ Rank-1 Acc    (gallery→probe) │  0.75   │
# ╘═══════════════════════════════╧═════════╛
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2096/3485715062.py in <cell line: 0>()
#      20     ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
#      21     ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
# ---> 22     ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
#      23     ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
#      24     ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
#
# NameError: name 'teacher_gp_auc' is not defined
