# %% [markdown]
# # Knowledge Distillation: ConvNeXt V2 → MobileNetV3 (Colab)
#
# **Mục tiêu:** Dùng ID embedding 512-D của teacher ConvNeXt V2 (đã train MTL) để hướng dẫn student MobileNetV3 học compact embedding cho face recognition.
#
# | | Teacher | Student |
# |---|---|---|
# | Model | `MTLFaceRecognition` (ConvNeXt V2) | `FaceRecognitionMobileNetV3` |
# | Params | ~28M | ~5M |
# | Embedding dùng cho KD | `x_id` (512-D, tầng cuối) | 512-D |
# | Mode | **Frozen** | **Trainable** |
#
# **KD Loss:**
# ```
# L_total = α · L_MagFace(student)  +  β · L_KD
# L_KD    = mean(1 - cosine_sim(norm(s_emb), norm(t_emb)))
# ```
#
# **Cách dùng:**
# 1. Mount Google Drive (cell 1)
# 2. Sửa `CONFIGURATION` và `TEACHER_CKPT` (cell Config)
# 3. Chạy từ trên xuống

# %% [markdown]
# ## 1. Mount Drive & Setup môi trường

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

REPO_URL    = 'https://github.com/NguyenXuanBinh22/DATN.git'
REPO_BRANCH = 'convnext-v2-dev'
REPO_DIR    = '/content/FR_Photometric_Stereo'

if not os.path.exists(REPO_DIR):
    os.system(f'git clone -b {REPO_BRANCH} {REPO_URL} {REPO_DIR}')
else:
    os.system(f'git -C {REPO_DIR} pull origin {REPO_BRANCH}')
    print('Repo đã tồn tại, đã pull latest.')

# %cd {REPO_DIR}
print(f'Working dir: {os.getcwd()}')

os.system('pip install -q albumentations==1.3.1 timm tabulate termcolor')
# Out:
# Mounted at /content/drive
# /content/FR_Photometric_Stereo
# Working dir: /content/FR_Photometric_Stereo
# 0

# %% [markdown]
# ## 2. Imports & Cấu hình

# %%
# %cd /content/FR_Photometric_Stereo
import warnings
warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import albumentations as A
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
from torch.utils.tensorboard import SummaryWriter
from tabulate import tabulate

from going_modular.dataloader.multitask import create_multitask_datafetcher, create_eval_loaders
from going_modular.model.MTLFaceRecognition import MTLFaceRecognition
from going_modular.model.FaceRecognitionMobileNetV3 import FaceRecognitionMobileNetV3
from going_modular.loss.WeightClassMagLoss import WeightClassMagLoss
from going_modular.utils.transforms import RandomResizedCropRect, GaussianNoise
from going_modular.utils.roc_auc_id import (
    compute_id_auc, compute_rank1,
    compute_id_auc_gallery_probe, compute_rank1_gallery_probe,
)
from going_modular.utils.MultiMetricEarlyStopping import MultiMetricEarlyStopping
from going_modular.utils.ModelCheckPoint import ModelCheckpoint
from going_modular.utils.ExperimentManager import ExperimentManager

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(42)
print(f'Device: {device}')
if device == 'cuda':
    print(f'GPU: {torch.cuda.get_device_name(0)}')
# Out:
# /content/FR_Photometric_Stereo
# Device: cuda
# GPU: Tesla T4

# %%
# ════════════════════════════════════════════════════════════
#  CẤU HÌNH — chỉnh sửa ở đây
# ════════════════════════════════════════════════════════════

# Đường dẫn dataset trên Google Drive
DRIVE_DATASET_DIR = '/content/drive/MyDrive/Photometric_DB_Full/'

# Checkpoint teacher ConvNeXt V2 đã train (best_model.pth hoặc last_model.pth)
# Ví dụ: '/content/drive/MyDrive/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth'
TEACHER_CKPT = '/content/drive/MyDrive/Photometric_DB_Full/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth'

EXPERIMENT_NAME = 'KD_ConvNextV2_to_MobileNetV3_Albedo_25'

CONFIGURATION = {
    'note':        EXPERIMENT_NAME,
    'dataset_dir': DRIVE_DATASET_DIR,

    # Ghi checkpoint và log vào Drive để không mất khi Colab disconnect
    'output_dir':  '/content/drive/MyDrive/',

    # Modality: 'albedo' | 'normalmap' | 'depthmap'
    # Phải giống modality mà teacher đã được train
    'type':        'albedo',

    # Teacher backbone (để tái tạo đúng kiến trúc khi load checkpoint)
    'teacher_backbone': 'convnextv2_tiny',

    # Student backbone
    'backbone':    'mobilenetv3_large_100',

    'use_sampler': True,   # PK Sampler — mỗi batch gồm batch_size identity khác nhau
    'device':      device,
    'epochs':      40,
    'batch_size':  32,
    'image_size':  112,
    'base_lr':     1e-4,
    'num_classes': None,   # tự động lấy từ CSV

    # Trọng số loss
    # L_total = task_weight * L_MagFace + kd_weight * L_KD
    'task_weight': 1.0,
    'kd_weight':   1.0,
}

print(f"Dataset dir : {CONFIGURATION['dataset_dir']}")
print(f"Output dir  : {CONFIGURATION['output_dir']}")
print(f"Teacher ckpt: {TEACHER_CKPT}")
# Out:
# Dataset dir : /content/drive/MyDrive/Photometric_DB_Full/
# Output dir  : /content/drive/MyDrive/
# Teacher ckpt: /content/drive/MyDrive/Photometric_DB_Full/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth

# %% [markdown]
# ## 3. Data Loading
#
# Dùng **cùng transform** với ConvNeXt V2 để student và teacher nhận cùng input trong mỗi batch.

# %%
dataset_dir = CONFIGURATION['dataset_dir']

# Tìm CSV — hỗ trợ cả hai cấu trúc thư mục
train_csv = os.path.join(dataset_dir, 'train_split.csv')
if not os.path.exists(train_csv):
    train_csv = os.path.join(dataset_dir, 'dataset', 'train_split.csv')
if not os.path.exists(train_csv):
    train_csv = os.path.join(dataset_dir, 'train_set.csv')
if not os.path.exists(train_csv):
    raise FileNotFoundError(
        f'Không tìm thấy CSV train tại {dataset_dir}.\n'
        f'Kiểm tra lại DRIVE_DATASET_DIR.'
    )
print(f'Train CSV: {train_csv}')

df_train = pd.read_csv(train_csv)
CONFIGURATION['num_classes'] = int(df_train['id'].nunique())
print(f'num_classes : {CONFIGURATION["num_classes"]}')
print(f'Số mẫu train: {len(df_train)}')

# Transform — giống hệt ConvNeXt V2 pipeline
train_transform = A.Compose([
    RandomResizedCropRect(CONFIGURATION['image_size']),
    GaussianNoise(p=0.2),
    A.HorizontalFlip(p=0.5),
])
test_transform = A.Compose([
    A.Resize(CONFIGURATION['image_size'], CONFIGURATION['image_size']),
])

# Training dataloader — probe_split.csv dùng để monitor AUC trong vòng lặp train
train_dl, test_dl, _ = create_multitask_datafetcher(
    CONFIGURATION, train_transform, test_transform, 'train_split.csv', 'probe_split.csv'
)
print(f'Train batches: {len(train_dl)} | Test batches (probe): {len(test_dl)}')

# Gallery-probe loaders — CHỈ dùng cho đánh giá cuối, không dùng trong training
# gallery_split.csv: reference set | probe_split.csv: query set
gallery_dl, probe_dl = create_eval_loaders(CONFIGURATION, test_transform)
# Out:
# Train CSV: /content/drive/MyDrive/Photometric_DB_Full/train_split.csv
# num_classes : 352
# Số mẫu train: 2622
# >>> SingleLoader: MODE = PK SAMPLER
# Train batches: 81 | Test batches (probe): 9
# Gallery: 68 ảnh | Probe: 288 ảnh
# Shared identity space: 68 identities

# %% [markdown]
# ## 4. Teacher Model (ConvNeXt V2 — Frozen)
#
# Load checkpoint đã train, freeze toàn bộ weights.
# Chỉ dùng `get_embedding(x)[-1]` để lấy **ID embedding** (`x_id`, tầng embedding cuối).

# %%
if not os.path.exists(TEACHER_CKPT):
    raise FileNotFoundError(
        f'Không tìm thấy teacher checkpoint: {TEACHER_CKPT}\n'
        f'Kiểm tra lại biến TEACHER_CKPT.'
    )

# Khởi tạo teacher với đúng kiến trúc
teacher = MTLFaceRecognition(
    backbone=CONFIGURATION['teacher_backbone'],
    num_classes=CONFIGURATION['num_classes'],
)

# Load weights
ckpt = torch.load(TEACHER_CKPT, map_location=device, weights_only=False)
state_dict = ckpt['model_state_dict']

# Remove keys related to the id_head.maglinear layer to avoid size mismatch errors
# This layer is not needed as the teacher is used for feature extraction only
keys_to_remove = [k for k in state_dict.keys() if 'id_head.maglinear' in k]
for k in keys_to_remove:
    del state_dict[k]

teacher.load_state_dict(ckpt['model_state_dict'], strict=False)  # strict=False để bỏ qua nếu có layers mới (như classifier)
print(f"Teacher loaded — epoch {ckpt.get('epoch', '?')}")

# Freeze hoàn toàn
teacher.to(device)
teacher.eval()
for p in teacher.parameters():
    p.requires_grad = False

teacher_params = sum(p.numel() for p in teacher.parameters())
print(f'Teacher params: {teacher_params:,} (tất cả frozen)')

# Smoke test — kiểm tra embedding shape
with torch.no_grad():
    _dummy = torch.randn(2, 3, 112, 112).to(device)
    # get_embedding() trả về (x_spec, x_fh, x_pose, x_emot, x_gender, x_id)
    _t_emb = teacher.get_embedding(_dummy)[-1]   # x_id
    print(f'Teacher ID embedding shape: {_t_emb.shape}')   # mong đợi [2, 512]
# Out:
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# Teacher loaded — epoch 28
# Teacher params: 45,670,280 (tất cả frozen)
# Teacher ID embedding shape: torch.Size([2, 512])

# %% [markdown]
# ## 4.1. Đánh giá Teacher Model (baseline)
#
# Đo AUC của teacher trên train/test set **trước khi distillation** để có baseline so sánh với student sau này.

# %%
class _TeacherEvalWrapper(torch.nn.Module):
    """MTLFaceRecognition.get_embedding() trả về tuple — wrapper giữ lại x_id (index -1)."""
    def __init__(self, teacher):
        super().__init__()
        self._teacher = teacher

    def get_embedding(self, x):
        return self._teacher.get_embedding(x)[-1]   # x_id: [B, 512]


teacher_wrapper = _TeacherEvalWrapper(teacher).to(device)
teacher_wrapper.eval()

teacher_gp_auc   = compute_id_auc_gallery_probe(gallery_dl, probe_dl, teacher_wrapper, device)
teacher_gp_rank1 = compute_rank1_gallery_probe(gallery_dl, probe_dl, teacher_wrapper, device)

rows = [
    ['Cosine AUC    (gallery→probe)', f"{teacher_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)', f"{teacher_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)', f"{teacher_gp_rank1:.4f}"],
]
print(f"Teacher ({CONFIGURATION['teacher_backbone']}) — weight: {TEACHER_CKPT}")
print(tabulate(rows, headers=['Metric', 'Value'], tablefmt='fancy_grid'))
# Out:
# Teacher (convnextv2_tiny) — weight: /content/drive/MyDrive/Photometric_DB_Full/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth
# ╒═══════════════════════════════╤═════════╕
# │ Metric                        │   Value │
# ╞═══════════════════════════════╪═════════╡
# │ Cosine AUC    (gallery→probe) │  0.9761 │
# ├───────────────────────────────┼─────────┤
# │ Euclidean AUC (gallery→probe) │  0.9761 │
# ├───────────────────────────────┼─────────┤
# │ Rank-1 Acc    (gallery→probe) │  0.8021 │
# ╘═══════════════════════════════╧═════════╛

# %% [markdown]
# ## 5. Student Model (MobileNetV3 — Trainable)

# %%
student = FaceRecognitionMobileNetV3(
    num_classes=CONFIGURATION['num_classes'],
    backbone=CONFIGURATION['backbone'],
)
student.to(device)

total_p     = sum(p.numel() for p in student.parameters())
trainable_p = sum(p.numel() for p in student.parameters() if p.requires_grad)
print(f'Student total params    : {total_p:,}')
print(f'Student trainable params: {trainable_p:,}')

# Smoke test
with torch.no_grad():
    _s_emb = student.get_embedding(_dummy)
    print(f'Student embedding shape: {_s_emb.shape}')   # mong đợi [2, 512]
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/22.1M [00:00<?, ?B/s]
# WARNING:timm.models._builder:Unexpected keys (classifier.bias, classifier.weight, conv_head.bias, conv_head.weight) found while loading pretrained weights. This may be expected if model is being adapted.
# Student total params    : 3,646,256
# Student trainable params: 3,646,256
# Student embedding shape: torch.Size([2, 512])

# %% [markdown]
# ## 6. Knowledge Distillation Loss
#
# ```
# L_total = α · L_MagFace  +  β · L_KD
#
# L_MagFace : WeightClassMagFace — phân biệt class boundaries cho student
# L_KD      : Cosine distance giữa student emb và teacher ID emb
#            = mean(1 - cos_sim(norm(s_emb), norm(t_emb)))
# ```
#
# **Tại sao cosine loss:**
# Face verification so sánh *hướng* của embedding (cosine sim), không phải magnitude.
# Cosine loss kéo student về đúng hướng mà không ràng buộc magnitude.

# %%
class KDLoss(nn.Module):
    """
    L_total = task_weight * L_MagFace  +  kd_weight * L_KD_cosine
    """

    def __init__(self, metadata_path: str, task_weight: float = 1.0, kd_weight: float = 1.0):
        super().__init__()
        self.magface = WeightClassMagLoss(metadata_path)
        self.task_w  = task_weight
        self.kd_w    = kd_weight

    def forward(
        self,
        student_logits,   # [cos_theta, cos_theta_m] từ MagLinear
        student_norm,     # x_norm từ MagLinear
        student_emb,      # [B, 512] — embedding trước MagLinear
        teacher_emb,      # [B, 512] — ID embedding của teacher (no_grad)
        id_labels,        # [B] — ground-truth identity
    ):
        # Task loss
        l_task = self.magface(student_logits, id_labels, student_norm)

        # KD loss — cosine distance trên unit hypersphere
        s_n = F.normalize(student_emb, p=2, dim=1)
        t_n = F.normalize(teacher_emb, p=2, dim=1)
        l_kd = (1.0 - F.cosine_similarity(s_n, t_n, dim=1)).mean()

        total = self.task_w * l_task + self.kd_w * l_kd
        return total, l_task, l_kd


criterion = KDLoss(
    metadata_path=train_csv,
    task_weight=CONFIGURATION['task_weight'],
    kd_weight=CONFIGURATION['kd_weight'],
)
print('KDLoss khởi tạo thành công.')
# Out:
# KDLoss khởi tạo thành công.

# %% [markdown]
# ## 7. Training

# %%
def train_epoch(train_dl, teacher, student, criterion, optimizer, device):
    student.train()
    # teacher.eval() + frozen — không cần đặt lại mỗi epoch

    total_loss = total_task = total_kd = 0.0

    for X, y in train_dl:
        X, y = X.to(device), y.to(device)
        id_labels = y[:, 0]   # chỉ cần identity label

        # Teacher forward — no gradient, không update weights
        with torch.no_grad():
            # get_embedding() → (x_spec, x_fh, x_pose, x_emot, x_gender, x_id)
            teacher_emb = teacher.get_embedding(X)[-1]   # x_id: [B, 512]

        # Student forward — một lần duy nhất để lấy cả embedding lẫn logits
        feat         = student.backbone(X)          # [B, 512, H, W]
        student_emb  = student.embedding(feat)      # [B, 512]
        logits, norm = student.maglinear(student_emb)

        # Loss tổng hợp
        loss, l_task, l_kd = criterion(
            logits, norm, student_emb, teacher_emb, id_labels
        )

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        total_task += l_task.item()
        total_kd   += l_kd.item()

    n = len(train_dl)
    return total_loss / n, total_task / n, total_kd / n


def display_metrics(epoch, train_metrics, test_metrics):
    rows = []
    for k in train_metrics:
        tv = train_metrics[k]
        ev = test_metrics.get(k, '-')
        fmt = lambda v: f'{v:.4f}' if isinstance(v, float) else str(v)
        rows.append([k, fmt(tv), fmt(ev)])
    print(f'\nEp {epoch}:')
    print(tabulate(rows, headers=['Metric', 'Train', 'Test'], tablefmt='fancy_grid'))

# %%
optimizer = Adam(student.parameters(), lr=CONFIGURATION['base_lr'])
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=20, T_mult=2, eta_min=1e-6)

manager = ExperimentManager(CONFIGURATION)
manager.log_text(
    f"Teacher: {CONFIGURATION['teacher_backbone']} | "
    f"Student: {CONFIGURATION['backbone']} | "
    f"Modality: {CONFIGURATION['type']} | "
    f"kd_weight={CONFIGURATION['kd_weight']} task_weight={CONFIGURATION['task_weight']}"
)

ckpt_saver = ModelCheckpoint(
    output_dir=manager.ckpt_dir,
    mode='max',
    best_metric_name='auc_id_cosine',
)
early_stopping = MultiMetricEarlyStopping(
    monitor_keys=['auc_id_cosine'],
    patience=10,
    mode='max',
    verbose=1,
    save_dir=manager.ckpt_dir,
    start_from_epoch=5,
)

writer = SummaryWriter(log_dir=manager.log_dir)
print(f'Experiment dir: {manager.exp_dir}')
print(f'Checkpoint dir: {manager.ckpt_dir}')
print('(Tất cả được ghi thẳng vào Google Drive)')
# Out:
# KHOI TAO THI NGHIEM: KD_ConvNextV2_to_MobileNetV3_Albedo_25
# Luu tru tai: /content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25
# Thoi gian: 2026-05-25 07:31:29
# --------------------------------------------------
# Teacher: convnextv2_tiny | Student: mobilenetv3_large_100 | Modality: albedo | kd_weight=1.0 task_weight=1.0
# Experiment dir: /content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25
# Checkpoint dir: /content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints
# (Tất cả được ghi thẳng vào Google Drive)

# %%
START_EPOCH = 0

manager.log_text('BAT DAU KNOWLEDGE DISTILLATION')

for epoch in range(START_EPOCH, CONFIGURATION['epochs']):
    manager.log_text(f'\n--- Epoch {epoch+1}/{CONFIGURATION["epochs"]} ---')

    # Train
    train_loss, train_task, train_kd = train_epoch(
        train_dl, teacher, student, criterion, optimizer, device
    )

    # AUC
    train_auc = compute_id_auc(train_dl, student, device)
    test_auc  = compute_id_auc(test_dl,  student, device)

    train_metrics = {
        'loss':             train_loss,
        'loss_task':        train_task,
        'loss_kd':          train_kd,
        'auc_id_cosine':    train_auc['id_cosine'],
        'auc_id_euclidean': train_auc['id_euclidean'],
    }
    test_metrics = {
        'auc_id_cosine':    test_auc['id_cosine'],
        'auc_id_euclidean': test_auc['id_euclidean'],
    }

    # TensorBoard
    writer.add_scalar('Loss/total', train_loss, epoch + 1)
    writer.add_scalar('Loss/task',  train_task, epoch + 1)
    writer.add_scalar('Loss/kd',    train_kd,   epoch + 1)
    writer.add_scalars('AUC/cosine',
        {'train': train_auc['id_cosine'],    'test': test_auc['id_cosine']},    epoch + 1)
    writer.add_scalars('AUC/euclidean',
        {'train': train_auc['id_euclidean'], 'test': test_auc['id_euclidean']}, epoch + 1)

    # Console + file log
    display_metrics(epoch + 1, train_metrics, test_metrics)
    manager.log_metrics(epoch + 1, {**train_metrics, **test_metrics})

    # Checkpoint + Scheduler
    ckpt_saver(student, optimizer, epoch + 1, test_metrics, scheduler)
    early_stopping(test_metrics, student,epoch+1)
    scheduler.step(epoch)

    if early_stopping.early_stop:
        manager.log_text('Early stopping triggered.')
        break

writer.close()
manager.log_text('KNOWLEDGE DISTILLATION HOAN TAT.')
# Out:
# BAT DAU KNOWLEDGE DISTILLATION
#
# --- Epoch 1/40 ---
#
# Ep 1:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 30.2861 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 29.2846 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  1.0015 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9073 │ 0.8918 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9073 │ 0.8918 │
# ╘══════════════════╧═════════╧════════╛
# Ep 1: loss: 30.2861, loss_task: 29.2846, loss_kd: 1.0015, auc_id_cosine: 0.8918, auc_id_euclidean: 0.8918
# --> SAVE BEST MODEL (auc_id_cosine: 0.8918)
#
# --- Epoch 2/40 ---
#
# Ep 2:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 32.3802 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 31.3817 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9985 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9327 │ 0.9063 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9327 │ 0.9063 │
# ╘══════════════════╧═════════╧════════╛
# Ep 2: loss: 32.3802, loss_task: 31.3817, loss_kd: 0.9985, auc_id_cosine: 0.9063, auc_id_euclidean: 0.9063
# --> SAVE BEST MODEL (auc_id_cosine: 0.9063)
#
# --- Epoch 3/40 ---
#
# Ep 3:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 30.7356 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 29.738  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9976 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9463 │ 0.9191 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9463 │ 0.9191 │
# ╘══════════════════╧═════════╧════════╛
# Ep 3: loss: 30.7356, loss_task: 29.7380, loss_kd: 0.9976, auc_id_cosine: 0.9191, auc_id_euclidean: 0.9191
# --> SAVE BEST MODEL (auc_id_cosine: 0.9191)
#
# --- Epoch 4/40 ---
#
# Ep 4:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 28.5458 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 27.5509 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9949 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9583 │ 0.9291 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9583 │ 0.9291 │
# ╘══════════════════╧═════════╧════════╛
# Ep 4: loss: 28.5458, loss_task: 27.5509, loss_kd: 0.9949, auc_id_cosine: 0.9291, auc_id_euclidean: 0.9291
# --> SAVE BEST MODEL (auc_id_cosine: 0.9291)
#
# --- Epoch 5/40 ---
#
# Ep 5:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 25.9957 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 25.0022 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9935 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9685 │ 0.9363 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9685 │ 0.9363 │
# ╘══════════════════╧═════════╧════════╛
# Ep 5: loss: 25.9957, loss_task: 25.0022, loss_kd: 0.9935, auc_id_cosine: 0.9363, auc_id_euclidean: 0.9363
# --> SAVE BEST MODEL (auc_id_cosine: 0.9363)
# 	Saved best model weights for 'auc_id_cosine' at epoch 5 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_5.pth'
#
# --- Epoch 6/40 ---
#
# Ep 6:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 23.2145 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 22.2202 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9943 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.979  │ 0.9426 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.979  │ 0.9426 │
# ╘══════════════════╧═════════╧════════╛
# Ep 6: loss: 23.2145, loss_task: 22.2202, loss_kd: 0.9943, auc_id_cosine: 0.9426, auc_id_euclidean: 0.9426
# --> SAVE BEST MODEL (auc_id_cosine: 0.9426)
# 	Saved best model weights for 'auc_id_cosine' at epoch 6 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_6.pth'
#
# --- Epoch 7/40 ---
#
# Ep 7:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 20.6781 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 19.6855 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9927 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.979  │ 0.9435 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.979  │ 0.9435 │
# ╘══════════════════╧═════════╧════════╛
# Ep 7: loss: 20.6781, loss_task: 19.6855, loss_kd: 0.9927, auc_id_cosine: 0.9435, auc_id_euclidean: 0.9435
# --> SAVE BEST MODEL (auc_id_cosine: 0.9435)
# 	Saved best model weights for 'auc_id_cosine' at epoch 7 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_7.pth'
#
# --- Epoch 8/40 ---
#
# Ep 8:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 18.433  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 17.4417 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9912 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9835 │ 0.9442 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9835 │ 0.9442 │
# ╘══════════════════╧═════════╧════════╛
# Ep 8: loss: 18.4330, loss_task: 17.4417, loss_kd: 0.9912, auc_id_cosine: 0.9442, auc_id_euclidean: 0.9442
# --> SAVE BEST MODEL (auc_id_cosine: 0.9442)
# 	Saved best model weights for 'auc_id_cosine' at epoch 8 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_8.pth'
#
# --- Epoch 9/40 ---
#
# Ep 9:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 16.4859 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 15.4938 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9921 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9819 │ 0.9444 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9819 │ 0.9444 │
# ╘══════════════════╧═════════╧════════╛
# Ep 9: loss: 16.4859, loss_task: 15.4938, loss_kd: 0.9921, auc_id_cosine: 0.9444, auc_id_euclidean: 0.9444
# --> SAVE BEST MODEL (auc_id_cosine: 0.9444)
# 	Saved best model weights for 'auc_id_cosine' at epoch 9 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_9.pth'
#
# --- Epoch 10/40 ---
#
# Ep 10:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 15.1398 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 14.1492 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9906 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9909 │ 0.9477 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9909 │ 0.9477 │
# ╘══════════════════╧═════════╧════════╛
# Ep 10: loss: 15.1398, loss_task: 14.1492, loss_kd: 0.9906, auc_id_cosine: 0.9477, auc_id_euclidean: 0.9477
# --> SAVE BEST MODEL (auc_id_cosine: 0.9477)
# 	Saved best model weights for 'auc_id_cosine' at epoch 10 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_10.pth'
#
# --- Epoch 11/40 ---
#
# Ep 11:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 13.6982 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 12.7082 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.99   │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9893 │ 0.9463 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9893 │ 0.9463 │
# ╘══════════════════╧═════════╧════════╛
# Ep 11: loss: 13.6982, loss_task: 12.7082, loss_kd: 0.9900, auc_id_cosine: 0.9463, auc_id_euclidean: 0.9463
# 	Epoch 11: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 12/40 ---
#
# Ep 12:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 12.7592 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 11.7697 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9895 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9902 │ 0.9487 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9902 │ 0.9487 │
# ╘══════════════════╧═════════╧════════╛
# Ep 12: loss: 12.7592, loss_task: 11.7697, loss_kd: 0.9895, auc_id_cosine: 0.9487, auc_id_euclidean: 0.9487
# --> SAVE BEST MODEL (auc_id_cosine: 0.9487)
# 	Saved best model weights for 'auc_id_cosine' at epoch 12 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_12.pth'
#
# --- Epoch 13/40 ---
#
# Ep 13:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 12.0398 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 11.0495 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9903 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9906 │ 0.9511 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9906 │ 0.9511 │
# ╘══════════════════╧═════════╧════════╛
# Ep 13: loss: 12.0398, loss_task: 11.0495, loss_kd: 0.9903, auc_id_cosine: 0.9511, auc_id_euclidean: 0.9511
# --> SAVE BEST MODEL (auc_id_cosine: 0.9511)
# 	Saved best model weights for 'auc_id_cosine' at epoch 13 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_13.pth'
#
# --- Epoch 14/40 ---
#
# Ep 14:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 11.5625 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │ 10.573  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9896 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9888 │ 0.9495 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9888 │ 0.9495 │
# ╘══════════════════╧═════════╧════════╛
# Ep 14: loss: 11.5625, loss_task: 10.5730, loss_kd: 0.9896, auc_id_cosine: 0.9495, auc_id_euclidean: 0.9495
# 	Epoch 14: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 15/40 ---
#
# Ep 15:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 10.8923 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.9034 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9889 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9929 │ 0.9499 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9929 │ 0.9499 │
# ╘══════════════════╧═════════╧════════╛
# Ep 15: loss: 10.8923, loss_task: 9.9034, loss_kd: 0.9889, auc_id_cosine: 0.9499, auc_id_euclidean: 0.9499
# 	Epoch 15: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 16/40 ---
#
# Ep 16:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 10.5631 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.5743 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9888 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9918 │ 0.9507 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9918 │ 0.9507 │
# ╘══════════════════╧═════════╧════════╛
# Ep 16: loss: 10.5631, loss_task: 9.5743, loss_kd: 0.9888, auc_id_cosine: 0.9507, auc_id_euclidean: 0.9507
# 	Epoch 16: EarlyStopping counter for 'auc_id_cosine': 3/10
#
# --- Epoch 17/40 ---
#
# Ep 17:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 10.3627 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.3741 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9887 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9911 │ 0.9500 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9911 │ 0.9500 │
# ╘══════════════════╧═════════╧════════╛
# Ep 17: loss: 10.3627, loss_task: 9.3741, loss_kd: 0.9887, auc_id_cosine: 0.9500, auc_id_euclidean: 0.9500
# 	Epoch 17: EarlyStopping counter for 'auc_id_cosine': 4/10
#
# --- Epoch 18/40 ---
#
# Ep 18:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 10.2775 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.2898 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9877 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9901 │ 0.9521 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9901 │ 0.9521 │
# ╘══════════════════╧═════════╧════════╛
# Ep 18: loss: 10.2775, loss_task: 9.2898, loss_kd: 0.9877, auc_id_cosine: 0.9521, auc_id_euclidean: 0.9521
# --> SAVE BEST MODEL (auc_id_cosine: 0.9521)
# 	Saved best model weights for 'auc_id_cosine' at epoch 18 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_18.pth'
#
# --- Epoch 19/40 ---
#
# Ep 19:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │ 10.1268 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  9.1381 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9887 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9911 │ 0.9518 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9911 │ 0.9518 │
# ╘══════════════════╧═════════╧════════╛
# Ep 19: loss: 10.1268, loss_task: 9.1381, loss_kd: 0.9887, auc_id_cosine: 0.9518, auc_id_euclidean: 0.9518
# 	Epoch 19: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 20/40 ---
#
# Ep 20:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  9.8884 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  8.901  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9874 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9927 │ 0.9524 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9927 │ 0.9524 │
# ╘══════════════════╧═════════╧════════╛
# Ep 20: loss: 9.8884, loss_task: 8.9010, loss_kd: 0.9874, auc_id_cosine: 0.9524, auc_id_euclidean: 0.9524
# --> SAVE BEST MODEL (auc_id_cosine: 0.9524)
# 	Saved best model weights for 'auc_id_cosine' at epoch 20 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_20.pth'
#
# --- Epoch 21/40 ---
#
# Ep 21:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  9.8159 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  8.8282 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9877 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9917 │ 0.9516 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9917 │ 0.9516 │
# ╘══════════════════╧═════════╧════════╛
# Ep 21: loss: 9.8159, loss_task: 8.8282, loss_kd: 0.9877, auc_id_cosine: 0.9516, auc_id_euclidean: 0.9516
# 	Epoch 21: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 22/40 ---
#
# Ep 22:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  9.8209 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  8.8358 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9851 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9912 │ 0.9518 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9912 │ 0.9518 │
# ╘══════════════════╧═════════╧════════╛
# Ep 22: loss: 9.8209, loss_task: 8.8358, loss_kd: 0.9851, auc_id_cosine: 0.9518, auc_id_euclidean: 0.9518
# 	Epoch 22: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 23/40 ---
#
# Ep 23:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  8.8627 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  7.877  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9857 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9951 │ 0.9545 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9951 │ 0.9545 │
# ╘══════════════════╧═════════╧════════╛
# Ep 23: loss: 8.8627, loss_task: 7.8770, loss_kd: 0.9857, auc_id_cosine: 0.9545, auc_id_euclidean: 0.9545
# --> SAVE BEST MODEL (auc_id_cosine: 0.9545)
# 	Saved best model weights for 'auc_id_cosine' at epoch 23 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_23.pth'
#
# --- Epoch 24/40 ---
#
# Ep 24:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  8.2097 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  7.2235 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9862 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9952 │ 0.9530 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9952 │ 0.9530 │
# ╘══════════════════╧═════════╧════════╛
# Ep 24: loss: 8.2097, loss_task: 7.2235, loss_kd: 0.9862, auc_id_cosine: 0.9530, auc_id_euclidean: 0.9530
# 	Epoch 24: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 25/40 ---
#
# Ep 25:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  7.2766 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  6.2927 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9839 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9963 │ 0.9535 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9963 │ 0.9535 │
# ╘══════════════════╧═════════╧════════╛
# Ep 25: loss: 7.2766, loss_task: 6.2927, loss_kd: 0.9839, auc_id_cosine: 0.9535, auc_id_euclidean: 0.9535
# 	Epoch 25: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 26/40 ---
#
# Ep 26:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.9924 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  6.0118 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9806 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9966 │ 0.9553 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9966 │ 0.9553 │
# ╘══════════════════╧═════════╧════════╛
# Ep 26: loss: 6.9924, loss_task: 6.0118, loss_kd: 0.9806, auc_id_cosine: 0.9553, auc_id_euclidean: 0.9553
# --> SAVE BEST MODEL (auc_id_cosine: 0.9553)
# 	Saved best model weights for 'auc_id_cosine' at epoch 26 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_26.pth'
#
# --- Epoch 27/40 ---
#
# Ep 27:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.356  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  5.3758 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9802 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9979 │ 0.9595 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9979 │ 0.9595 │
# ╘══════════════════╧═════════╧════════╛
# Ep 27: loss: 6.3560, loss_task: 5.3758, loss_kd: 0.9802, auc_id_cosine: 0.9595, auc_id_euclidean: 0.9595
# --> SAVE BEST MODEL (auc_id_cosine: 0.9595)
# 	Saved best model weights for 'auc_id_cosine' at epoch 27 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_27.pth'
#
# --- Epoch 28/40 ---
#
# Ep 28:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  6.0362 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  5.0569 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9793 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9976 │ 0.9588 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9976 │ 0.9588 │
# ╘══════════════════╧═════════╧════════╛
# Ep 28: loss: 6.0362, loss_task: 5.0569, loss_kd: 0.9793, auc_id_cosine: 0.9588, auc_id_euclidean: 0.9588
# 	Epoch 28: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 29/40 ---
#
# Ep 29:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.8454 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  4.8679 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9776 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9984 │ 0.9612 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9984 │ 0.9612 │
# ╘══════════════════╧═════════╧════════╛
# Ep 29: loss: 5.8454, loss_task: 4.8679, loss_kd: 0.9776, auc_id_cosine: 0.9612, auc_id_euclidean: 0.9612
# --> SAVE BEST MODEL (auc_id_cosine: 0.9612)
# 	Saved best model weights for 'auc_id_cosine' at epoch 29 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_29.pth'
#
# --- Epoch 30/40 ---
#
# Ep 30:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.4478 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  4.4702 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9776 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9985 │ 0.9618 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9985 │ 0.9618 │
# ╘══════════════════╧═════════╧════════╛
# Ep 30: loss: 5.4478, loss_task: 4.4702, loss_kd: 0.9776, auc_id_cosine: 0.9618, auc_id_euclidean: 0.9618
# --> SAVE BEST MODEL (auc_id_cosine: 0.9618)
# 	Saved best model weights for 'auc_id_cosine' at epoch 30 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_30.pth'
#
# --- Epoch 31/40 ---
#
# Ep 31:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.2809 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  4.3063 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9746 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9984 │ 0.9619 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9984 │ 0.9619 │
# ╘══════════════════╧═════════╧════════╛
# Ep 31: loss: 5.2809, loss_task: 4.3063, loss_kd: 0.9746, auc_id_cosine: 0.9619, auc_id_euclidean: 0.9619
# --> SAVE BEST MODEL (auc_id_cosine: 0.9619)
# 	Saved best model weights for 'auc_id_cosine' at epoch 31 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_31.pth'
#
# --- Epoch 32/40 ---
#
# Ep 32:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  5.0114 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  4.0367 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9747 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9989 │ 0.9637 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9989 │ 0.9637 │
# ╘══════════════════╧═════════╧════════╛
# Ep 32: loss: 5.0114, loss_task: 4.0367, loss_kd: 0.9747, auc_id_cosine: 0.9637, auc_id_euclidean: 0.9637
# --> SAVE BEST MODEL (auc_id_cosine: 0.9637)
# 	Saved best model weights for 'auc_id_cosine' at epoch 32 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_32.pth'
#
# --- Epoch 33/40 ---
#
# Ep 33:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.7075 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.7363 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9711 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9995 │ 0.9638 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9995 │ 0.9638 │
# ╘══════════════════╧═════════╧════════╛
# Ep 33: loss: 4.7075, loss_task: 3.7363, loss_kd: 0.9711, auc_id_cosine: 0.9638, auc_id_euclidean: 0.9638
# --> SAVE BEST MODEL (auc_id_cosine: 0.9638)
# 	Saved best model weights for 'auc_id_cosine' at epoch 33 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_33.pth'
#
# --- Epoch 34/40 ---
#
# Ep 34:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.6429 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.6734 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9694 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9996 │ 0.9635 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9996 │ 0.9635 │
# ╘══════════════════╧═════════╧════════╛
# Ep 34: loss: 4.6429, loss_task: 3.6734, loss_kd: 0.9694, auc_id_cosine: 0.9635, auc_id_euclidean: 0.9635
# 	Epoch 34: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 35/40 ---
#
# Ep 35:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.5431 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.5738 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9693 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9993 │ 0.9639 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9993 │ 0.9639 │
# ╘══════════════════╧═════════╧════════╛
# Ep 35: loss: 4.5431, loss_task: 3.5738, loss_kd: 0.9693, auc_id_cosine: 0.9639, auc_id_euclidean: 0.9639
# --> SAVE BEST MODEL (auc_id_cosine: 0.9639)
# 	Saved best model weights for 'auc_id_cosine' at epoch 35 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_35.pth'
#
# --- Epoch 36/40 ---
#
# Ep 36:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.3765 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.407  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9695 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9997 │ 0.9659 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9997 │ 0.9659 │
# ╘══════════════════╧═════════╧════════╛
# Ep 36: loss: 4.3765, loss_task: 3.4070, loss_kd: 0.9695, auc_id_cosine: 0.9659, auc_id_euclidean: 0.9659
# --> SAVE BEST MODEL (auc_id_cosine: 0.9659)
# 	Saved best model weights for 'auc_id_cosine' at epoch 36 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_36.pth'
#
# --- Epoch 37/40 ---
#
# Ep 37:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.2905 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.3226 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9679 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9993 │ 0.9660 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9993 │ 0.9660 │
# ╘══════════════════╧═════════╧════════╛
# Ep 37: loss: 4.2905, loss_task: 3.3226, loss_kd: 0.9679, auc_id_cosine: 0.9660, auc_id_euclidean: 0.9660
# --> SAVE BEST MODEL (auc_id_cosine: 0.9660)
# 	Saved best model weights for 'auc_id_cosine' at epoch 37 to '/content/drive/MyDrive/experiments/KD_ConvNextV2_to_MobileNetV3_Albedo_25/checkpoints/best_auc_id_cosine_37.pth'
#
# --- Epoch 38/40 ---
#
# Ep 38:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.143  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.1773 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9657 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9991 │ 0.9642 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9991 │ 0.9642 │
# ╘══════════════════╧═════════╧════════╛
# Ep 38: loss: 4.1430, loss_task: 3.1773, loss_kd: 0.9657, auc_id_cosine: 0.9642, auc_id_euclidean: 0.9642
# 	Epoch 38: EarlyStopping counter for 'auc_id_cosine': 1/10
#
# --- Epoch 39/40 ---
#
# Ep 39:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  4.075  │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  3.1118 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9632 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9996 │ 0.9636 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9996 │ 0.9636 │
# ╘══════════════════╧═════════╧════════╛
# Ep 39: loss: 4.0750, loss_task: 3.1118, loss_kd: 0.9632, auc_id_cosine: 0.9636, auc_id_euclidean: 0.9636
# 	Epoch 39: EarlyStopping counter for 'auc_id_cosine': 2/10
#
# --- Epoch 40/40 ---
#
# Ep 40:
# ╒══════════════════╤═════════╤════════╕
# │ Metric           │   Train │ Test   │
# ╞══════════════════╪═════════╪════════╡
# │ loss             │  3.9026 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_task        │  2.9395 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ loss_kd          │  0.9631 │ -      │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_cosine    │  0.9984 │ 0.9646 │
# ├──────────────────┼─────────┼────────┤
# │ auc_id_euclidean │  0.9984 │ 0.9646 │
# ╘══════════════════╧═════════╧════════╛
# Ep 40: loss: 3.9026, loss_task: 2.9395, loss_kd: 0.9631, auc_id_cosine: 0.9646, auc_id_euclidean: 0.9646
# 	Epoch 40: EarlyStopping counter for 'auc_id_cosine': 3/10
# KNOWLEDGE DISTILLATION HOAN TAT.

# %% [markdown]
# ## 8. Resume Training từ Checkpoint
#
# > Chạy cell này khi Colab disconnect và muốn tiếp tục train.
# > Checkpoint đã được ghi thẳng vào Drive nên không bị mất.
# >
# > **Cách dùng:** Chạy cell Setup → Imports → Data → Teacher → Student → Loss → Setup Train,
# > sau đó chạy cell này (không chạy cell fit ở trên), rồi chạy lại cell fit.

# %%
CKPT_PATH = os.path.join(manager.ckpt_dir, 'last_model.pth')

if not os.path.exists(CKPT_PATH):
    raise FileNotFoundError(f'Không tìm thấy checkpoint: {CKPT_PATH}')

checkpoint = torch.load(CKPT_PATH, map_location=device)
student.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
if 'scheduler_state_dict' in checkpoint:
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])

START_EPOCH = checkpoint['epoch']
print(f'Resume từ epoch {START_EPOCH} — chạy lại cell "cell-fit" để tiếp tục.')

# %% [markdown]
# ## 9. Đánh giá Final

# %%
best_ckpt_path = os.path.join(manager.ckpt_dir, 'best_model.pth')
best_ckpt = torch.load(best_ckpt_path, map_location=device, weights_only=False)
student.load_state_dict(best_ckpt['model_state_dict'])
student.eval()
print(f"Best model từ epoch {best_ckpt.get('epoch', '?')}")

student_gp_auc   = compute_id_auc_gallery_probe(gallery_dl, probe_dl, student, device)
student_gp_rank1 = compute_rank1_gallery_probe(gallery_dl, probe_dl, student, device)

rows = [
    ['Cosine AUC    (gallery→probe)', f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)', f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)', f"{student_gp_rank1:.4f}"],
]
print(f"\nStudent ({CONFIGURATION['backbone']}) — KD from {CONFIGURATION['teacher_backbone']}")
print(tabulate(rows, headers=['Metric', 'Value'], tablefmt='fancy_grid'))

# So sánh Teacher vs Student
compare_rows = [
    ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
    ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
    ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
    ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
    ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
]
print('\n--- Teacher vs Student (KD) ---')
print(tabulate(compare_rows, headers=['Metric', 'Teacher', 'Student (KD)'], tablefmt='fancy_grid'))
# Out:
# Best model từ epoch 37
#
# Student (mobilenetv3_large_100) — KD from convnextv2_tiny
# ╒═══════════════════════════════╤═════════╕
# │ Metric                        │   Value │
# ╞═══════════════════════════════╪═════════╡
# │ Cosine AUC    (gallery→probe) │  0.9704 │
# ├───────────────────────────────┼─────────┤
# │ Euclidean AUC (gallery→probe) │  0.9704 │
# ├───────────────────────────────┼─────────┤
# │ Rank-1 Acc    (gallery→probe) │  0.7396 │
# ╘═══════════════════════════════╧═════════╛
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_596/3485715062.py in <cell line: 0>()
#      20     ['Model',                          CONFIGURATION['teacher_backbone'],           CONFIGURATION['backbone']],
#      21     ['Params',                         f'{teacher_params:,}',                       f'{total_p:,}'],
# ---> 22     ['Cosine AUC    (gallery→probe)',   f"{teacher_gp_auc['id_cosine']:.4f}",        f"{student_gp_auc['id_cosine']:.4f}"],
#      23     ['Euclidean AUC (gallery→probe)',   f"{teacher_gp_auc['id_euclidean']:.4f}",     f"{student_gp_auc['id_euclidean']:.4f}"],
#      24     ['Rank-1 Acc    (gallery→probe)',   f"{teacher_gp_rank1:.4f}",                   f"{student_gp_rank1:.4f}"],
#
# NameError: name 'teacher_gp_auc' is not defined

# %% [markdown]
# ## 10. Export ONNX
#
# Export phần inference (backbone + embedding + L2 normalize, bỏ MagLinear)
# để chuẩn bị quantize INT8 deploy edge device.

# %%
class InferenceWrapper(nn.Module):
    """Backbone + embedding + L2 normalize — không có MagLinear."""
    def __init__(self, model):
        super().__init__()
        self.backbone  = model.backbone
        self.embedding = model.embedding

    def forward(self, x):
        emb = self.embedding(self.backbone(x))
        return F.normalize(emb, p=2, dim=1)


inference_model = InferenceWrapper(student).eval().cpu()
dummy_input = torch.randn(1, 3, 112, 112)

# Lưu vào Drive để không mất
onnx_path = os.path.join(manager.ckpt_dir, 'kd_mobilenetv3_fr.onnx')

torch.onnx.export(
    inference_model,
    dummy_input,
    onnx_path,
    input_names=['input'],
    output_names=['embedding'],
    dynamic_axes={'input': {0: 'batch'}, 'embedding': {0: 'batch'}},
    opset_version=17,
)
print(f'Exported ONNX: {onnx_path}')
